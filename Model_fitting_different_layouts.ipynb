# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_3by3_5p.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_3by3_5p.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm

input_layer = Input(shape=(27,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32,verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.02036267  0.29820167 -0.09116619 -0.98972578  0.26476729 -0.09036746
#   -0.9837491   0.30531915 -0.07307987 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.54569173  0.19010131 -0.06120685 -0.50938901  0.23481354 -0.15790448
#   -0.61666068  0.1758637  -0.18206539]
#  [-1.00824775  0.28045885 -0.09769205 -0.98190998  0.27323716 -0.07463917
#   -0.97715078  0.32671682 -0.088353   -1.15192394  0.35794571 -0.09489435
#   -1.0909224   0.26811341 -0.13170993 -0.96211243  0.34586763 -0.20159506
#   -0.51474273  0.19205429 -0.09489435 -0.57574427  0.28188659 -0.13170993
#   -0.70455423  0.20413237 -0.20159506]]
# [[ -25.    -25.      1.      0.      0.   -110.    -60.  ]
#  [ -20.25  -25.      1.      0.      0.   -110.    -60.  ]]
# (11718, 27) (11718, 7) training data size
# (3907, 27) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 27)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               19600
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 515,207
# Trainable params: 515,207
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 2s - loss: 0.1910 - val_loss: 0.1613
# Epoch 2/30
# 367/367 - 2s - loss: 0.1450 - val_loss: 0.1589
# Epoch 3/30
# 367/367 - 2s - loss: 0.1276 - val_loss: 0.1221
# Epoch 4/30
# 367/367 - 2s - loss: 0.1160 - val_loss: 0.1167
# Epoch 5/30
# 367/367 - 2s - loss: 0.1084 - val_loss: 0.1205
# Epoch 6/30
# 367/367 - 2s - loss: 0.1009 - val_loss: 0.1023
# Epoch 7/30
# 367/367 - 2s - loss: 0.0952 - val_loss: 0.1094
# Epoch 8/30
# 367/367 - 2s - loss: 0.0914 - val_loss: 0.1059
# Epoch 9/30
# 367/367 - 2s - loss: 0.0859 - val_loss: 0.1047
# Epoch 10/30
# 367/367 - 2s - loss: 0.0854 - val_loss: 0.0915
# Epoch 11/30
# 367/367 - 2s - loss: 0.0805 - val_loss: 0.0934
# Epoch 12/30
# 367/367 - 2s - loss: 0.0780 - val_loss: 0.0994
# Epoch 13/30
# 367/367 - 2s - loss: 0.0766 - val_loss: 0.0849
# Epoch 14/30
# 367/367 - 2s - loss: 0.0743 - val_loss: 0.0896
# Epoch 15/30
# 367/367 - 2s - loss: 0.0740 - val_loss: 0.0952
# Epoch 16/30
# 367/367 - 2s - loss: 0.0718 - val_loss: 0.0942
# Epoch 17/30
# 367/367 - 2s - loss: 0.0706 - val_loss: 0.0852
# Epoch 18/30
# 367/367 - 2s - loss: 0.0702 - val_loss: 0.0806
# Epoch 19/30
# 367/367 - 2s - loss: 0.0690 - val_loss: 0.0825
# Epoch 20/30
# 367/367 - 2s - loss: 0.0687 - val_loss: 0.0991
# Epoch 21/30
# 367/367 - 2s - loss: 0.0656 - val_loss: 0.0878
# Epoch 22/30
# 367/367 - 2s - loss: 0.0649 - val_loss: 0.0940
# Epoch 23/30
# 367/367 - 2s - loss: 0.0655 - val_loss: 0.0829
# Epoch 24/30
# 367/367 - 2s - loss: 0.0633 - val_loss: 0.0884
# Epoch 25/30
# 367/367 - 2s - loss: 0.0631 - val_loss: 0.0916
# Epoch 26/30
# 367/367 - 2s - loss: 0.0618 - val_loss: 0.0799
# Epoch 27/30
# 367/367 - 2s - loss: 0.0614 - val_loss: 0.0834
# Epoch 28/30
# 367/367 - 2s - loss: 0.0613 - val_loss: 0.0824
# Epoch 29/30
# 367/367 - 2s - loss: 0.0585 - val_loss: 0.0858
# Epoch 30/30
# 367/367 - 2s - loss: 0.0593 - val_loss: 0.0885

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_5by5_5p.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_5by5_5p.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(75,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.9488398   0.27977635 -0.06382377
#   -0.93883182  0.27000495 -0.06162218 -0.93148948  0.26939003 -0.0527648
#   -0.93109606  0.28276686 -0.04627309 -0.98153236  0.30460744 -0.05918509
#   -0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.0120749   0.32409174 -0.04765968 -1.02291172  0.31880814 -0.06668594
#   -1.02036267  0.29820167 -0.09116619 -0.98972578  0.26476729 -0.09036746
#   -0.9837491   0.30531915 -0.07307987 -1.0357901   0.34044636 -0.01908688
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.63087656  0.20955364 -0.01908688 -0.59768246  0.20031284 -0.03087716
#   -0.54569173  0.19010131 -0.06120685 -0.50938901  0.23481354 -0.15790448
#   -0.61666068  0.1758637  -0.18206539]
#  [-0.94906436  0.28005432 -0.06378252 -0.93908118  0.27017944 -0.06177466
#   -0.93158594  0.26922574 -0.05301074 -0.93105513  0.28231883 -0.04631448
#   -0.93144176  0.29982134 -0.05004352 -0.97839739  0.2933505  -0.07036558
#   -0.96585982  0.27592104 -0.07564251 -0.95078506  0.26699579 -0.06520045
#   -0.94932924  0.28774936 -0.05465025 -0.94645257  0.31294373 -0.06586889
#   -1.02272593  0.31906828 -0.06611355 -1.02077071  0.29901301 -0.09062266
#   -0.99050553  0.26508204 -0.09110694 -0.9837551   0.3037751  -0.07257984
#   -0.95944684  0.33227993 -0.1044864  -1.06796758  0.34942397 -0.03044844
#   -1.11938532  0.35973415 -0.05994865 -1.15928041  0.31931829 -0.15501954
#   -1.05526317  0.37424272 -0.17869592 -0.9126731   0.3206714  -0.18714644
#   -0.59869909  0.20057603 -0.03044844 -0.54728134  0.19026585 -0.05994865
#   -0.50738625  0.23068171 -0.15501954 -0.6114035   0.17575728 -0.17869592
#   -0.75399357  0.2293286  -0.18714644]]
# [[ -45.    -45.      1.      0.      0.   -110.    -60.  ]
#  [ -35.25  -45.      1.      0.      0.   -110.    -60.  ]]
# (11718, 75) (11718, 7) training data size
# (3907, 75) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 75)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 700)               53200
# _________________________________________________________________
# dense_19 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 548,807
# Trainable params: 548,807
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 2s - loss: 0.1926 - val_loss: 0.1493
# Epoch 2/30
# 367/367 - 2s - loss: 0.1465 - val_loss: 0.1387
# Epoch 3/30
# 367/367 - 2s - loss: 0.1299 - val_loss: 0.1434
# Epoch 4/30
# 367/367 - 2s - loss: 0.1185 - val_loss: 0.1258
# Epoch 5/30
# 367/367 - 2s - loss: 0.1112 - val_loss: 0.1211
# Epoch 6/30
# 367/367 - 2s - loss: 0.1022 - val_loss: 0.1182
# Epoch 7/30
# 367/367 - 2s - loss: 0.0999 - val_loss: 0.1085
# Epoch 8/30
# 367/367 - 2s - loss: 0.0935 - val_loss: 0.1025
# Epoch 9/30
# 367/367 - 2s - loss: 0.0899 - val_loss: 0.1089
# Epoch 10/30
# 367/367 - 2s - loss: 0.0862 - val_loss: 0.0974
# Epoch 11/30
# 367/367 - 2s - loss: 0.0840 - val_loss: 0.1134
# Epoch 12/30
# 367/367 - 2s - loss: 0.0805 - val_loss: 0.0977
# Epoch 13/30
# 367/367 - 2s - loss: 0.0786 - val_loss: 0.1111
# Epoch 14/30
# 367/367 - 2s - loss: 0.0774 - val_loss: 0.0947
# Epoch 15/30
# 367/367 - 2s - loss: 0.0753 - val_loss: 0.0936
# Epoch 16/30
# 367/367 - 2s - loss: 0.0743 - val_loss: 0.1030
# Epoch 17/30
# 367/367 - 2s - loss: 0.0717 - val_loss: 0.0888
# Epoch 18/30
# 367/367 - 2s - loss: 0.0705 - val_loss: 0.1091
# Epoch 19/30
# 367/367 - 2s - loss: 0.0694 - val_loss: 0.1092
# Epoch 20/30
# 367/367 - 2s - loss: 0.0686 - val_loss: 0.0952
# Epoch 21/30
# 367/367 - 2s - loss: 0.0682 - val_loss: 0.0961
# Epoch 22/30
# 367/367 - 2s - loss: 0.0653 - val_loss: 0.0888
# Epoch 23/30
# 367/367 - 2s - loss: 0.0647 - val_loss: 0.0934
# Epoch 24/30
# 367/367 - 2s - loss: 0.0640 - val_loss: 0.0962
# Epoch 25/30
# 367/367 - 2s - loss: 0.0633 - val_loss: 0.0784
# Epoch 26/30
# 367/367 - 2s - loss: 0.0622 - val_loss: 0.0821
# Epoch 27/30
# 367/367 - 2s - loss: 0.0608 - val_loss: 0.0848
# Epoch 28/30
# 367/367 - 2s - loss: 0.0605 - val_loss: 0.0933
# Epoch 29/30
# 367/367 - 2s - loss: 0.0598 - val_loss: 0.0848
# Epoch 30/30
# 367/367 - 2s - loss: 0.0592 - val_loss: 0.0924

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_22 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 2s - loss: 0.1905 - val_loss: 0.1564
# Epoch 2/30
# 367/367 - 2s - loss: 0.1447 - val_loss: 0.1353
# Epoch 3/30
# 367/367 - 2s - loss: 0.1267 - val_loss: 0.1331
# Epoch 4/30
# 367/367 - 2s - loss: 0.1149 - val_loss: 0.1105
# Epoch 5/30
# 367/367 - 2s - loss: 0.1084 - val_loss: 0.1033
# Epoch 6/30
# 367/367 - 2s - loss: 0.1029 - val_loss: 0.1070
# Epoch 7/30
# 367/367 - 2s - loss: 0.0959 - val_loss: 0.1049
# Epoch 8/30
# 367/367 - 2s - loss: 0.0903 - val_loss: 0.0980
# Epoch 9/30
# 367/367 - 2s - loss: 0.0871 - val_loss: 0.0839
# Epoch 10/30
# 367/367 - 2s - loss: 0.0838 - val_loss: 0.1073
# Epoch 11/30
# 367/367 - 2s - loss: 0.0822 - val_loss: 0.0791
# Epoch 12/30
# 367/367 - 2s - loss: 0.0787 - val_loss: 0.0816
# Epoch 13/30
# 367/367 - 2s - loss: 0.0755 - val_loss: 0.0778
# Epoch 14/30
# 367/367 - 2s - loss: 0.0762 - val_loss: 0.0898
# Epoch 15/30
# 367/367 - 2s - loss: 0.0745 - val_loss: 0.0862
# Epoch 16/30
# 367/367 - 2s - loss: 0.0727 - val_loss: 0.0850
# Epoch 17/30
# 367/367 - 2s - loss: 0.0708 - val_loss: 0.0731
# Epoch 18/30
# 367/367 - 2s - loss: 0.0699 - val_loss: 0.0764
# Epoch 19/30
# 367/367 - 2s - loss: 0.0694 - val_loss: 0.0935
# Epoch 20/30
# 367/367 - 2s - loss: 0.0677 - val_loss: 0.0750
# Epoch 21/30
# 367/367 - 2s - loss: 0.0666 - val_loss: 0.0748
# Epoch 22/30
# 367/367 - 2s - loss: 0.0665 - val_loss: 0.0791
# Epoch 23/30
# 367/367 - 2s - loss: 0.0656 - val_loss: 0.0806
# Epoch 24/30
# 367/367 - 2s - loss: 0.0653 - val_loss: 0.0718
# Epoch 25/30
# 367/367 - 2s - loss: 0.0627 - val_loss: 0.0757
# Epoch 26/30
# 367/367 - 2s - loss: 0.0615 - val_loss: 0.0620
# Epoch 27/30
# 367/367 - 2s - loss: 0.0621 - val_loss: 0.0846
# Epoch 28/30
# 367/367 - 2s - loss: 0.0632 - val_loss: 0.0836
# Epoch 29/30
# 367/367 - 2s - loss: 0.0613 - val_loss: 0.0752
# Epoch 30/30
# 367/367 - 2s - loss: 0.0605 - val_loss: 0.0875

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_25 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_26 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 2s - loss: 0.1894 - val_loss: 0.1557
# Epoch 2/30
# 367/367 - 2s - loss: 0.1438 - val_loss: 0.1399
# Epoch 3/30
# 367/367 - 2s - loss: 0.1289 - val_loss: 0.1348
# Epoch 4/30
# 367/367 - 2s - loss: 0.1168 - val_loss: 0.1116
# Epoch 5/30
# 367/367 - 2s - loss: 0.1079 - val_loss: 0.1066
# Epoch 6/30
# 367/367 - 2s - loss: 0.1023 - val_loss: 0.1169
# Epoch 7/30
# 367/367 - 2s - loss: 0.0962 - val_loss: 0.1058
# Epoch 8/30
# 367/367 - 2s - loss: 0.0910 - val_loss: 0.0922
# Epoch 9/30
# 367/367 - 2s - loss: 0.0907 - val_loss: 0.1035
# Epoch 10/30
# 367/367 - 2s - loss: 0.0872 - val_loss: 0.1020
# Epoch 11/30
# 367/367 - 2s - loss: 0.0845 - val_loss: 0.1029
# Epoch 12/30
# 367/367 - 2s - loss: 0.0827 - val_loss: 0.0916
# Epoch 13/30
# 367/367 - 2s - loss: 0.0808 - val_loss: 0.0892
# Epoch 14/30
# 367/367 - 2s - loss: 0.0788 - val_loss: 0.0962
# Epoch 15/30
# 367/367 - 2s - loss: 0.0782 - val_loss: 0.0967
# Epoch 16/30
# 367/367 - 2s - loss: 0.0769 - val_loss: 0.0964
# Epoch 17/30
# 367/367 - 2s - loss: 0.0748 - val_loss: 0.0904
# Epoch 18/30
# 367/367 - 2s - loss: 0.0743 - val_loss: 0.0892
# Epoch 19/30
# 367/367 - 2s - loss: 0.0738 - val_loss: 0.0830
# Epoch 20/30
# 367/367 - 2s - loss: 0.0728 - val_loss: 0.0861
# Epoch 21/30
# 367/367 - 2s - loss: 0.0712 - val_loss: 0.0753
# Epoch 22/30
# 367/367 - 2s - loss: 0.0704 - val_loss: 0.0854
# Epoch 23/30
# 367/367 - 2s - loss: 0.0699 - val_loss: 0.0883
# Epoch 24/30
# 367/367 - 2s - loss: 0.0689 - val_loss: 0.0773
# Epoch 25/30
# 367/367 - 2s - loss: 0.0685 - val_loss: 0.0816
# Epoch 26/30
# 367/367 - 2s - loss: 0.0660 - val_loss: 0.0855
# Epoch 27/30
# 367/367 - 2s - loss: 0.0667 - val_loss: 0.0715
# Epoch 28/30
# 367/367 - 2s - loss: 0.0649 - val_loss: 0.0753
# Epoch 29/30
# 367/367 - 2s - loss: 0.0638 - val_loss: 0.0779
# Epoch 30/30
# 367/367 - 2s - loss: 0.0640 - val_loss: 0.0871

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_28 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_29 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 2s - loss: 0.1853 - val_loss: 0.1533
# Epoch 2/30
# 352/352 - 2s - loss: 0.1427 - val_loss: 0.1267
# Epoch 3/30
# 352/352 - 2s - loss: 0.1217 - val_loss: 0.1217
# Epoch 4/30
# 352/352 - 2s - loss: 0.1060 - val_loss: 0.1191
# Epoch 5/30
# 352/352 - 2s - loss: 0.0959 - val_loss: 0.1055
# Epoch 6/30
# 352/352 - 2s - loss: 0.0872 - val_loss: 0.1040
# Epoch 7/30
# 352/352 - 2s - loss: 0.0809 - val_loss: 0.0932
# Epoch 8/30
# 352/352 - 2s - loss: 0.0767 - val_loss: 0.0856
# Epoch 9/30
# 352/352 - 2s - loss: 0.0735 - val_loss: 0.0883
# Epoch 10/30
# 352/352 - 2s - loss: 0.0684 - val_loss: 0.0885
# Epoch 11/30
# 352/352 - 2s - loss: 0.0664 - val_loss: 0.0878
# Epoch 12/30
# 352/352 - 2s - loss: 0.0660 - val_loss: 0.0837
# Epoch 13/30
# 352/352 - 2s - loss: 0.0631 - val_loss: 0.0853
# Epoch 14/30
# 352/352 - 2s - loss: 0.0620 - val_loss: 0.0837
# Epoch 15/30
# 352/352 - 2s - loss: 0.0598 - val_loss: 0.0780
# Epoch 16/30
# 352/352 - 2s - loss: 0.0584 - val_loss: 0.0807
# Epoch 17/30
# 352/352 - 2s - loss: 0.0579 - val_loss: 0.0826
# Epoch 18/30
# 352/352 - 2s - loss: 0.0549 - val_loss: 0.0813
# Epoch 19/30
# 352/352 - 2s - loss: 0.0552 - val_loss: 0.0765
# Epoch 20/30
# 352/352 - 2s - loss: 0.0547 - val_loss: 0.0801
# Epoch 21/30
# 352/352 - 2s - loss: 0.0547 - val_loss: 0.0782
# Epoch 22/30
# 352/352 - 2s - loss: 0.0530 - val_loss: 0.0796
# Epoch 23/30
# 352/352 - 2s - loss: 0.0522 - val_loss: 0.0774
# Epoch 24/30
# 352/352 - 2s - loss: 0.0509 - val_loss: 0.0738
# Epoch 25/30
# 352/352 - 2s - loss: 0.0506 - val_loss: 0.0759
# Epoch 26/30
# 352/352 - 2s - loss: 0.0494 - val_loss: 0.0721
# Epoch 27/30
# 352/352 - 2s - loss: 0.0493 - val_loss: 0.0783
# Epoch 28/30
# 352/352 - 2s - loss: 0.0478 - val_loss: 0.0722
# Epoch 29/30
# 352/352 - 2s - loss: 0.0481 - val_loss: 0.0846
# Epoch 30/30
# 352/352 - 2s - loss: 0.0474 - val_loss: 0.0732

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['3x3','4x4','5x5','8x4','Hexagon'], loc='upper right')
#plt.xlim(0,50)
#plt.ylim(0.07,0.17)
#plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.07, 0.18, 0.02))
plt.savefig('Validation_Loss_for_different_layouts.png', dpi=300)
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['3x3','4x4','5x5','8x4','Hexagon'], loc='upper right')
#plt.xlim(0,50)
#plt.ylim(0.07,0.17)
#plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.07, 0.18, 0.02))
plt.savefig('Training_Loss_for_different_layouts.png', dpi=300)
plt.show()
