# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm

input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=32,verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense (Dense)                (None, 700)               34300
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 367/367 - 2s - loss: 0.1888 - val_loss: 0.1722
# Epoch 2/20
# 367/367 - 2s - loss: 0.1441 - val_loss: 0.1444
# Epoch 3/20
# 367/367 - 2s - loss: 0.1261 - val_loss: 0.1318
# Epoch 4/20
# 367/367 - 2s - loss: 0.1153 - val_loss: 0.1168
# Epoch 5/20
# 367/367 - 2s - loss: 0.1071 - val_loss: 0.1117
# Epoch 6/20
# 367/367 - 2s - loss: 0.1006 - val_loss: 0.0989
# Epoch 7/20
# 367/367 - 2s - loss: 0.0970 - val_loss: 0.1056
# Epoch 8/20
# 367/367 - 2s - loss: 0.0898 - val_loss: 0.0934
# Epoch 9/20
# 367/367 - 2s - loss: 0.0869 - val_loss: 0.0932
# Epoch 10/20
# 367/367 - 2s - loss: 0.0831 - val_loss: 0.0930
# Epoch 11/20
# 367/367 - 2s - loss: 0.0819 - val_loss: 0.0912
# Epoch 12/20
# 367/367 - 2s - loss: 0.0794 - val_loss: 0.0858
# Epoch 13/20
# 367/367 - 2s - loss: 0.0759 - val_loss: 0.0816
# Epoch 14/20
# 367/367 - 2s - loss: 0.0752 - val_loss: 0.0861
# Epoch 15/20
# 367/367 - 2s - loss: 0.0731 - val_loss: 0.0911
# Epoch 16/20
# 367/367 - 2s - loss: 0.0721 - val_loss: 0.0789
# Epoch 17/20
# 367/367 - 2s - loss: 0.0698 - val_loss: 0.0836
# Epoch 18/20
# 367/367 - 2s - loss: 0.0693 - val_loss: 0.0821
# Epoch 19/20
# 367/367 - 2s - loss: 0.0670 - val_loss: 0.0911
# Epoch 20/20
# 367/367 - 2s - loss: 0.0672 - val_loss: 0.0880

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 92/92 - 1s - loss: 0.2199 - val_loss: 0.1846
# Epoch 2/20
# 92/92 - 1s - loss: 0.1689 - val_loss: 0.1528
# Epoch 3/20
# 92/92 - 1s - loss: 0.1486 - val_loss: 0.1392
# Epoch 4/20
# 92/92 - 1s - loss: 0.1379 - val_loss: 0.1333
# Epoch 5/20
# 92/92 - 0s - loss: 0.1271 - val_loss: 0.1258
# Epoch 6/20
# 92/92 - 1s - loss: 0.1228 - val_loss: 0.1264
# Epoch 7/20
# 92/92 - 1s - loss: 0.1162 - val_loss: 0.1109
# Epoch 8/20
# 92/92 - 1s - loss: 0.1121 - val_loss: 0.1116
# Epoch 9/20
# 92/92 - 0s - loss: 0.1063 - val_loss: 0.1047
# Epoch 10/20
# 92/92 - 1s - loss: 0.1038 - val_loss: 0.1055
# Epoch 11/20
# 92/92 - 1s - loss: 0.1002 - val_loss: 0.1028
# Epoch 12/20
# 92/92 - 1s - loss: 0.1001 - val_loss: 0.1009
# Epoch 13/20
# 92/92 - 1s - loss: 0.0953 - val_loss: 0.0958
# Epoch 14/20
# 92/92 - 1s - loss: 0.0923 - val_loss: 0.1008
# Epoch 15/20
# 92/92 - 1s - loss: 0.0912 - val_loss: 0.0941
# Epoch 16/20
# 92/92 - 1s - loss: 0.0878 - val_loss: 0.0947
# Epoch 17/20
# 92/92 - 1s - loss: 0.0861 - val_loss: 0.0913
# Epoch 18/20
# 92/92 - 1s - loss: 0.0839 - val_loss: 0.0948
# Epoch 19/20
# 92/92 - 1s - loss: 0.0826 - val_loss: 0.0900
# Epoch 20/20
# 92/92 - 1s - loss: 0.0800 - val_loss: 0.0823

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, batch_size=32, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 2s - loss: 0.1924 - val_loss: 0.1712
# Epoch 2/30
# 367/367 - 2s - loss: 0.1443 - val_loss: 0.1536
# Epoch 3/30
# 367/367 - 2s - loss: 0.1264 - val_loss: 0.1358
# Epoch 4/30
# 367/367 - 2s - loss: 0.1145 - val_loss: 0.1269
# Epoch 5/30
# 367/367 - 2s - loss: 0.1081 - val_loss: 0.1220
# Epoch 6/30
# 367/367 - 2s - loss: 0.1017 - val_loss: 0.1162
# Epoch 7/30
# 367/367 - 2s - loss: 0.0948 - val_loss: 0.1071
# Epoch 8/30
# 367/367 - 2s - loss: 0.0923 - val_loss: 0.1002
# Epoch 9/30
# 367/367 - 2s - loss: 0.0868 - val_loss: 0.1099
# Epoch 10/30
# 367/367 - 2s - loss: 0.0843 - val_loss: 0.0990
# Epoch 11/30
# 367/367 - 2s - loss: 0.0818 - val_loss: 0.0907
# Epoch 12/30
# 367/367 - 2s - loss: 0.0776 - val_loss: 0.0978
# Epoch 13/30
# 367/367 - 2s - loss: 0.0771 - val_loss: 0.0961
# Epoch 14/30
# 367/367 - 2s - loss: 0.0755 - val_loss: 0.0996
# Epoch 15/30
# 367/367 - 2s - loss: 0.0739 - val_loss: 0.0896
# Epoch 16/30
# 367/367 - 2s - loss: 0.0725 - val_loss: 0.0895
# Epoch 17/30
# 367/367 - 2s - loss: 0.0701 - val_loss: 0.1107
# Epoch 18/30
# 367/367 - 2s - loss: 0.0681 - val_loss: 0.0953
# Epoch 19/30
# 367/367 - 2s - loss: 0.0690 - val_loss: 0.1013
# Epoch 20/30
# 367/367 - 2s - loss: 0.0668 - val_loss: 0.0928
# Epoch 21/30
# 367/367 - 2s - loss: 0.0660 - val_loss: 0.0869
# Epoch 22/30
# 367/367 - 2s - loss: 0.0658 - val_loss: 0.1050
# Epoch 23/30
# 367/367 - 2s - loss: 0.0645 - val_loss: 0.1070
# Epoch 24/30
# 367/367 - 2s - loss: 0.0633 - val_loss: 0.1055
# Epoch 25/30
# 367/367 - 2s - loss: 0.0626 - val_loss: 0.0917
# Epoch 26/30
# 367/367 - 2s - loss: 0.0624 - val_loss: 0.0861
# Epoch 27/30
# 367/367 - 2s - loss: 0.0603 - val_loss: 0.0989
# Epoch 28/30
# 367/367 - 2s - loss: 0.0615 - val_loss: 0.1014
# Epoch 29/30
# 367/367 - 2s - loss: 0.0599 - val_loss: 0.0887
# Epoch 30/30
# 367/367 - 2s - loss: 0.0602 - val_loss: 0.0896

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_10 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 92/92 - 1s - loss: 0.2226 - val_loss: 0.1860
# Epoch 2/30
# 92/92 - 1s - loss: 0.1719 - val_loss: 0.1600
# Epoch 3/30
# 92/92 - 1s - loss: 0.1528 - val_loss: 0.1515
# Epoch 4/30
# 92/92 - 1s - loss: 0.1388 - val_loss: 0.1354
# Epoch 5/30
# 92/92 - 1s - loss: 0.1314 - val_loss: 0.1385
# Epoch 6/30
# 92/92 - 1s - loss: 0.1247 - val_loss: 0.1391
# Epoch 7/30
# 92/92 - 1s - loss: 0.1185 - val_loss: 0.1251
# Epoch 8/30
# 92/92 - 1s - loss: 0.1176 - val_loss: 0.1241
# Epoch 9/30
# 92/92 - 1s - loss: 0.1105 - val_loss: 0.1277
# Epoch 10/30
# 92/92 - 1s - loss: 0.1043 - val_loss: 0.1194
# Epoch 11/30
# 92/92 - 1s - loss: 0.1035 - val_loss: 0.1039
# Epoch 12/30
# 92/92 - 1s - loss: 0.1000 - val_loss: 0.1023
# Epoch 13/30
# 92/92 - 1s - loss: 0.0976 - val_loss: 0.1052
# Epoch 14/30
# 92/92 - 1s - loss: 0.0939 - val_loss: 0.1101
# Epoch 15/30
# 92/92 - 1s - loss: 0.0925 - val_loss: 0.1033
# Epoch 16/30
# 92/92 - 1s - loss: 0.0898 - val_loss: 0.0961
# Epoch 17/30
# 92/92 - 1s - loss: 0.0870 - val_loss: 0.0898
# Epoch 18/30
# 92/92 - 1s - loss: 0.0847 - val_loss: 0.0956
# Epoch 19/30
# 92/92 - 1s - loss: 0.0829 - val_loss: 0.0934
# Epoch 20/30
# 92/92 - 1s - loss: 0.0825 - val_loss: 0.1018
# Epoch 21/30
# 92/92 - 1s - loss: 0.0812 - val_loss: 0.0898
# Epoch 22/30
# 92/92 - 1s - loss: 0.0774 - val_loss: 0.0993
# Epoch 23/30
# 92/92 - 1s - loss: 0.0788 - val_loss: 0.0924
# Epoch 24/30
# 92/92 - 1s - loss: 0.0746 - val_loss: 0.0964
# Epoch 25/30
# 92/92 - 1s - loss: 0.0742 - val_loss: 0.0967
# Epoch 26/30
# 92/92 - 1s - loss: 0.0728 - val_loss: 0.0902
# Epoch 27/30
# 92/92 - 1s - loss: 0.0707 - val_loss: 0.0867
# Epoch 28/30
# 92/92 - 1s - loss: 0.0729 - val_loss: 0.0920
# Epoch 29/30
# 92/92 - 1s - loss: 0.0700 - val_loss: 0.0857
# Epoch 30/30
# 92/92 - 1s - loss: 0.0683 - val_loss: 0.1005

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_13 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 367/367 - 2s - loss: 0.1919 - val_loss: 0.1577
# Epoch 2/20
# 367/367 - 2s - loss: 0.1474 - val_loss: 0.1393
# Epoch 3/20
# 367/367 - 2s - loss: 0.1294 - val_loss: 0.1285
# Epoch 4/20
# 367/367 - 2s - loss: 0.1177 - val_loss: 0.1214
# Epoch 5/20
# 367/367 - 2s - loss: 0.1079 - val_loss: 0.1038
# Epoch 6/20
# 367/367 - 2s - loss: 0.0989 - val_loss: 0.0990
# Epoch 7/20
# 367/367 - 2s - loss: 0.0919 - val_loss: 0.0950
# Epoch 8/20
# 367/367 - 2s - loss: 0.0867 - val_loss: 0.0920
# Epoch 9/20
# 367/367 - 2s - loss: 0.0826 - val_loss: 0.0878
# Epoch 10/20
# 367/367 - 2s - loss: 0.0787 - val_loss: 0.0844
# Epoch 11/20
# 367/367 - 2s - loss: 0.0742 - val_loss: 0.0860
# Epoch 12/20
# 367/367 - 2s - loss: 0.0720 - val_loss: 0.0789
# Epoch 13/20
# 367/367 - 2s - loss: 0.0690 - val_loss: 0.0816
# Epoch 14/20
# 367/367 - 2s - loss: 0.0681 - val_loss: 0.0737
# Epoch 15/20
# 367/367 - 2s - loss: 0.0641 - val_loss: 0.0843
# Epoch 16/20
# 367/367 - 2s - loss: 0.0629 - val_loss: 0.0727
# Epoch 17/20
# 367/367 - 2s - loss: 0.0598 - val_loss: 0.0742
# Epoch 18/20
# 367/367 - 2s - loss: 0.0585 - val_loss: 0.0810
# Epoch 19/20
# 367/367 - 2s - loss: 0.0582 - val_loss: 0.0717
# Epoch 20/20
# 367/367 - 2s - loss: 0.0563 - val_loss: 0.0726

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 92/92 - 1s - loss: 0.2216 - val_loss: 0.1874
# Epoch 2/20
# 92/92 - 1s - loss: 0.1688 - val_loss: 0.1579
# Epoch 3/20
# 92/92 - 1s - loss: 0.1485 - val_loss: 0.1463
# Epoch 4/20
# 92/92 - 1s - loss: 0.1383 - val_loss: 0.1349
# Epoch 5/20
# 92/92 - 1s - loss: 0.1279 - val_loss: 0.1270
# Epoch 6/20
# 92/92 - 1s - loss: 0.1211 - val_loss: 0.1244
# Epoch 7/20
# 92/92 - 1s - loss: 0.1162 - val_loss: 0.1232
# Epoch 8/20
# 92/92 - 1s - loss: 0.1106 - val_loss: 0.1140
# Epoch 9/20
# 92/92 - 1s - loss: 0.1067 - val_loss: 0.1102
# Epoch 10/20
# 92/92 - 1s - loss: 0.1020 - val_loss: 0.1128
# Epoch 11/20
# 92/92 - 1s - loss: 0.0987 - val_loss: 0.1040
# Epoch 12/20
# 92/92 - 1s - loss: 0.0955 - val_loss: 0.1079
# Epoch 13/20
# 92/92 - 1s - loss: 0.0935 - val_loss: 0.1021
# Epoch 14/20
# 92/92 - 1s - loss: 0.0904 - val_loss: 0.1043
# Epoch 15/20
# 92/92 - 1s - loss: 0.0883 - val_loss: 0.1032
# Epoch 16/20
# 92/92 - 1s - loss: 0.0862 - val_loss: 0.1008
# Epoch 17/20
# 92/92 - 1s - loss: 0.0851 - val_loss: 0.1041
# Epoch 18/20
# 92/92 - 1s - loss: 0.0831 - val_loss: 0.0997
# Epoch 19/20
# 92/92 - 1s - loss: 0.0821 - val_loss: 0.0984
# Epoch 20/20
# 92/92 - 1s - loss: 0.0808 - val_loss: 0.0968

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_7 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_19 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 2s - loss: 0.1914 - val_loss: 0.1563
# Epoch 2/30
# 367/367 - 2s - loss: 0.1469 - val_loss: 0.1374
# Epoch 3/30
# 367/367 - 2s - loss: 0.1300 - val_loss: 0.1151
# Epoch 4/30
# 367/367 - 2s - loss: 0.1183 - val_loss: 0.1215
# Epoch 5/30
# 367/367 - 2s - loss: 0.1092 - val_loss: 0.1004
# Epoch 6/30
# 367/367 - 2s - loss: 0.0999 - val_loss: 0.0977
# Epoch 7/30
# 367/367 - 2s - loss: 0.0930 - val_loss: 0.0913
# Epoch 8/30
# 367/367 - 2s - loss: 0.0872 - val_loss: 0.0926
# Epoch 9/30
# 367/367 - 2s - loss: 0.0826 - val_loss: 0.0919
# Epoch 10/30
# 367/367 - 2s - loss: 0.0800 - val_loss: 0.0869
# Epoch 11/30
# 367/367 - 2s - loss: 0.0742 - val_loss: 0.0884
# Epoch 12/30
# 367/367 - 2s - loss: 0.0725 - val_loss: 0.0799
# Epoch 13/30
# 367/367 - 2s - loss: 0.0695 - val_loss: 0.0881
# Epoch 14/30
# 367/367 - 2s - loss: 0.0673 - val_loss: 0.0773
# Epoch 15/30
# 367/367 - 2s - loss: 0.0653 - val_loss: 0.0796
# Epoch 16/30
# 367/367 - 2s - loss: 0.0631 - val_loss: 0.0708
# Epoch 17/30
# 367/367 - 2s - loss: 0.0610 - val_loss: 0.0781
# Epoch 18/30
# 367/367 - 2s - loss: 0.0597 - val_loss: 0.0842
# Epoch 19/30
# 367/367 - 2s - loss: 0.0582 - val_loss: 0.0738
# Epoch 20/30
# 367/367 - 2s - loss: 0.0567 - val_loss: 0.0795
# Epoch 21/30
# 367/367 - 2s - loss: 0.0561 - val_loss: 0.0725
# Epoch 22/30
# 367/367 - 2s - loss: 0.0550 - val_loss: 0.0740
# Epoch 23/30
# 367/367 - 2s - loss: 0.0536 - val_loss: 0.0747
# Epoch 24/30
# 367/367 - 2s - loss: 0.0524 - val_loss: 0.0728
# Epoch 25/30
# 367/367 - 2s - loss: 0.0516 - val_loss: 0.0730
# Epoch 26/30
# 367/367 - 2s - loss: 0.0508 - val_loss: 0.0714
# Epoch 27/30
# 367/367 - 2s - loss: 0.0501 - val_loss: 0.0747
# Epoch 28/30
# 367/367 - 2s - loss: 0.0494 - val_loss: 0.0729
# Epoch 29/30
# 367/367 - 2s - loss: 0.0492 - val_loss: 0.0760
# Epoch 30/30
# 367/367 - 2s - loss: 0.0484 - val_loss: 0.0718

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_8 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_22 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 92/92 - 1s - loss: 0.2214 - val_loss: 0.1809
# Epoch 2/30
# 92/92 - 1s - loss: 0.1692 - val_loss: 0.1512
# Epoch 3/30
# 92/92 - 1s - loss: 0.1487 - val_loss: 0.1405
# Epoch 4/30
# 92/92 - 1s - loss: 0.1364 - val_loss: 0.1332
# Epoch 5/30
# 92/92 - 1s - loss: 0.1288 - val_loss: 0.1273
# Epoch 6/30
# 92/92 - 1s - loss: 0.1201 - val_loss: 0.1200
# Epoch 7/30
# 92/92 - 1s - loss: 0.1155 - val_loss: 0.1133
# Epoch 8/30
# 92/92 - 1s - loss: 0.1101 - val_loss: 0.1129
# Epoch 9/30
# 92/92 - 1s - loss: 0.1068 - val_loss: 0.1151
# Epoch 10/30
# 92/92 - 1s - loss: 0.1025 - val_loss: 0.1034
# Epoch 11/30
# 92/92 - 1s - loss: 0.0996 - val_loss: 0.1015
# Epoch 12/30
# 92/92 - 1s - loss: 0.0965 - val_loss: 0.1006
# Epoch 13/30
# 92/92 - 1s - loss: 0.0932 - val_loss: 0.0996
# Epoch 14/30
# 92/92 - 1s - loss: 0.0911 - val_loss: 0.0931
# Epoch 15/30
# 92/92 - 1s - loss: 0.0891 - val_loss: 0.0946
# Epoch 16/30
# 92/92 - 1s - loss: 0.0874 - val_loss: 0.0900
# Epoch 17/30
# 92/92 - 1s - loss: 0.0853 - val_loss: 0.0910
# Epoch 18/30
# 92/92 - 1s - loss: 0.0837 - val_loss: 0.0877
# Epoch 19/30
# 92/92 - 1s - loss: 0.0828 - val_loss: 0.0887
# Epoch 20/30
# 92/92 - 1s - loss: 0.0815 - val_loss: 0.0875
# Epoch 21/30
# 92/92 - 1s - loss: 0.0801 - val_loss: 0.0855
# Epoch 22/30
# 92/92 - 1s - loss: 0.0793 - val_loss: 0.0862
# Epoch 23/30
# 92/92 - 1s - loss: 0.0782 - val_loss: 0.0847
# Epoch 24/30
# 92/92 - 1s - loss: 0.0777 - val_loss: 0.0847
# Epoch 25/30
# 92/92 - 1s - loss: 0.0767 - val_loss: 0.0834
# Epoch 26/30
# 92/92 - 1s - loss: 0.0760 - val_loss: 0.0839
# Epoch 27/30
# 92/92 - 1s - loss: 0.0756 - val_loss: 0.0821
# Epoch 28/30
# 92/92 - 1s - loss: 0.0753 - val_loss: 0.0824
# Epoch 29/30
# 92/92 - 1s - loss: 0.0744 - val_loss: 0.0823
# Epoch 30/30
# 92/92 - 1s - loss: 0.0741 - val_loss: 0.0826

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['adam_20_32','adam_20_128','adam_30_32','adam_30_128','lr_20_32','lr_20_128','lr_30_32','lr_30_128'], loc='upper right')
#plt.xlim(0,50)
#plt.ylim(0.07,0.17)
#plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.07, 0.18, 0.02))
plt.savefig('Validation_Loss_for_doubt_5p.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['adam_20_32','adam_20_128','adam_30_32','adam_30_128','lr_20_32','lr_20_128','lr_30_32','lr_30_128'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.040,)
#plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.0, 0.23, 0.02))
plt.savefig('Training_Loss_for_doubt_5p.png', dpi=1200)
plt.show()
