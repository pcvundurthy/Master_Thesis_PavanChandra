# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm


input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam")
model.summary()
history_9 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense (Dense)                (None, 700)               28000
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 54s - loss: 0.0945 - val_loss: 0.1099
# Epoch 2/30
# 12456/12456 - 57s - loss: 0.0650 - val_loss: 0.1332
# Epoch 3/30
# 12456/12456 - 60s - loss: 0.0568 - val_loss: 0.1545
# Epoch 4/30
# 12456/12456 - 59s - loss: 0.0523 - val_loss: 0.1557
# Epoch 5/30
# 12456/12456 - 62s - loss: 0.0483 - val_loss: 0.1479
# Epoch 6/30
# 12456/12456 - 60s - loss: 0.0462 - val_loss: 0.1654
# Epoch 7/30
# 12456/12456 - 62s - loss: 0.0442 - val_loss: 0.1469
# Epoch 8/30
# 12456/12456 - 59s - loss: 0.0426 - val_loss: 0.1532
# Epoch 9/30
# 12456/12456 - 62s - loss: 0.0411 - val_loss: 0.1591
# Epoch 10/30
# 12456/12456 - 73s - loss: 0.0399 - val_loss: 0.1625
# Epoch 11/30
# 12456/12456 - 66s - loss: 0.0390 - val_loss: 0.1584
# Epoch 12/30
# 12456/12456 - 63s - loss: 0.0380 - val_loss: 0.1709
# Epoch 13/30
# 12456/12456 - 77s - loss: 0.0371 - val_loss: 0.1593
# Epoch 14/30
# 12456/12456 - 108s - loss: 0.0365 - val_loss: 0.1668
# Epoch 15/30
# 12456/12456 - 109s - loss: 0.0357 - val_loss: 0.1712
# Epoch 16/30
# 12456/12456 - 109s - loss: 0.0352 - val_loss: 0.1700
# Epoch 17/30
# 12456/12456 - 108s - loss: 0.0342 - val_loss: 0.1764
# Epoch 18/30
# 12456/12456 - 109s - loss: 0.0339 - val_loss: 0.1729
# Epoch 19/30
# 12456/12456 - 108s - loss: 0.0332 - val_loss: 0.1630
# Epoch 20/30
# 12456/12456 - 109s - loss: 0.0327 - val_loss: 0.1693
# Epoch 21/30
# 12456/12456 - 109s - loss: 0.0323 - val_loss: 0.1722
# Epoch 22/30
# 12456/12456 - 110s - loss: 0.0320 - val_loss: 0.1666
# Epoch 23/30
# 12456/12456 - 112s - loss: 0.0315 - val_loss: 0.1611
# Epoch 24/30
# 12456/12456 - 121s - loss: 0.0312 - val_loss: 0.1673
# Epoch 25/30
# 12456/12456 - 111s - loss: 0.0310 - val_loss: 0.1717
# Epoch 26/30
# 12456/12456 - 116s - loss: 0.0305 - val_loss: 0.1708
# Epoch 27/30
# 12456/12456 - 112s - loss: 0.0301 - val_loss: 0.1706
# Epoch 28/30
# 12456/12456 - 115s - loss: 0.0297 - val_loss: 0.1676
# Epoch 29/30
# 12456/12456 - 115s - loss: 0.0294 - val_loss: 0.1726
# Epoch 30/30
# 12456/12456 - 113s - loss: 0.0292 - val_loss: 0.1646

# %%
##for 0.1 lr
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate 0.1
#
opt = keras.optimizers.Adam(learning_rate=0.1)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               28000
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 150s - loss: 0.3500 - val_loss: 0.2907
# Epoch 2/30
# 12456/12456 - 145s - loss: 0.2892 - val_loss: 0.2880
# Epoch 3/30
# 12456/12456 - 110s - loss: 0.2892 - val_loss: 0.2865
# Epoch 4/30
# 12456/12456 - 118s - loss: 0.2893 - val_loss: 0.2894
# Epoch 5/30
# 12456/12456 - 173s - loss: 0.2893 - val_loss: 0.2881
# Epoch 6/30
# 12456/12456 - 178s - loss: 0.2892 - val_loss: 0.2911
# Epoch 7/30
# 12456/12456 - 176s - loss: 0.2892 - val_loss: 0.2899
# Epoch 8/30
# 12456/12456 - 169s - loss: 0.2892 - val_loss: 0.2880
# Epoch 9/30
# 12456/12456 - 165s - loss: 0.2894 - val_loss: 0.2932
# Epoch 10/30
# 12456/12456 - 163s - loss: 0.2892 - val_loss: 0.2872
# Epoch 11/30
# 12456/12456 - 124s - loss: 0.2892 - val_loss: 0.2908
# Epoch 12/30
# 12456/12456 - 131s - loss: 0.2892 - val_loss: 0.2894
# Epoch 13/30
# 12456/12456 - 105s - loss: 0.2893 - val_loss: 0.2875
# Epoch 14/30
# 12456/12456 - 113s - loss: 0.2893 - val_loss: 0.2919
# Epoch 15/30
# 12456/12456 - 109s - loss: 0.2893 - val_loss: 0.2859
# Epoch 16/30
# 12456/12456 - 105s - loss: 0.2891 - val_loss: 0.2874
# Epoch 17/30
# 12456/12456 - 106s - loss: 0.2893 - val_loss: 0.2867
# Epoch 18/30
# 12456/12456 - 107s - loss: 0.2893 - val_loss: 0.2910
# Epoch 19/30
# 12456/12456 - 105s - loss: 0.2893 - val_loss: 0.2875
# Epoch 20/30
# 12456/12456 - 114s - loss: 0.2892 - val_loss: 0.2909
# Epoch 21/30
# 12456/12456 - 116s - loss: 0.2891 - val_loss: 0.2887
# Epoch 22/30
# 12456/12456 - 113s - loss: 0.2892 - val_loss: 0.2883
# Epoch 23/30
# 12456/12456 - 117s - loss: 0.2893 - val_loss: 0.2883
# Epoch 24/30
# 12456/12456 - 118s - loss: 0.2892 - val_loss: 0.2877
# Epoch 25/30
# 12456/12456 - 116s - loss: 0.2893 - val_loss: 0.2902
# Epoch 26/30
# 12456/12456 - 120s - loss: 0.2892 - val_loss: 0.2902
# Epoch 27/30
# 12456/12456 - 124s - loss: 0.2892 - val_loss: 0.2886
# Epoch 28/30
# 12456/12456 - 121s - loss: 0.2893 - val_loss: 0.2880
# Epoch 29/30
# 12456/12456 - 116s - loss: 0.2892 - val_loss: 0.2875
# Epoch 30/30
# 12456/12456 - 116s - loss: 0.2892 - val_loss: 0.2911

# %%
##for 0.01
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               28000
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 116s - loss: 0.1150 - val_loss: 0.0973
# Epoch 2/30
# 12456/12456 - 117s - loss: 0.0964 - val_loss: 0.1017
# Epoch 3/30
# 12456/12456 - 120s - loss: 0.0917 - val_loss: 0.1060
# Epoch 4/30
# 12456/12456 - 117s - loss: 0.0890 - val_loss: 0.0914
# Epoch 5/30
# 12456/12456 - 117s - loss: 0.0864 - val_loss: 0.1010
# Epoch 6/30
# 12456/12456 - 116s - loss: 0.0850 - val_loss: 0.0954
# Epoch 7/30
# 12456/12456 - 116s - loss: 0.0837 - val_loss: 0.1042
# Epoch 8/30
# 12456/12456 - 118s - loss: 0.0829 - val_loss: 0.1065
# Epoch 9/30
# 12456/12456 - 115s - loss: 0.0825 - val_loss: 0.0985
# Epoch 10/30
# 12456/12456 - 113s - loss: 0.0817 - val_loss: 0.1157
# Epoch 11/30
# 12456/12456 - 99s - loss: 0.0814 - val_loss: 0.1027
# Epoch 12/30
# 12456/12456 - 65s - loss: 0.0812 - val_loss: 0.1094
# Epoch 13/30
# 12456/12456 - 125s - loss: 0.0807 - val_loss: 0.1066
# Epoch 14/30
# 12456/12456 - 124s - loss: 0.0808 - val_loss: 0.1131
# Epoch 15/30
# 12456/12456 - 125s - loss: 0.0806 - val_loss: 0.1094
# Epoch 16/30
# 12456/12456 - 125s - loss: 0.0803 - val_loss: 0.1040
# Epoch 17/30
# 12456/12456 - 124s - loss: 0.0806 - val_loss: 0.1192
# Epoch 18/30
# 12456/12456 - 122s - loss: 0.0805 - val_loss: 0.1078
# Epoch 19/30
# 12456/12456 - 131s - loss: 0.0801 - val_loss: 0.1146
# Epoch 20/30
# 12456/12456 - 129s - loss: 0.0800 - val_loss: 0.1184
# Epoch 21/30
# 12456/12456 - 121s - loss: 0.0799 - val_loss: 0.1228
# Epoch 22/30
# 12456/12456 - 85s - loss: 0.0801 - val_loss: 0.1181
# Epoch 23/30
# 12456/12456 - 115s - loss: 0.0797 - val_loss: 0.1199
# Epoch 24/30
# 12456/12456 - 119s - loss: 0.0799 - val_loss: 0.1208
# Epoch 25/30
# 12456/12456 - 139s - loss: 0.0798 - val_loss: 0.1116
# Epoch 26/30
# 12456/12456 - 150s - loss: 0.0799 - val_loss: 0.1153
# Epoch 27/30
# 12456/12456 - 148s - loss: 0.0798 - val_loss: 0.1196
# Epoch 28/30
# 12456/12456 - 149s - loss: 0.0797 - val_loss: 0.1107
# Epoch 29/30
# 12456/12456 - 147s - loss: 0.0799 - val_loss: 0.1204
# Epoch 30/30
# 12456/12456 - 146s - loss: 0.0791 - val_loss: 0.1173

# %%
##for 0.001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 700)               28000
# _________________________________________________________________
# dense_10 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 146s - loss: 0.0948 - val_loss: 0.0885
# Epoch 2/30
# 12456/12456 - 145s - loss: 0.0649 - val_loss: 0.0886
# Epoch 3/30
# 12456/12456 - 115s - loss: 0.0563 - val_loss: 0.1151
# Epoch 4/30
# 12456/12456 - 97s - loss: 0.0517 - val_loss: 0.1094
# Epoch 5/30
# 12456/12456 - 103s - loss: 0.0484 - val_loss: 0.1340
# Epoch 6/30
# 12456/12456 - 113s - loss: 0.0461 - val_loss: 0.1263
# Epoch 7/30
# 12456/12456 - 119s - loss: 0.0440 - val_loss: 0.1093
# Epoch 8/30
# 12456/12456 - 119s - loss: 0.0426 - val_loss: 0.1081
# Epoch 9/30
# 12456/12456 - 111s - loss: 0.0410 - val_loss: 0.1194
# Epoch 10/30
# 12456/12456 - 111s - loss: 0.0398 - val_loss: 0.1343
# Epoch 11/30
# 12456/12456 - 114s - loss: 0.0389 - val_loss: 0.1178
# Epoch 12/30
# 12456/12456 - 98s - loss: 0.0378 - val_loss: 0.1100
# Epoch 13/30
# 12456/12456 - 67s - loss: 0.0369 - val_loss: 0.1186
# Epoch 14/30
# 12456/12456 - 62s - loss: 0.0359 - val_loss: 0.1343
# Epoch 15/30
# 12456/12456 - 120s - loss: 0.0354 - val_loss: 0.1336
# Epoch 16/30
# 12456/12456 - 121s - loss: 0.0344 - val_loss: 0.1305
# Epoch 17/30
# 12456/12456 - 119s - loss: 0.0342 - val_loss: 0.1415
# Epoch 18/30
# 12456/12456 - 121s - loss: 0.0337 - val_loss: 0.1249
# Epoch 19/30
# 12456/12456 - 122s - loss: 0.0331 - val_loss: 0.1341
# Epoch 20/30
# 12456/12456 - 124s - loss: 0.0324 - val_loss: 0.1254
# Epoch 21/30
# 12456/12456 - 84s - loss: 0.0318 - val_loss: 0.1464
# Epoch 22/30
# 12456/12456 - 113s - loss: 0.0315 - val_loss: 0.1274
# Epoch 23/30
# 12456/12456 - 115s - loss: 0.0309 - val_loss: 0.1456
# Epoch 24/30
# 12456/12456 - 123s - loss: 0.0307 - val_loss: 0.1371
# Epoch 25/30
# 12456/12456 - 110s - loss: 0.0304 - val_loss: 0.1332
# Epoch 26/30
# 12456/12456 - 113s - loss: 0.0299 - val_loss: 0.1435
# Epoch 27/30
# 12456/12456 - 108s - loss: 0.0295 - val_loss: 0.1428
# Epoch 28/30
# 12456/12456 - 108s - loss: 0.0293 - val_loss: 0.1342
# Epoch 29/30
# 12456/12456 - 119s - loss: 0.0290 - val_loss: 0.1509
# Epoch 30/30
# 12456/12456 - 121s - loss: 0.0287 - val_loss: 0.1350

# %%
##for 0.0001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_13 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 108s - loss: 0.1235 - val_loss: 0.0950
# Epoch 2/30
# 12456/12456 - 108s - loss: 0.0789 - val_loss: 0.0821
# Epoch 3/30
# 12456/12456 - 109s - loss: 0.0619 - val_loss: 0.0798
# Epoch 4/30
# 12456/12456 - 109s - loss: 0.0535 - val_loss: 0.0833
# Epoch 5/30
# 12456/12456 - 107s - loss: 0.0483 - val_loss: 0.0831
# Epoch 6/30
# 12456/12456 - 109s - loss: 0.0445 - val_loss: 0.0849
# Epoch 7/30
# 12456/12456 - 108s - loss: 0.0418 - val_loss: 0.0944
# Epoch 8/30
# 12456/12456 - 109s - loss: 0.0396 - val_loss: 0.0940
# Epoch 9/30
# 12456/12456 - 108s - loss: 0.0379 - val_loss: 0.0959
# Epoch 10/30
# 12456/12456 - 110s - loss: 0.0366 - val_loss: 0.1031
# Epoch 11/30
# 12456/12456 - 113s - loss: 0.0354 - val_loss: 0.0919
# Epoch 12/30
# 12456/12456 - 112s - loss: 0.0343 - val_loss: 0.0927
# Epoch 13/30
# 12456/12456 - 112s - loss: 0.0335 - val_loss: 0.1055
# Epoch 14/30
# 12456/12456 - 113s - loss: 0.0327 - val_loss: 0.1024
# Epoch 15/30
# 12456/12456 - 130s - loss: 0.0320 - val_loss: 0.0967
# Epoch 16/30
# 12456/12456 - 159s - loss: 0.0312 - val_loss: 0.0983
# Epoch 17/30
# 12456/12456 - 158s - loss: 0.0305 - val_loss: 0.0972
# Epoch 18/30
# 12456/12456 - 158s - loss: 0.0300 - val_loss: 0.1030
# Epoch 19/30
# 12456/12456 - 163s - loss: 0.0294 - val_loss: 0.1008
# Epoch 20/30
# 12456/12456 - 162s - loss: 0.0289 - val_loss: 0.1115
# Epoch 21/30
# 12456/12456 - 139s - loss: 0.0285 - val_loss: 0.1000
# Epoch 22/30
# 12456/12456 - 153s - loss: 0.0279 - val_loss: 0.0979
# Epoch 23/30
# 12456/12456 - 178s - loss: 0.0276 - val_loss: 0.1022
# Epoch 24/30
# 12456/12456 - 173s - loss: 0.0272 - val_loss: 0.1059
# Epoch 25/30
# 12456/12456 - 174s - loss: 0.0267 - val_loss: 0.0983
# Epoch 26/30
# 12456/12456 - 160s - loss: 0.0264 - val_loss: 0.1019
# Epoch 27/30
# 12456/12456 - 109s - loss: 0.0260 - val_loss: 0.1062
# Epoch 28/30
# 12456/12456 - 109s - loss: 0.0257 - val_loss: 0.1024
# Epoch 29/30
# 12456/12456 - 112s - loss: 0.0255 - val_loss: 0.1087
# Epoch 30/30
# 12456/12456 - 112s - loss: 0.0252 - val_loss: 0.1091

# %%
##for lr scheduler 5epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 159s - loss: 0.0939 - val_loss: 0.1008
# Epoch 2/30
# 12456/12456 - 111s - loss: 0.0640 - val_loss: 0.1257
# Epoch 3/30
# 12456/12456 - 113s - loss: 0.0558 - val_loss: 0.1107
# Epoch 4/30
# 12456/12456 - 117s - loss: 0.0506 - val_loss: 0.1242
# Epoch 5/30
# 12456/12456 - 116s - loss: 0.0477 - val_loss: 0.1336
# Epoch 6/30
# 12456/12456 - 118s - loss: 0.0436 - val_loss: 0.1277
# Epoch 7/30
# 12456/12456 - 116s - loss: 0.0399 - val_loss: 0.1528
# Epoch 8/30
# 12456/12456 - 112s - loss: 0.0369 - val_loss: 0.1411
# Epoch 9/30
# 12456/12456 - 109s - loss: 0.0346 - val_loss: 0.1245
# Epoch 10/30
# 12456/12456 - 65s - loss: 0.0324 - val_loss: 0.1354
# Epoch 11/30
# 12456/12456 - 59s - loss: 0.0305 - val_loss: 0.1451
# Epoch 12/30
# 12456/12456 - 59s - loss: 0.0290 - val_loss: 0.1425
# Epoch 13/30
# 12456/12456 - 58s - loss: 0.0273 - val_loss: 0.1473
# Epoch 14/30
# 12456/12456 - 60s - loss: 0.0260 - val_loss: 0.1538
# Epoch 15/30
# 12456/12456 - 58s - loss: 0.0248 - val_loss: 0.1537
# Epoch 16/30
# 12456/12456 - 59s - loss: 0.0236 - val_loss: 0.1614
# Epoch 17/30
# 12456/12456 - 63s - loss: 0.0227 - val_loss: 0.1535
# Epoch 18/30
# 12456/12456 - 58s - loss: 0.0217 - val_loss: 0.1596
# Epoch 19/30
# 12456/12456 - 57s - loss: 0.0209 - val_loss: 0.1574
# Epoch 20/30
# 12456/12456 - 57s - loss: 0.0201 - val_loss: 0.1601
# Epoch 21/30
# 12456/12456 - 57s - loss: 0.0195 - val_loss: 0.1628
# Epoch 22/30
# 12456/12456 - 57s - loss: 0.0189 - val_loss: 0.1615
# Epoch 23/30
# 12456/12456 - 58s - loss: 0.0182 - val_loss: 0.1686
# Epoch 24/30
# 12456/12456 - 56s - loss: 0.0177 - val_loss: 0.1647
# Epoch 25/30
# 12456/12456 - 57s - loss: 0.0172 - val_loss: 0.1637
# Epoch 26/30
# 12456/12456 - 57s - loss: 0.0167 - val_loss: 0.1659
# Epoch 27/30
# 12456/12456 - 57s - loss: 0.0164 - val_loss: 0.1656
# Epoch 28/30
# 12456/12456 - 57s - loss: 0.0160 - val_loss: 0.1660
# Epoch 29/30
# 12456/12456 - 57s - loss: 0.0157 - val_loss: 0.1671
# Epoch 30/30
# 12456/12456 - 62s - loss: 0.0154 - val_loss: 0.1679

# %%
##for for lr scheduler 10epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_19 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 69s - loss: 0.0937 - val_loss: 0.1126
# Epoch 2/30
# 12456/12456 - 72s - loss: 0.0637 - val_loss: 0.1332
# Epoch 3/30
# 12456/12456 - 67s - loss: 0.0556 - val_loss: 0.1433
# Epoch 4/30
# 12456/12456 - 68s - loss: 0.0506 - val_loss: 0.1275
# Epoch 5/30
# 12456/12456 - 65s - loss: 0.0473 - val_loss: 0.1402
# Epoch 6/30
# 12456/12456 - 62s - loss: 0.0448 - val_loss: 0.1618
# Epoch 7/30
# 12456/12456 - 59s - loss: 0.0431 - val_loss: 0.1468
# Epoch 8/30
# 12456/12456 - 58s - loss: 0.0415 - val_loss: 0.1442
# Epoch 9/30
# 12456/12456 - 59s - loss: 0.0401 - val_loss: 0.1430
# Epoch 10/30
# 12456/12456 - 58s - loss: 0.0388 - val_loss: 0.1447
# Epoch 11/30
# 12456/12456 - 58s - loss: 0.0362 - val_loss: 0.1520
# Epoch 12/30
# 12456/12456 - 60s - loss: 0.0337 - val_loss: 0.1670
# Epoch 13/30
# 12456/12456 - 57s - loss: 0.0317 - val_loss: 0.1589
# Epoch 14/30
# 12456/12456 - 58s - loss: 0.0297 - val_loss: 0.1636
# Epoch 15/30
# 12456/12456 - 59s - loss: 0.0281 - val_loss: 0.1610
# Epoch 16/30
# 12456/12456 - 59s - loss: 0.0265 - val_loss: 0.1691
# Epoch 17/30
# 12456/12456 - 57s - loss: 0.0253 - val_loss: 0.1652
# Epoch 18/30
# 12456/12456 - 58s - loss: 0.0239 - val_loss: 0.1726
# Epoch 19/30
# 12456/12456 - 57s - loss: 0.0230 - val_loss: 0.1761
# Epoch 20/30
# 12456/12456 - 59s - loss: 0.0218 - val_loss: 0.1688
# Epoch 21/30
# 12456/12456 - 57s - loss: 0.0210 - val_loss: 0.1738
# Epoch 22/30
# 12456/12456 - 57s - loss: 0.0201 - val_loss: 0.1783
# Epoch 23/30
# 12456/12456 - 57s - loss: 0.0194 - val_loss: 0.1773
# Epoch 24/30
# 12456/12456 - 61s - loss: 0.0187 - val_loss: 0.1766
# Epoch 25/30
# 12456/12456 - 62s - loss: 0.0180 - val_loss: 0.1765
# Epoch 26/30
# 12456/12456 - 58s - loss: 0.0175 - val_loss: 0.1772
# Epoch 27/30
# 12456/12456 - 57s - loss: 0.0169 - val_loss: 0.1757
# Epoch 28/30
# 12456/12456 - 56s - loss: 0.0165 - val_loss: 0.1774
# Epoch 29/30
# 12456/12456 - 58s - loss: 0.0160 - val_loss: 0.1774
# Epoch 30/30
# 12456/12456 - 56s - loss: 0.0156 - val_loss: 0.1797

# %%
##for 7p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 15:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_7 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_22 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 58s - loss: 0.0928 - val_loss: 0.1271
# Epoch 2/30
# 12456/12456 - 56s - loss: 0.0634 - val_loss: 0.1761
# Epoch 3/30
# 12456/12456 - 57s - loss: 0.0554 - val_loss: 0.1665
# Epoch 4/30
# 12456/12456 - 58s - loss: 0.0505 - val_loss: 0.1671
# Epoch 5/30
# 12456/12456 - 58s - loss: 0.0477 - val_loss: 0.1748
# Epoch 6/30
# 12456/12456 - 57s - loss: 0.0450 - val_loss: 0.1773
# Epoch 7/30
# 12456/12456 - 57s - loss: 0.0432 - val_loss: 0.1811
# Epoch 8/30
# 12456/12456 - 57s - loss: 0.0412 - val_loss: 0.1813
# Epoch 9/30
# 12456/12456 - 56s - loss: 0.0400 - val_loss: 0.1824
# Epoch 10/30
# 12456/12456 - 67s - loss: 0.0392 - val_loss: 0.1874
# Epoch 11/30
# 12456/12456 - 107s - loss: 0.0380 - val_loss: 0.1786
# Epoch 12/30
# 12456/12456 - 106s - loss: 0.0371 - val_loss: 0.1825
# Epoch 13/30
# 12456/12456 - 109s - loss: 0.0361 - val_loss: 0.1953
# Epoch 14/30
# 12456/12456 - 110s - loss: 0.0352 - val_loss: 0.1744
# Epoch 15/30
# 12456/12456 - 103s - loss: 0.0346 - val_loss: 0.1860
# Epoch 16/30
# 12456/12456 - 106s - loss: 0.0324 - val_loss: 0.1989
# Epoch 17/30
# 12456/12456 - 107s - loss: 0.0305 - val_loss: 0.1911
# Epoch 18/30
# 12456/12456 - 108s - loss: 0.0285 - val_loss: 0.1909
# Epoch 19/30
# 12456/12456 - 109s - loss: 0.0270 - val_loss: 0.1923
# Epoch 20/30
# 12456/12456 - 107s - loss: 0.0255 - val_loss: 0.1998
# Epoch 21/30
# 12456/12456 - 80s - loss: 0.0241 - val_loss: 0.1940
# Epoch 22/30
# 12456/12456 - 53s - loss: 0.0229 - val_loss: 0.2039
# Epoch 23/30
# 12456/12456 - 55s - loss: 0.0219 - val_loss: 0.2034
# Epoch 24/30
# 12456/12456 - 54s - loss: 0.0209 - val_loss: 0.2062
# Epoch 25/30
# 12456/12456 - 54s - loss: 0.0200 - val_loss: 0.2074
# Epoch 26/30
# 12456/12456 - 55s - loss: 0.0193 - val_loss: 0.2055
# Epoch 27/30
# 12456/12456 - 55s - loss: 0.0184 - val_loss: 0.2091
# Epoch 28/30
# 12456/12456 - 55s - loss: 0.0178 - val_loss: 0.2060
# Epoch 29/30
# 12456/12456 - 55s - loss: 0.0171 - val_loss: 0.2139
# Epoch 30/30
# 12456/12456 - 56s - loss: 0.0166 - val_loss: 0.2088

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_8 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.95577278  0.29018906 -0.05968228 -0.95285668  0.28523687 -0.06230832
#   -0.96507965  0.29320504 -0.06235831 -0.96670822  0.29785939 -0.0581769
#   -0.95759521  0.29439365 -0.05642046 -0.94805721  0.28787829 -0.05719368
#   -0.94535261  0.28357395 -0.05919212 -0.95782091  0.28945862 -0.06161459
#   -0.96248066  0.2937159  -0.06021506 -0.95998563  0.29410383 -0.05824146
#   -0.95376963  0.2907841  -0.05787685 -0.94965628  0.28714094 -0.0588126
#   -0.95126099  0.28626837 -0.06051846]
#  [-0.95377151  0.28666443 -0.06167502 -0.95004612  0.28130342 -0.06354794
#   -0.96300077  0.28914703 -0.06501411 -0.96566287  0.29459503 -0.06124983
#   -0.95637869  0.29142416 -0.05883111 -0.9461804   0.28480131 -0.0587187
#   -0.94288035  0.28023559 -0.06009021 -0.95548305  0.28558049 -0.06358238
#   -0.96074716  0.29007443 -0.06280472 -0.95853547  0.29082239 -0.06074648
#   -0.9520524   0.28757402 -0.05986261 -0.94751114  0.28380035 -0.06028608
#   -0.9488063   0.28264135 -0.06190161]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 39) (398580, 7) training data size
# (132861, 39) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 39)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_25 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_26 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 56s - loss: 0.0949 - val_loss: 0.1004
# Epoch 2/30
# 12456/12456 - 56s - loss: 0.0647 - val_loss: 0.1012
# Epoch 3/30
# 12456/12456 - 56s - loss: 0.0562 - val_loss: 0.1317
# Epoch 4/30
# 12456/12456 - 57s - loss: 0.0511 - val_loss: 0.1145
# Epoch 5/30
# 12456/12456 - 56s - loss: 0.0480 - val_loss: 0.1217
# Epoch 6/30
# 12456/12456 - 56s - loss: 0.0456 - val_loss: 0.1247
# Epoch 7/30
# 12456/12456 - 57s - loss: 0.0434 - val_loss: 0.1337
# Epoch 8/30
# 12456/12456 - 56s - loss: 0.0418 - val_loss: 0.1189
# Epoch 9/30
# 12456/12456 - 58s - loss: 0.0402 - val_loss: 0.1383
# Epoch 10/30
# 12456/12456 - 57s - loss: 0.0393 - val_loss: 0.1308
# Epoch 11/30
# 12456/12456 - 57s - loss: 0.0382 - val_loss: 0.1342
# Epoch 12/30
# 12456/12456 - 57s - loss: 0.0371 - val_loss: 0.1370
# Epoch 13/30
# 12456/12456 - 57s - loss: 0.0364 - val_loss: 0.1350
# Epoch 14/30
# 12456/12456 - 57s - loss: 0.0356 - val_loss: 0.1374
# Epoch 15/30
# 12456/12456 - 56s - loss: 0.0349 - val_loss: 0.1310
# Epoch 16/30
# 12456/12456 - 58s - loss: 0.0340 - val_loss: 0.1451
# Epoch 17/30
# 12456/12456 - 59s - loss: 0.0336 - val_loss: 0.1409
# Epoch 18/30
# 12456/12456 - 59s - loss: 0.0330 - val_loss: 0.1360
# Epoch 19/30
# 12456/12456 - 57s - loss: 0.0325 - val_loss: 0.1379
# Epoch 20/30
# 12456/12456 - 58s - loss: 0.0319 - val_loss: 0.1481
# Epoch 21/30
# 12456/12456 - 62s - loss: 0.0301 - val_loss: 0.1287
# Epoch 22/30
# 12456/12456 - 61s - loss: 0.0283 - val_loss: 0.1426
# Epoch 23/30
# 12456/12456 - 63s - loss: 0.0266 - val_loss: 0.1457
# Epoch 24/30
# 12456/12456 - 64s - loss: 0.0252 - val_loss: 0.1438
# Epoch 25/30
# 12456/12456 - 63s - loss: 0.0240 - val_loss: 0.1459
# Epoch 26/30
# 12456/12456 - 63s - loss: 0.0228 - val_loss: 0.1508
# Epoch 27/30
# 12456/12456 - 64s - loss: 0.0217 - val_loss: 0.1546
# Epoch 28/30
# 12456/12456 - 63s - loss: 0.0207 - val_loss: 0.1459
# Epoch 29/30
# 12456/12456 - 62s - loss: 0.0198 - val_loss: 0.1544
# Epoch 30/30
# 12456/12456 - 66s - loss: 0.0190 - val_loss: 0.1523

# %%
#plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#lgd=plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.06,0.25)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.06, 0.25, 0.02))
plt.savefig('Validation_Loss_for_lr_hex_9p.png', dpi=1200)
plt.show()

# %%
#plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.04,0.25)
plt.xticks(np.arange(0.0, 31, 2))
plt.yticks(np.arange(0.04, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_hex_9p.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['lr=0.1','lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.05,)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.05, 0.31, 0.05))
plt.savefig('Validation_Loss_for_lr_1_hex_9p.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.1','lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.0,)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_1_hex_9p.png', dpi=1200)
plt.show()
