# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm


input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam")
model.summary()
history_9 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_27 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_28 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_29 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 5s - loss: 0.1839 - val_loss: 0.1647
# Epoch 2/30
# 352/352 - 3s - loss: 0.1408 - val_loss: 0.1447
# Epoch 3/30
# 352/352 - 3s - loss: 0.1192 - val_loss: 0.1237
# Epoch 4/30
# 352/352 - 3s - loss: 0.1050 - val_loss: 0.1225
# Epoch 5/30
# 352/352 - 4s - loss: 0.0921 - val_loss: 0.1107
# Epoch 6/30
# 352/352 - 3s - loss: 0.0863 - val_loss: 0.1068
# Epoch 7/30
# 352/352 - 4s - loss: 0.0788 - val_loss: 0.1015
# Epoch 8/30
# 352/352 - 3s - loss: 0.0750 - val_loss: 0.1151
# Epoch 9/30
# 352/352 - 3s - loss: 0.0715 - val_loss: 0.1128
# Epoch 10/30
# 352/352 - 3s - loss: 0.0683 - val_loss: 0.1008
# Epoch 11/30
# 352/352 - 3s - loss: 0.0644 - val_loss: 0.0978
# Epoch 12/30
# 352/352 - 3s - loss: 0.0634 - val_loss: 0.1099
# Epoch 13/30
# 352/352 - 4s - loss: 0.0609 - val_loss: 0.1041
# Epoch 14/30
# 352/352 - 3s - loss: 0.0588 - val_loss: 0.0938
# Epoch 15/30
# 352/352 - 3s - loss: 0.0579 - val_loss: 0.1103
# Epoch 16/30
# 352/352 - 3s - loss: 0.0574 - val_loss: 0.0973
# Epoch 17/30
# 352/352 - 3s - loss: 0.0553 - val_loss: 0.1020
# Epoch 18/30
# 352/352 - 3s - loss: 0.0554 - val_loss: 0.0895
# Epoch 19/30
# 352/352 - 3s - loss: 0.0540 - val_loss: 0.0947
# Epoch 20/30
# 352/352 - 3s - loss: 0.0530 - val_loss: 0.1032
# Epoch 21/30
# 352/352 - 2s - loss: 0.0512 - val_loss: 0.0978
# Epoch 22/30
# 352/352 - 3s - loss: 0.0519 - val_loss: 0.0945
# Epoch 23/30
# 352/352 - 3s - loss: 0.0509 - val_loss: 0.0925
# Epoch 24/30
# 352/352 - 3s - loss: 0.0502 - val_loss: 0.0973
# Epoch 25/30
# 352/352 - 3s - loss: 0.0491 - val_loss: 0.0859
# Epoch 26/30
# 352/352 - 3s - loss: 0.0483 - val_loss: 0.0813
# Epoch 27/30
# 352/352 - 3s - loss: 0.0467 - val_loss: 0.0890
# Epoch 28/30
# 352/352 - 3s - loss: 0.0477 - val_loss: 0.0940
# Epoch 29/30
# 352/352 - 4s - loss: 0.0463 - val_loss: 0.0951
# Epoch 30/30
# 352/352 - 4s - loss: 0.0468 - val_loss: 0.0813

# %%
##for 0.1 lr
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate 0.1
#
opt = keras.optimizers.Adam(learning_rate=0.1)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_31 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_32 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 3s - loss: 2.7101 - val_loss: 0.2969
# Epoch 2/30
# 352/352 - 2s - loss: 0.2966 - val_loss: 0.2970
# Epoch 3/30
# 352/352 - 3s - loss: 0.2966 - val_loss: 0.2970
# Epoch 4/30
# 352/352 - 3s - loss: 0.2965 - val_loss: 0.2946
# Epoch 5/30
# 352/352 - 3s - loss: 0.2959 - val_loss: 0.2957
# Epoch 6/30
# 352/352 - 3s - loss: 0.2972 - val_loss: 0.2970
# Epoch 7/30
# 352/352 - 3s - loss: 0.2961 - val_loss: 0.3019
# Epoch 8/30
# 352/352 - 3s - loss: 0.2970 - val_loss: 0.2963
# Epoch 9/30
# 352/352 - 3s - loss: 0.2968 - val_loss: 0.2975
# Epoch 10/30
# 352/352 - 3s - loss: 0.2974 - val_loss: 0.2965
# Epoch 11/30
# 352/352 - 3s - loss: 0.2960 - val_loss: 0.2959
# Epoch 12/30
# 352/352 - 3s - loss: 0.2963 - val_loss: 0.2958
# Epoch 13/30
# 352/352 - 4s - loss: 0.2960 - val_loss: 0.3011
# Epoch 14/30
# 352/352 - 3s - loss: 0.2967 - val_loss: 0.2962
# Epoch 15/30
# 352/352 - 4s - loss: 0.2967 - val_loss: 0.2969
# Epoch 16/30
# 352/352 - 3s - loss: 0.2966 - val_loss: 0.2979
# Epoch 17/30
# 352/352 - 3s - loss: 0.2963 - val_loss: 0.2953
# Epoch 18/30
# 352/352 - 3s - loss: 0.2970 - val_loss: 0.3030
# Epoch 19/30
# 352/352 - 3s - loss: 0.2969 - val_loss: 0.2941
# Epoch 20/30
# 352/352 - 4s - loss: 0.2962 - val_loss: 0.2993
# Epoch 21/30
# 352/352 - 4s - loss: 0.2972 - val_loss: 0.2938
# Epoch 22/30
# 352/352 - 4s - loss: 0.2963 - val_loss: 0.2972
# Epoch 23/30
# 352/352 - 4s - loss: 0.2967 - val_loss: 0.2930
# Epoch 24/30
# 352/352 - 3s - loss: 0.2960 - val_loss: 0.2931
# Epoch 25/30
# 352/352 - 3s - loss: 0.2967 - val_loss: 0.2926
# Epoch 26/30
# 352/352 - 3s - loss: 0.2964 - val_loss: 0.2971
# Epoch 27/30
# 352/352 - 4s - loss: 0.2963 - val_loss: 0.2950
# Epoch 28/30
# 352/352 - 4s - loss: 0.2962 - val_loss: 0.2954
# Epoch 29/30
# 352/352 - 4s - loss: 0.2969 - val_loss: 0.2947
# Epoch 30/30
# 352/352 - 4s - loss: 0.2967 - val_loss: 0.2956

# %%
##for 0.01
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_33 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_34 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_35 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 2s - loss: 0.2231 - val_loss: 0.1847
# Epoch 2/30
# 352/352 - 3s - loss: 0.1684 - val_loss: 0.1630
# Epoch 3/30
# 352/352 - 4s - loss: 0.1490 - val_loss: 0.1592
# Epoch 4/30
# 352/352 - 3s - loss: 0.1329 - val_loss: 0.1539
# Epoch 5/30
# 352/352 - 2s - loss: 0.1218 - val_loss: 0.1428
# Epoch 6/30
# 352/352 - 3s - loss: 0.1149 - val_loss: 0.1438
# Epoch 7/30
# 352/352 - 4s - loss: 0.1070 - val_loss: 0.1387
# Epoch 8/30
# 352/352 - 3s - loss: 0.1038 - val_loss: 0.1215
# Epoch 9/30
# 352/352 - 3s - loss: 0.1011 - val_loss: 0.1435
# Epoch 10/30
# 352/352 - 3s - loss: 0.0940 - val_loss: 0.1281
# Epoch 11/30
# 352/352 - 4s - loss: 0.0929 - val_loss: 0.1323
# Epoch 12/30
# 352/352 - 4s - loss: 0.0928 - val_loss: 0.1368
# Epoch 13/30
# 352/352 - 3s - loss: 0.0894 - val_loss: 0.1425
# Epoch 14/30
# 352/352 - 4s - loss: 0.0879 - val_loss: 0.1326
# Epoch 15/30
# 352/352 - 4s - loss: 0.0850 - val_loss: 0.1289
# Epoch 16/30
# 352/352 - 3s - loss: 0.0842 - val_loss: 0.1364
# Epoch 17/30
# 352/352 - 3s - loss: 0.0841 - val_loss: 0.1213
# Epoch 18/30
# 352/352 - 3s - loss: 0.0817 - val_loss: 0.1436
# Epoch 19/30
# 352/352 - 3s - loss: 0.0831 - val_loss: 0.1285
# Epoch 20/30
# 352/352 - 3s - loss: 0.0797 - val_loss: 0.1357
# Epoch 21/30
# 352/352 - 2s - loss: 0.0788 - val_loss: 0.1237
# Epoch 22/30
# 352/352 - 2s - loss: 0.0785 - val_loss: 0.1338
# Epoch 23/30
# 352/352 - 3s - loss: 0.0787 - val_loss: 0.1134
# Epoch 24/30
# 352/352 - 3s - loss: 0.0779 - val_loss: 0.1245
# Epoch 25/30
# 352/352 - 3s - loss: 0.0781 - val_loss: 0.1292
# Epoch 26/30
# 352/352 - 3s - loss: 0.0777 - val_loss: 0.1315
# Epoch 27/30
# 352/352 - 3s - loss: 0.0753 - val_loss: 0.1242
# Epoch 28/30
# 352/352 - 3s - loss: 0.0747 - val_loss: 0.1220
# Epoch 29/30
# 352/352 - 4s - loss: 0.0743 - val_loss: 0.1275
# Epoch 30/30
# 352/352 - 4s - loss: 0.0745 - val_loss: 0.1220

# %%
##for 0.001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_37 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_38 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 4s - loss: 0.1852 - val_loss: 0.1612
# Epoch 2/30
# 352/352 - 3s - loss: 0.1415 - val_loss: 0.1453
# Epoch 3/30
# 352/352 - 3s - loss: 0.1212 - val_loss: 0.1237
# Epoch 4/30
# 352/352 - 3s - loss: 0.1049 - val_loss: 0.1172
# Epoch 5/30
# 352/352 - 3s - loss: 0.0942 - val_loss: 0.1163
# Epoch 6/30
# 352/352 - 3s - loss: 0.0849 - val_loss: 0.1036
# Epoch 7/30
# 352/352 - 2s - loss: 0.0800 - val_loss: 0.1104
# Epoch 8/30
# 352/352 - 2s - loss: 0.0750 - val_loss: 0.1044
# Epoch 9/30
# 352/352 - 3s - loss: 0.0700 - val_loss: 0.1069
# Epoch 10/30
# 352/352 - 3s - loss: 0.0681 - val_loss: 0.1047
# Epoch 11/30
# 352/352 - 4s - loss: 0.0664 - val_loss: 0.1091
# Epoch 12/30
# 352/352 - 4s - loss: 0.0614 - val_loss: 0.0979
# Epoch 13/30
# 352/352 - 4s - loss: 0.0616 - val_loss: 0.0967
# Epoch 14/30
# 352/352 - 3s - loss: 0.0585 - val_loss: 0.1001
# Epoch 15/30
# 352/352 - 3s - loss: 0.0592 - val_loss: 0.1011
# Epoch 16/30
# 352/352 - 3s - loss: 0.0557 - val_loss: 0.1027
# Epoch 17/30
# 352/352 - 3s - loss: 0.0559 - val_loss: 0.0996
# Epoch 18/30
# 352/352 - 3s - loss: 0.0539 - val_loss: 0.1016
# Epoch 19/30
# 352/352 - 3s - loss: 0.0533 - val_loss: 0.0929
# Epoch 20/30
# 352/352 - 3s - loss: 0.0528 - val_loss: 0.1106
# Epoch 21/30
# 352/352 - 3s - loss: 0.0509 - val_loss: 0.0981
# Epoch 22/30
# 352/352 - 4s - loss: 0.0504 - val_loss: 0.1130
# Epoch 23/30
# 352/352 - 4s - loss: 0.0509 - val_loss: 0.1006
# Epoch 24/30
# 352/352 - 3s - loss: 0.0486 - val_loss: 0.1004
# Epoch 25/30
# 352/352 - 3s - loss: 0.0482 - val_loss: 0.0960
# Epoch 26/30
# 352/352 - 3s - loss: 0.0478 - val_loss: 0.0954
# Epoch 27/30
# 352/352 - 3s - loss: 0.0481 - val_loss: 0.0988
# Epoch 28/30
# 352/352 - 4s - loss: 0.0463 - val_loss: 0.0931
# Epoch 29/30
# 352/352 - 4s - loss: 0.0467 - val_loss: 0.0953
# Epoch 30/30
# 352/352 - 3s - loss: 0.0460 - val_loss: 0.0891

# %%
##for 0.0001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_39 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_40 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_41 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 4s - loss: 0.2195 - val_loss: 0.1809
# Epoch 2/30
# 352/352 - 3s - loss: 0.1702 - val_loss: 0.1651
# Epoch 3/30
# 352/352 - 3s - loss: 0.1563 - val_loss: 0.1568
# Epoch 4/30
# 352/352 - 4s - loss: 0.1472 - val_loss: 0.1472
# Epoch 5/30
# 352/352 - 4s - loss: 0.1395 - val_loss: 0.1425
# Epoch 6/30
# 352/352 - 4s - loss: 0.1328 - val_loss: 0.1413
# Epoch 7/30
# 352/352 - 3s - loss: 0.1268 - val_loss: 0.1422
# Epoch 8/30
# 352/352 - 3s - loss: 0.1215 - val_loss: 0.1382
# Epoch 9/30
# 352/352 - 3s - loss: 0.1168 - val_loss: 0.1389
# Epoch 10/30
# 352/352 - 2s - loss: 0.1127 - val_loss: 0.1387
# Epoch 11/30
# 352/352 - 2s - loss: 0.1085 - val_loss: 0.1357
# Epoch 12/30
# 352/352 - 3s - loss: 0.1049 - val_loss: 0.1295
# Epoch 13/30
# 352/352 - 3s - loss: 0.1011 - val_loss: 0.1324
# Epoch 14/30
# 352/352 - 3s - loss: 0.0984 - val_loss: 0.1317
# Epoch 15/30
# 352/352 - 4s - loss: 0.0951 - val_loss: 0.1310
# Epoch 16/30
# 352/352 - 4s - loss: 0.0925 - val_loss: 0.1267
# Epoch 17/30
# 352/352 - 3s - loss: 0.0902 - val_loss: 0.1289
# Epoch 18/30
# 352/352 - 3s - loss: 0.0875 - val_loss: 0.1273
# Epoch 19/30
# 352/352 - 3s - loss: 0.0857 - val_loss: 0.1319
# Epoch 20/30
# 352/352 - 3s - loss: 0.0834 - val_loss: 0.1286
# Epoch 21/30
# 352/352 - 3s - loss: 0.0814 - val_loss: 0.1273
# Epoch 22/30
# 352/352 - 3s - loss: 0.0797 - val_loss: 0.1291
# Epoch 23/30
# 352/352 - 3s - loss: 0.0782 - val_loss: 0.1271
# Epoch 24/30
# 352/352 - 3s - loss: 0.0764 - val_loss: 0.1316
# Epoch 25/30
# 352/352 - 3s - loss: 0.0749 - val_loss: 0.1303
# Epoch 26/30
# 352/352 - 3s - loss: 0.0732 - val_loss: 0.1310
# Epoch 27/30
# 352/352 - 3s - loss: 0.0721 - val_loss: 0.1284
# Epoch 28/30
# 352/352 - 3s - loss: 0.0715 - val_loss: 0.1290
# Epoch 29/30
# 352/352 - 4s - loss: 0.0697 - val_loss: 0.1305
# Epoch 30/30
# 352/352 - 4s - loss: 0.0687 - val_loss: 0.1274

# %%
##for lr scheduler 5epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_42 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_43 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_44 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 4s - loss: 0.1860 - val_loss: 0.1587
# Epoch 2/30
# 352/352 - 3s - loss: 0.1415 - val_loss: 0.1346
# Epoch 3/30
# 352/352 - 3s - loss: 0.1192 - val_loss: 0.1250
# Epoch 4/30
# 352/352 - 3s - loss: 0.1048 - val_loss: 0.1072
# Epoch 5/30
# 352/352 - 3s - loss: 0.0934 - val_loss: 0.1069
# Epoch 6/30
# 352/352 - 3s - loss: 0.0849 - val_loss: 0.1027
# Epoch 7/30
# 352/352 - 3s - loss: 0.0768 - val_loss: 0.0902
# Epoch 8/30
# 352/352 - 4s - loss: 0.0725 - val_loss: 0.0964
# Epoch 9/30
# 352/352 - 4s - loss: 0.0660 - val_loss: 0.0846
# Epoch 10/30
# 352/352 - 3s - loss: 0.0613 - val_loss: 0.0764
# Epoch 11/30
# 352/352 - 3s - loss: 0.0587 - val_loss: 0.0744
# Epoch 12/30
# 352/352 - 3s - loss: 0.0555 - val_loss: 0.0825
# Epoch 13/30
# 352/352 - 2s - loss: 0.0527 - val_loss: 0.0802
# Epoch 14/30
# 352/352 - 3s - loss: 0.0505 - val_loss: 0.0831
# Epoch 15/30
# 352/352 - 3s - loss: 0.0481 - val_loss: 0.0770
# Epoch 16/30
# 352/352 - 4s - loss: 0.0464 - val_loss: 0.0754
# Epoch 17/30
# 352/352 - 3s - loss: 0.0448 - val_loss: 0.0721
# Epoch 18/30
# 352/352 - 3s - loss: 0.0434 - val_loss: 0.0762
# Epoch 19/30
# 352/352 - 4s - loss: 0.0422 - val_loss: 0.0697
# Epoch 20/30
# 352/352 - 4s - loss: 0.0406 - val_loss: 0.0758
# Epoch 21/30
# 352/352 - 3s - loss: 0.0398 - val_loss: 0.0730
# Epoch 22/30
# 352/352 - 3s - loss: 0.0386 - val_loss: 0.0732
# Epoch 23/30
# 352/352 - 3s - loss: 0.0376 - val_loss: 0.0688
# Epoch 24/30
# 352/352 - 3s - loss: 0.0370 - val_loss: 0.0700
# Epoch 25/30
# 352/352 - 3s - loss: 0.0362 - val_loss: 0.0733
# Epoch 26/30
# 352/352 - 3s - loss: 0.0355 - val_loss: 0.0733
# Epoch 27/30
# 352/352 - 3s - loss: 0.0350 - val_loss: 0.0708
# Epoch 28/30
# 352/352 - 3s - loss: 0.0342 - val_loss: 0.0731
# Epoch 29/30
# 352/352 - 3s - loss: 0.0340 - val_loss: 0.0729
# Epoch 30/30
# 352/352 - 3s - loss: 0.0333 - val_loss: 0.0724

# %%
##for for lr scheduler 10epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_45 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_46 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_47 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 4s - loss: 0.1844 - val_loss: 0.1540
# Epoch 2/30
# 352/352 - 3s - loss: 0.1406 - val_loss: 0.1340
# Epoch 3/30
# 352/352 - 3s - loss: 0.1184 - val_loss: 0.1209
# Epoch 4/30
# 352/352 - 3s - loss: 0.1028 - val_loss: 0.1082
# Epoch 5/30
# 352/352 - 3s - loss: 0.0945 - val_loss: 0.0970
# Epoch 6/30
# 352/352 - 3s - loss: 0.0865 - val_loss: 0.0990
# Epoch 7/30
# 352/352 - 3s - loss: 0.0818 - val_loss: 0.0870
# Epoch 8/30
# 352/352 - 3s - loss: 0.0759 - val_loss: 0.0764
# Epoch 9/30
# 352/352 - 3s - loss: 0.0723 - val_loss: 0.0840
# Epoch 10/30
# 352/352 - 3s - loss: 0.0693 - val_loss: 0.0828
# Epoch 11/30
# 352/352 - 3s - loss: 0.0660 - val_loss: 0.0887
# Epoch 12/30
# 352/352 - 4s - loss: 0.0617 - val_loss: 0.0700
# Epoch 13/30
# 352/352 - 4s - loss: 0.0584 - val_loss: 0.0749
# Epoch 14/30
# 352/352 - 3s - loss: 0.0546 - val_loss: 0.0728
# Epoch 15/30
# 352/352 - 3s - loss: 0.0519 - val_loss: 0.0689
# Epoch 16/30
# 352/352 - 2s - loss: 0.0499 - val_loss: 0.0661
# Epoch 17/30
# 352/352 - 3s - loss: 0.0474 - val_loss: 0.0699
# Epoch 18/30
# 352/352 - 3s - loss: 0.0463 - val_loss: 0.0606
# Epoch 19/30
# 352/352 - 3s - loss: 0.0438 - val_loss: 0.0674
# Epoch 20/30
# 352/352 - 3s - loss: 0.0427 - val_loss: 0.0613
# Epoch 21/30
# 352/352 - 3s - loss: 0.0409 - val_loss: 0.0610
# Epoch 22/30
# 352/352 - 4s - loss: 0.0400 - val_loss: 0.0626
# Epoch 23/30
# 352/352 - 5s - loss: 0.0386 - val_loss: 0.0624
# Epoch 24/30
# 352/352 - 4s - loss: 0.0373 - val_loss: 0.0610
# Epoch 25/30
# 352/352 - 3s - loss: 0.0365 - val_loss: 0.0592
# Epoch 26/30
# 352/352 - 3s - loss: 0.0356 - val_loss: 0.0582
# Epoch 27/30
# 352/352 - 3s - loss: 0.0349 - val_loss: 0.0573
# Epoch 28/30
# 352/352 - 3s - loss: 0.0341 - val_loss: 0.0587
# Epoch 29/30
# 352/352 - 3s - loss: 0.0334 - val_loss: 0.0594
# Epoch 30/30
# 352/352 - 3s - loss: 0.0329 - val_loss: 0.0583

# %%
##for lr 15
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 15:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_7 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_48 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_49 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_50 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 3s - loss: 0.1890 - val_loss: 0.1637
# Epoch 2/30
# 352/352 - 2s - loss: 0.1453 - val_loss: 0.1353
# Epoch 3/30
# 352/352 - 3s - loss: 0.1241 - val_loss: 0.1173
# Epoch 4/30
# 352/352 - 4s - loss: 0.1077 - val_loss: 0.1057
# Epoch 5/30
# 352/352 - 4s - loss: 0.0985 - val_loss: 0.0975
# Epoch 6/30
# 352/352 - 4s - loss: 0.0891 - val_loss: 0.0961
# Epoch 7/30
# 352/352 - 3s - loss: 0.0823 - val_loss: 0.0902
# Epoch 8/30
# 352/352 - 3s - loss: 0.0768 - val_loss: 0.0816
# Epoch 9/30
# 352/352 - 3s - loss: 0.0736 - val_loss: 0.0910
# Epoch 10/30
# 352/352 - 3s - loss: 0.0698 - val_loss: 0.0881
# Epoch 11/30
# 352/352 - 3s - loss: 0.0670 - val_loss: 0.0805
# Epoch 12/30
# 352/352 - 3s - loss: 0.0656 - val_loss: 0.0748
# Epoch 13/30
# 352/352 - 3s - loss: 0.0627 - val_loss: 0.0853
# Epoch 14/30
# 352/352 - 4s - loss: 0.0597 - val_loss: 0.0830
# Epoch 15/30
# 352/352 - 5s - loss: 0.0592 - val_loss: 0.0828
# Epoch 16/30
# 352/352 - 4s - loss: 0.0569 - val_loss: 0.0752
# Epoch 17/30
# 352/352 - 3s - loss: 0.0528 - val_loss: 0.0772
# Epoch 18/30
# 352/352 - 3s - loss: 0.0500 - val_loss: 0.0718
# Epoch 19/30
# 352/352 - 3s - loss: 0.0484 - val_loss: 0.0714
# Epoch 20/30
# 352/352 - 3s - loss: 0.0462 - val_loss: 0.0771
# Epoch 21/30
# 352/352 - 3s - loss: 0.0438 - val_loss: 0.0752
# Epoch 22/30
# 352/352 - 3s - loss: 0.0422 - val_loss: 0.0660
# Epoch 23/30
# 352/352 - 3s - loss: 0.0415 - val_loss: 0.0739
# Epoch 24/30
# 352/352 - 3s - loss: 0.0390 - val_loss: 0.0691
# Epoch 25/30
# 352/352 - 3s - loss: 0.0394 - val_loss: 0.0690
# Epoch 26/30
# 352/352 - 4s - loss: 0.0369 - val_loss: 0.0689
# Epoch 27/30
# 352/352 - 4s - loss: 0.0359 - val_loss: 0.0663
# Epoch 28/30
# 352/352 - 4s - loss: 0.0347 - val_loss: 0.0697
# Epoch 29/30
# 352/352 - 3s - loss: 0.0336 - val_loss: 0.0700
# Epoch 30/30
# 352/352 - 3s - loss: 0.0329 - val_loss: 0.0676

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_hex_data_5_lat.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_hex_data_5_lat.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(39,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_8 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-1.00901681  0.29679417 -0.08563573 -0.97388892  0.28921222 -0.0662603
#   -0.37344024  0.12355706 -0.01399191 -0.59876742  0.19760429 -0.00185156
#   -1.00398709  0.32061918 -0.04832024 -0.95216501  0.28265648 -0.0638499
#   -0.9334568   0.26823752 -0.05543414 -1.03193563  0.27726761 -0.11295288
#   -1.10520987  0.35590611 -0.05583592 -1.03836211  0.33191525 -0.05323987
#   -0.98781711  0.30041034 -0.06865264 -0.9567859   0.27526951 -0.07071635
#   -0.95931839  0.26640576 -0.07235861]
#  [-0.98836305  0.27067152 -0.09028607 -0.96738877  0.32452781 -0.08436246
#   -0.66492566  0.17587357 -0.62967133 -0.54999814  0.1815278  -0.00326393
#   -1.01130939  0.31629536 -0.06232372 -0.9438729   0.27323179 -0.06404359
#   -0.93160064  0.27691075 -0.04796361 -1.00585762  0.28769086 -0.08180055
#   -1.14943396  0.34447756 -0.1169303  -1.05270035  0.3252866  -0.07783491
#   -0.98008612  0.28561229 -0.07801196 -0.94556221  0.26725919 -0.06429194
#   -0.95405513  0.27887607 -0.05839654]]
# [[ -17.   -17.     1.     0.     0.  -110.   -60. ]
#  [  -8.5  -17.     1.     0.     0.  -110.   -60. ]]
# (11250, 39) (11250, 7) training data size
# (3750, 39) (3750, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 39)]              0
# _________________________________________________________________
# dense_51 (Dense)             (None, 700)               28000
# _________________________________________________________________
# dense_52 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_53 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 523,607
# Trainable params: 523,607
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 352/352 - 4s - loss: 0.1889 - val_loss: 0.1746
# Epoch 2/30
# 352/352 - 3s - loss: 0.1443 - val_loss: 0.1465
# Epoch 3/30
# 352/352 - 3s - loss: 0.1217 - val_loss: 0.1289
# Epoch 4/30
# 352/352 - 2s - loss: 0.1076 - val_loss: 0.1229
# Epoch 5/30
# 352/352 - 3s - loss: 0.0942 - val_loss: 0.1124
# Epoch 6/30
# 352/352 - 3s - loss: 0.0881 - val_loss: 0.1249
# Epoch 7/30
# 352/352 - 4s - loss: 0.0800 - val_loss: 0.1158
# Epoch 8/30
# 352/352 - 4s - loss: 0.0772 - val_loss: 0.1151
# Epoch 9/30
# 352/352 - 5s - loss: 0.0720 - val_loss: 0.1171
# Epoch 10/30
# 352/352 - 3s - loss: 0.0695 - val_loss: 0.1183
# Epoch 11/30
# 352/352 - 3s - loss: 0.0656 - val_loss: 0.1150
# Epoch 12/30
# 352/352 - 4s - loss: 0.0643 - val_loss: 0.1211
# Epoch 13/30
# 352/352 - 3s - loss: 0.0625 - val_loss: 0.1090
# Epoch 14/30
# 352/352 - 3s - loss: 0.0593 - val_loss: 0.1122
# Epoch 15/30
# 352/352 - 3s - loss: 0.0581 - val_loss: 0.1139
# Epoch 16/30
# 352/352 - 3s - loss: 0.0573 - val_loss: 0.1121
# Epoch 17/30
# 352/352 - 3s - loss: 0.0572 - val_loss: 0.1062
# Epoch 18/30
# 352/352 - 4s - loss: 0.0553 - val_loss: 0.1139
# Epoch 19/30
# 352/352 - 4s - loss: 0.0543 - val_loss: 0.1117
# Epoch 20/30
# 352/352 - 3s - loss: 0.0527 - val_loss: 0.1059
# Epoch 21/30
# 352/352 - 3s - loss: 0.0505 - val_loss: 0.0981
# Epoch 22/30
# 352/352 - 3s - loss: 0.0476 - val_loss: 0.1063
# Epoch 23/30
# 352/352 - 3s - loss: 0.0453 - val_loss: 0.1078
# Epoch 24/30
# 352/352 - 3s - loss: 0.0442 - val_loss: 0.1012
# Epoch 25/30
# 352/352 - 3s - loss: 0.0425 - val_loss: 0.1046
# Epoch 26/30
# 352/352 - 3s - loss: 0.0415 - val_loss: 0.1013
# Epoch 27/30
# 352/352 - 3s - loss: 0.0387 - val_loss: 0.0971
# Epoch 28/30
# 352/352 - 4s - loss: 0.0371 - val_loss: 0.0985
# Epoch 29/30
# 352/352 - 3s - loss: 0.0358 - val_loss: 0.1038
# Epoch 30/30
# 352/352 - 4s - loss: 0.0349 - val_loss: 0.1052

# %%
#plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#lgd=plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.06,0.25)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.06, 0.25, 0.02))
plt.savefig('Validation_Loss_for_lr_hex.png', dpi=1200)
plt.show()

# %%
#plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.04,0.25)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.04, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_hex.png', dpi=1200)
plt.show()
