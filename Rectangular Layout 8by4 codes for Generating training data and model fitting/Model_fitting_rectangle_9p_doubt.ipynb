# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm

input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=32,verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense (Dense)                (None, 700)               67900
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 12456/12456 - 109s - loss: 0.1029 - val_loss: 0.0905
# Epoch 2/20
# 12456/12456 - 113s - loss: 0.0706 - val_loss: 0.0949
# Epoch 3/20
# 12456/12456 - 112s - loss: 0.0617 - val_loss: 0.0808
# Epoch 4/20
# 12456/12456 - 112s - loss: 0.0574 - val_loss: 0.0828
# Epoch 5/20
# 12456/12456 - 111s - loss: 0.0539 - val_loss: 0.0810
# Epoch 6/20
# 12456/12456 - 111s - loss: 0.0512 - val_loss: 0.0804
# Epoch 7/20
# 12456/12456 - 112s - loss: 0.0494 - val_loss: 0.0908
# Epoch 8/20
# 12456/12456 - 111s - loss: 0.0476 - val_loss: 0.0875
# Epoch 9/20
# 12456/12456 - 111s - loss: 0.0466 - val_loss: 0.0934
# Epoch 10/20
# 12456/12456 - 116s - loss: 0.0451 - val_loss: 0.0830
# Epoch 11/20
# 12456/12456 - 124s - loss: 0.0441 - val_loss: 0.0818
# Epoch 12/20
# 12456/12456 - 114s - loss: 0.0432 - val_loss: 0.0869
# Epoch 13/20
# 12456/12456 - 118s - loss: 0.0424 - val_loss: 0.0818
# Epoch 14/20
# 12456/12456 - 115s - loss: 0.0417 - val_loss: 0.0756
# Epoch 15/20
# 12456/12456 - 118s - loss: 0.0410 - val_loss: 0.0868
# Epoch 16/20
# 12456/12456 - 114s - loss: 0.0401 - val_loss: 0.0788
# Epoch 17/20
# 12456/12456 - 109s - loss: 0.0396 - val_loss: 0.0887
# Epoch 18/20
# 12456/12456 - 81s - loss: 0.0392 - val_loss: 0.0762
# Epoch 19/20
# 12456/12456 - 149s - loss: 0.0387 - val_loss: 0.0850
# Epoch 20/20
# 12456/12456 - 154s - loss: 0.0383 - val_loss: 0.0919

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               67900
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 3114/3114 - 48s - loss: 0.1146 - val_loss: 0.0975
# Epoch 2/20
# 3114/3114 - 55s - loss: 0.0748 - val_loss: 0.1081
# Epoch 3/20
# 3114/3114 - 55s - loss: 0.0651 - val_loss: 0.0887
# Epoch 4/20
# 3114/3114 - 48s - loss: 0.0601 - val_loss: 0.1103
# Epoch 5/20
# 3114/3114 - 54s - loss: 0.0562 - val_loss: 0.0936
# Epoch 6/20
# 3114/3114 - 56s - loss: 0.0538 - val_loss: 0.1029
# Epoch 7/20
# 3114/3114 - 54s - loss: 0.0515 - val_loss: 0.1083
# Epoch 8/20
# 3114/3114 - 50s - loss: 0.0496 - val_loss: 0.1072
# Epoch 9/20
# 3114/3114 - 58s - loss: 0.0480 - val_loss: 0.1068
# Epoch 10/20
# 3114/3114 - 54s - loss: 0.0464 - val_loss: 0.1115
# Epoch 11/20
# 3114/3114 - 48s - loss: 0.0454 - val_loss: 0.1224
# Epoch 12/20
# 3114/3114 - 52s - loss: 0.0439 - val_loss: 0.1277
# Epoch 13/20
# 3114/3114 - 52s - loss: 0.0429 - val_loss: 0.1123
# Epoch 14/20
# 3114/3114 - 49s - loss: 0.0417 - val_loss: 0.1200
# Epoch 15/20
# 3114/3114 - 51s - loss: 0.0413 - val_loss: 0.1190
# Epoch 16/20
# 3114/3114 - 52s - loss: 0.0405 - val_loss: 0.1223
# Epoch 17/20
# 3114/3114 - 50s - loss: 0.0397 - val_loss: 0.1263
# Epoch 18/20
# 3114/3114 - 52s - loss: 0.0394 - val_loss: 0.1194
# Epoch 19/20
# 3114/3114 - 53s - loss: 0.0388 - val_loss: 0.1223
# Epoch 20/20
# 3114/3114 - 52s - loss: 0.0378 - val_loss: 0.1311

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, batch_size=32, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               67900
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 148s - loss: 0.1048 - val_loss: 0.0953
# Epoch 2/30
# 12456/12456 - 109s - loss: 0.0710 - val_loss: 0.0904
# Epoch 3/30
# 12456/12456 - 111s - loss: 0.0629 - val_loss: 0.0963
# Epoch 4/30
# 12456/12456 - 116s - loss: 0.0579 - val_loss: 0.0842
# Epoch 5/30
# 12456/12456 - 109s - loss: 0.0544 - val_loss: 0.0904
# Epoch 6/30
# 12456/12456 - 108s - loss: 0.0514 - val_loss: 0.0751
# Epoch 7/30
# 12456/12456 - 109s - loss: 0.0496 - val_loss: 0.0872
# Epoch 8/30
# 12456/12456 - 109s - loss: 0.0480 - val_loss: 0.1021
# Epoch 9/30
# 12456/12456 - 115s - loss: 0.0465 - val_loss: 0.1005
# Epoch 10/30
# 12456/12456 - 119s - loss: 0.0455 - val_loss: 0.1043
# Epoch 11/30
# 12456/12456 - 118s - loss: 0.0443 - val_loss: 0.0841
# Epoch 12/30
# 12456/12456 - 118s - loss: 0.0433 - val_loss: 0.0973
# Epoch 13/30
# 12456/12456 - 123s - loss: 0.0425 - val_loss: 0.0936
# Epoch 14/30
# 12456/12456 - 119s - loss: 0.0417 - val_loss: 0.0937
# Epoch 15/30
# 12456/12456 - 120s - loss: 0.0413 - val_loss: 0.0865
# Epoch 16/30
# 12456/12456 - 126s - loss: 0.0403 - val_loss: 0.0919
# Epoch 17/30
# 12456/12456 - 123s - loss: 0.0397 - val_loss: 0.1024
# Epoch 18/30
# 12456/12456 - 118s - loss: 0.0388 - val_loss: 0.0768
# Epoch 19/30
# 12456/12456 - 118s - loss: 0.0386 - val_loss: 0.0895
# Epoch 20/30
# 12456/12456 - 89s - loss: 0.0379 - val_loss: 0.0910
# Epoch 21/30
# 12456/12456 - 121s - loss: 0.0375 - val_loss: 0.1041
# Epoch 22/30
# 12456/12456 - 119s - loss: 0.0370 - val_loss: 0.0995
# Epoch 23/30
# 12456/12456 - 120s - loss: 0.0366 - val_loss: 0.0959
# Epoch 24/30
# 12456/12456 - 118s - loss: 0.0362 - val_loss: 0.1056
# Epoch 25/30
# 12456/12456 - 119s - loss: 0.0360 - val_loss: 0.0968
# Epoch 26/30
# 12456/12456 - 120s - loss: 0.0355 - val_loss: 0.0860
# Epoch 27/30
# 12456/12456 - 117s - loss: 0.0351 - val_loss: 0.0917
# Epoch 28/30
# 12456/12456 - 118s - loss: 0.0347 - val_loss: 0.0966
# Epoch 29/30
# 12456/12456 - 115s - loss: 0.0345 - val_loss: 0.0898
# Epoch 30/30
# 12456/12456 - 119s - loss: 0.0343 - val_loss: 0.1011

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 700)               67900
# _________________________________________________________________
# dense_10 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 3114/3114 - 39s - loss: 0.1168 - val_loss: 0.0926
# Epoch 2/30
# 3114/3114 - 39s - loss: 0.0760 - val_loss: 0.0961
# Epoch 3/30
# 3114/3114 - 38s - loss: 0.0657 - val_loss: 0.1058
# Epoch 4/30
# 3114/3114 - 37s - loss: 0.0605 - val_loss: 0.1151
# Epoch 5/30
# 3114/3114 - 39s - loss: 0.0569 - val_loss: 0.1139
# Epoch 6/30
# 3114/3114 - 38s - loss: 0.0539 - val_loss: 0.1201
# Epoch 7/30
# 3114/3114 - 32s - loss: 0.0516 - val_loss: 0.1181
# Epoch 8/30
# 3114/3114 - 37s - loss: 0.0503 - val_loss: 0.1290
# Epoch 9/30
# 3114/3114 - 41s - loss: 0.0484 - val_loss: 0.1254
# Epoch 10/30
# 3114/3114 - 33s - loss: 0.0471 - val_loss: 0.1289
# Epoch 11/30
# 3114/3114 - 39s - loss: 0.0460 - val_loss: 0.1184
# Epoch 12/30
# 3114/3114 - 37s - loss: 0.0448 - val_loss: 0.1143
# Epoch 13/30
# 3114/3114 - 38s - loss: 0.0438 - val_loss: 0.1166
# Epoch 14/30
# 3114/3114 - 35s - loss: 0.0428 - val_loss: 0.1203
# Epoch 15/30
# 3114/3114 - 38s - loss: 0.0423 - val_loss: 0.1360
# Epoch 16/30
# 3114/3114 - 36s - loss: 0.0415 - val_loss: 0.1278
# Epoch 17/30
# 3114/3114 - 33s - loss: 0.0407 - val_loss: 0.1354
# Epoch 18/30
# 3114/3114 - 38s - loss: 0.0400 - val_loss: 0.1343
# Epoch 19/30
# 3114/3114 - 38s - loss: 0.0390 - val_loss: 0.1254
# Epoch 20/30
# 3114/3114 - 33s - loss: 0.0387 - val_loss: 0.1370
# Epoch 21/30
# 3114/3114 - 40s - loss: 0.0382 - val_loss: 0.1212
# Epoch 22/30
# 3114/3114 - 37s - loss: 0.0375 - val_loss: 0.1354
# Epoch 23/30
# 3114/3114 - 40s - loss: 0.0372 - val_loss: 0.1379
# Epoch 24/30
# 3114/3114 - 35s - loss: 0.0367 - val_loss: 0.1354
# Epoch 25/30
# 3114/3114 - 40s - loss: 0.0363 - val_loss: 0.1380
# Epoch 26/30
# 3114/3114 - 39s - loss: 0.0358 - val_loss: 0.1333
# Epoch 27/30
# 3114/3114 - 35s - loss: 0.0354 - val_loss: 0.1269
# Epoch 28/30
# 3114/3114 - 41s - loss: 0.0351 - val_loss: 0.1266
# Epoch 29/30
# 3114/3114 - 37s - loss: 0.0347 - val_loss: 0.1377
# Epoch 30/30
# 3114/3114 - 37s - loss: 0.0345 - val_loss: 0.1361

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_13 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 12456/12456 - 114s - loss: 0.1034 - val_loss: 0.0813
# Epoch 2/20
# 12456/12456 - 125s - loss: 0.0703 - val_loss: 0.0825
# Epoch 3/20
# 12456/12456 - 126s - loss: 0.0621 - val_loss: 0.0681
# Epoch 4/20
# 12456/12456 - 154s - loss: 0.0574 - val_loss: 0.0675
# Epoch 5/20
# 12456/12456 - 150s - loss: 0.0541 - val_loss: 0.0804
# Epoch 6/20
# 12456/12456 - 150s - loss: 0.0500 - val_loss: 0.0708
# Epoch 7/20
# 12456/12456 - 148s - loss: 0.0463 - val_loss: 0.0750
# Epoch 8/20
# 12456/12456 - 148s - loss: 0.0430 - val_loss: 0.0923
# Epoch 9/20
# 12456/12456 - 123s - loss: 0.0403 - val_loss: 0.0760
# Epoch 10/20
# 12456/12456 - 148s - loss: 0.0379 - val_loss: 0.0768
# Epoch 11/20
# 12456/12456 - 149s - loss: 0.0359 - val_loss: 0.0797
# Epoch 12/20
# 12456/12456 - 114s - loss: 0.0340 - val_loss: 0.0773
# Epoch 13/20
# 12456/12456 - 108s - loss: 0.0324 - val_loss: 0.0814
# Epoch 14/20
# 12456/12456 - 109s - loss: 0.0309 - val_loss: 0.0883
# Epoch 15/20
# 12456/12456 - 121s - loss: 0.0295 - val_loss: 0.0784
# Epoch 16/20
# 12456/12456 - 123s - loss: 0.0284 - val_loss: 0.0832
# Epoch 17/20
# 12456/12456 - 119s - loss: 0.0273 - val_loss: 0.0777
# Epoch 18/20
# 12456/12456 - 116s - loss: 0.0262 - val_loss: 0.0837
# Epoch 19/20
# 12456/12456 - 114s - loss: 0.0254 - val_loss: 0.0832
# Epoch 20/20
# 12456/12456 - 121s - loss: 0.0245 - val_loss: 0.0847

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=20, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 3114/3114 - 39s - loss: 0.1147 - val_loss: 0.0984
# Epoch 2/20
# 3114/3114 - 37s - loss: 0.0758 - val_loss: 0.0986
# Epoch 3/20
# 3114/3114 - 36s - loss: 0.0654 - val_loss: 0.0896
# Epoch 4/20
# 3114/3114 - 35s - loss: 0.0601 - val_loss: 0.0849
# Epoch 5/20
# 3114/3114 - 38s - loss: 0.0567 - val_loss: 0.0879
# Epoch 6/20
# 3114/3114 - 37s - loss: 0.0517 - val_loss: 0.0826
# Epoch 7/20
# 3114/3114 - 32s - loss: 0.0483 - val_loss: 0.0792
# Epoch 8/20
# 3114/3114 - 37s - loss: 0.0452 - val_loss: 0.0821
# Epoch 9/20
# 3114/3114 - 36s - loss: 0.0425 - val_loss: 0.0839
# Epoch 10/20
# 3114/3114 - 34s - loss: 0.0403 - val_loss: 0.0815
# Epoch 11/20
# 3114/3114 - 39s - loss: 0.0382 - val_loss: 0.0800
# Epoch 12/20
# 3114/3114 - 36s - loss: 0.0362 - val_loss: 0.0877
# Epoch 13/20
# 3114/3114 - 38s - loss: 0.0347 - val_loss: 0.0829
# Epoch 14/20
# 3114/3114 - 37s - loss: 0.0331 - val_loss: 0.0854
# Epoch 15/20
# 3114/3114 - 36s - loss: 0.0319 - val_loss: 0.0807
# Epoch 16/20
# 3114/3114 - 37s - loss: 0.0307 - val_loss: 0.0864
# Epoch 17/20
# 3114/3114 - 33s - loss: 0.0295 - val_loss: 0.0844
# Epoch 18/20
# 3114/3114 - 39s - loss: 0.0286 - val_loss: 0.0831
# Epoch 19/20
# 3114/3114 - 39s - loss: 0.0275 - val_loss: 0.0831
# Epoch 20/20
# 3114/3114 - 34s - loss: 0.0268 - val_loss: 0.0861

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_7 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_19 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12456/12456 - 121s - loss: 0.1028 - val_loss: 0.1105
# Epoch 2/30
# 12456/12456 - 119s - loss: 0.0698 - val_loss: 0.0831
# Epoch 3/30
# 12456/12456 - 122s - loss: 0.0619 - val_loss: 0.0858
# Epoch 4/30
# 12456/12456 - 116s - loss: 0.0570 - val_loss: 0.0850
# Epoch 5/30
# 12456/12456 - 116s - loss: 0.0541 - val_loss: 0.0916
# Epoch 6/30
# 12456/12456 - 111s - loss: 0.0495 - val_loss: 0.1011
# Epoch 7/30
# 12456/12456 - 111s - loss: 0.0462 - val_loss: 0.0900
# Epoch 8/30
# 12456/12456 - 122s - loss: 0.0431 - val_loss: 0.0899
# Epoch 9/30
# 12456/12456 - 123s - loss: 0.0405 - val_loss: 0.0854
# Epoch 10/30
# 12456/12456 - 69s - loss: 0.0381 - val_loss: 0.0838
# Epoch 11/30
# 12456/12456 - 109s - loss: 0.0360 - val_loss: 0.0850
# Epoch 12/30
# 12456/12456 - 112s - loss: 0.0343 - val_loss: 0.0914
# Epoch 13/30
# 12456/12456 - 110s - loss: 0.0327 - val_loss: 0.0890
# Epoch 14/30
# 12456/12456 - 111s - loss: 0.0313 - val_loss: 0.0873
# Epoch 15/30
# 12456/12456 - 111s - loss: 0.0298 - val_loss: 0.0803
# Epoch 16/30
# 12456/12456 - 111s - loss: 0.0288 - val_loss: 0.0938
# Epoch 17/30
# 12456/12456 - 110s - loss: 0.0276 - val_loss: 0.0902
# Epoch 18/30
# 12456/12456 - 110s - loss: 0.0267 - val_loss: 0.0910
# Epoch 19/30
# 12456/12456 - 111s - loss: 0.0257 - val_loss: 0.0917
# Epoch 20/30
# 12456/12456 - 113s - loss: 0.0249 - val_loss: 0.0865
# Epoch 21/30
# 12456/12456 - 117s - loss: 0.0240 - val_loss: 0.0924
# Epoch 22/30
# 12456/12456 - 114s - loss: 0.0234 - val_loss: 0.0903
# Epoch 23/30
# 12456/12456 - 115s - loss: 0.0227 - val_loss: 0.0909
# Epoch 24/30
# 12456/12456 - 114s - loss: 0.0222 - val_loss: 0.0891
# Epoch 25/30
# 12456/12456 - 152s - loss: 0.0217 - val_loss: 0.0906
# Epoch 26/30
# 12456/12456 - 167s - loss: 0.0212 - val_loss: 0.0930
# Epoch 27/30
# 12456/12456 - 159s - loss: 0.0207 - val_loss: 0.0912
# Epoch 28/30
# 12456/12456 - 167s - loss: 0.0204 - val_loss: 0.0926
# Epoch 29/30
# 12456/12456 - 167s - loss: 0.0200 - val_loss: 0.0928
# Epoch 30/30
# 12456/12456 - 166s - loss: 0.0196 - val_loss: 0.0925

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_8 = model.fit(xtrain_scale, ytrain_scale, epochs=30, batch_size=128, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_22 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 3114/3114 - 57s - loss: 0.1158 - val_loss: 0.0942
# Epoch 2/30
# 3114/3114 - 53s - loss: 0.0761 - val_loss: 0.0842
# Epoch 3/30
# 3114/3114 - 56s - loss: 0.0659 - val_loss: 0.0759
# Epoch 4/30
# 3114/3114 - 56s - loss: 0.0605 - val_loss: 0.0714
# Epoch 5/30
# 3114/3114 - 52s - loss: 0.0569 - val_loss: 0.0764
# Epoch 6/30
# 3114/3114 - 51s - loss: 0.0523 - val_loss: 0.0744
# Epoch 7/30
# 3114/3114 - 54s - loss: 0.0486 - val_loss: 0.0687
# Epoch 8/30
# 3114/3114 - 51s - loss: 0.0456 - val_loss: 0.0727
# Epoch 9/30
# 3114/3114 - 49s - loss: 0.0430 - val_loss: 0.0629
# Epoch 10/30
# 3114/3114 - 55s - loss: 0.0406 - val_loss: 0.0696
# Epoch 11/30
# 3114/3114 - 54s - loss: 0.0385 - val_loss: 0.0672
# Epoch 12/30
# 3114/3114 - 49s - loss: 0.0366 - val_loss: 0.0672
# Epoch 13/30
# 3114/3114 - 52s - loss: 0.0350 - val_loss: 0.0655
# Epoch 14/30
# 3114/3114 - 57s - loss: 0.0335 - val_loss: 0.0689
# Epoch 15/30
# 3114/3114 - 40s - loss: 0.0321 - val_loss: 0.0632
# Epoch 16/30
# 3114/3114 - 31s - loss: 0.0309 - val_loss: 0.0711
# Epoch 17/30
# 3114/3114 - 37s - loss: 0.0298 - val_loss: 0.0648
# Epoch 18/30
# 3114/3114 - 33s - loss: 0.0287 - val_loss: 0.0685
# Epoch 19/30
# 3114/3114 - 29s - loss: 0.0276 - val_loss: 0.0682
# Epoch 20/30
# 3114/3114 - 33s - loss: 0.0268 - val_loss: 0.0669
# Epoch 21/30
# 3114/3114 - 33s - loss: 0.0262 - val_loss: 0.0683
# Epoch 22/30
# 3114/3114 - 30s - loss: 0.0254 - val_loss: 0.0715
# Epoch 23/30
# 3114/3114 - 35s - loss: 0.0249 - val_loss: 0.0689
# Epoch 24/30
# 3114/3114 - 34s - loss: 0.0241 - val_loss: 0.0677
# Epoch 25/30
# 3114/3114 - 32s - loss: 0.0236 - val_loss: 0.0692
# Epoch 26/30
# 3114/3114 - 32s - loss: 0.0231 - val_loss: 0.0678
# Epoch 27/30
# 3114/3114 - 34s - loss: 0.0227 - val_loss: 0.0700
# Epoch 28/30
# 3114/3114 - 35s - loss: 0.0222 - val_loss: 0.0705
# Epoch 29/30
# 3114/3114 - 25s - loss: 0.0219 - val_loss: 0.0711
# Epoch 30/30
# 3114/3114 - 21s - loss: 0.0216 - val_loss: 0.0724

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['adam_20_32','adam_20_128','adam_30_32','adam_30_128','lr_20_32','lr_20_128','lr_30_32','lr_30_128'], loc='upper right')
#plt.xlim(0,50)
#plt.ylim(0.07,0.17)
#plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.07, 0.18, 0.02))
plt.savefig('Validation_Loss_for_doubt_rec_8by4_9p.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['adam_20_32','adam_20_128','adam_30_32','adam_30_128','lr_20_32','lr_20_128','lr_30_32','lr_30_128'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.040,)
#plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.0, 0.23, 0.02))
plt.savefig('Training_Loss_for_doubt_rec_8by4_9p.png', dpi=1200)
plt.show()

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_9 = model.fit(xtrain_scale, ytrain_scale, epochs=10, batch_size=32, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90836324  0.27004906 -0.04331301 -0.90570851  0.27039791 -0.03953705
#   -0.90471256  0.27400243 -0.03594176 -0.90502894  0.28023207 -0.03400004
#   -0.90556629  0.28745112 -0.0344934  -0.90520776  0.29392846 -0.0371333
#   -0.90341833  0.29863415 -0.04096209 -0.90029299  0.30137019 -0.0449961
#   -0.91640707  0.27032652 -0.04840821 -0.91246933  0.26963156 -0.04386949
#   -0.91093671  0.27377707 -0.03915447 -0.91138562  0.28190003 -0.03686586
#   -0.91188126  0.29108703 -0.03825304 -0.91065709  0.29851197 -0.04244688
#   -0.90726515  0.30299163 -0.04763721 -0.90228117  0.3047821  -0.05240289
#   -0.92782466  0.27168001 -0.05514205 -0.92170094  0.26878186 -0.04989897
#   -0.91913849  0.27343056 -0.0434195  -0.91979977  0.28459757 -0.0407365
#   -0.91990554  0.29653971 -0.04394415 -0.91668381  0.30452564 -0.05056722
#   -0.91040981  0.30779329 -0.05725101 -0.9026909   0.30775993 -0.06228637
#   -0.9453638   0.27580499 -0.06393223 -0.93546776  0.2682143  -0.05890998
#   -0.93065271  0.27284305 -0.04947522 -0.93164531  0.28941618 -0.04651011
#   -0.93006896  0.30494943 -0.05361452 -0.92220311  0.31184616 -0.06364637
#   -0.91104486  0.31200429 -0.07108995 -0.89981264  0.30909536 -0.07504597]]
# [[ -35.     -75.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -75.       1.       0.       0.    -110.     -60.   ]]
# (398580, 96) (398580, 7) training data size
# (132861, 96) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_25 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_26 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12456/12456 - 106s - loss: 0.1030 - val_loss: 0.0977
# Epoch 2/10
# 12456/12456 - 75s - loss: 0.0706 - val_loss: 0.1024
# Epoch 3/10
# 12456/12456 - 113s - loss: 0.0625 - val_loss: 0.0954
# Epoch 4/10
# 12456/12456 - 115s - loss: 0.0574 - val_loss: 0.1037
# Epoch 5/10
# 12456/12456 - 119s - loss: 0.0537 - val_loss: 0.1053
# Epoch 6/10
# 12456/12456 - 119s - loss: 0.0498 - val_loss: 0.0958
# Epoch 7/10
# 12456/12456 - 121s - loss: 0.0457 - val_loss: 0.0914
# Epoch 8/10
# 12456/12456 - 117s - loss: 0.0428 - val_loss: 0.0965
# Epoch 9/10
# 12456/12456 - 111s - loss: 0.0404 - val_loss: 0.1062
# Epoch 10/10
# 12456/12456 - 111s - loss: 0.0382 - val_loss: 0.1105

# %%
plt.plot(history_9.history['loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training Loss for lr_10_32','Validation Loss for lr_10_32'], loc='upper right')
plt.show()
