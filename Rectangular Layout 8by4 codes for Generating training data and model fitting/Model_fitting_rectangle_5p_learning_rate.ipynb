# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm


input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam")
model.summary()
history_9 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense (Dense)                (None, 700)               67900
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 4s - loss: 0.1903 - val_loss: 0.1620
# Epoch 2/30
# 367/367 - 4s - loss: 0.1460 - val_loss: 0.1366
# Epoch 3/30
# 367/367 - 3s - loss: 0.1277 - val_loss: 0.1259
# Epoch 4/30
# 367/367 - 4s - loss: 0.1170 - val_loss: 0.1194
# Epoch 5/30
# 367/367 - 3s - loss: 0.1092 - val_loss: 0.1192
# Epoch 6/30
# 367/367 - 3s - loss: 0.1029 - val_loss: 0.1416
# Epoch 7/30
# 367/367 - 3s - loss: 0.0978 - val_loss: 0.1259
# Epoch 8/30
# 367/367 - 4s - loss: 0.0935 - val_loss: 0.1088
# Epoch 9/30
# 367/367 - 3s - loss: 0.0887 - val_loss: 0.1073
# Epoch 10/30
# 367/367 - 3s - loss: 0.0863 - val_loss: 0.1074
# Epoch 11/30
# 367/367 - 2s - loss: 0.0858 - val_loss: 0.0984
# Epoch 12/30
# 367/367 - 3s - loss: 0.0828 - val_loss: 0.1001
# Epoch 13/30
# 367/367 - 3s - loss: 0.0810 - val_loss: 0.1102
# Epoch 14/30
# 367/367 - 3s - loss: 0.0788 - val_loss: 0.0931
# Epoch 15/30
# 367/367 - 4s - loss: 0.0775 - val_loss: 0.1001
# Epoch 16/30
# 367/367 - 3s - loss: 0.0766 - val_loss: 0.0921
# Epoch 17/30
# 367/367 - 4s - loss: 0.0752 - val_loss: 0.0898
# Epoch 18/30
# 367/367 - 3s - loss: 0.0731 - val_loss: 0.0898
# Epoch 19/30
# 367/367 - 4s - loss: 0.0728 - val_loss: 0.1076
# Epoch 20/30
# 367/367 - 3s - loss: 0.0722 - val_loss: 0.0952
# Epoch 21/30
# 367/367 - 3s - loss: 0.0700 - val_loss: 0.0915
# Epoch 22/30
# 367/367 - 4s - loss: 0.0697 - val_loss: 0.0987
# Epoch 23/30
# 367/367 - 3s - loss: 0.0705 - val_loss: 0.0960
# Epoch 24/30
# 367/367 - 3s - loss: 0.0671 - val_loss: 0.0817
# Epoch 25/30
# 367/367 - 3s - loss: 0.0661 - val_loss: 0.1042
# Epoch 26/30
# 367/367 - 3s - loss: 0.0676 - val_loss: 0.0972
# Epoch 27/30
# 367/367 - 3s - loss: 0.0661 - val_loss: 0.0842
# Epoch 28/30
# 367/367 - 3s - loss: 0.0648 - val_loss: 0.0833
# Epoch 29/30
# 367/367 - 3s - loss: 0.0655 - val_loss: 0.1020
# Epoch 30/30
# 367/367 - 3s - loss: 0.0641 - val_loss: 0.1003

# %%
##for 0.1 lr
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate 0.1
#
opt = keras.optimizers.Adam(learning_rate=0.1)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               67900
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 4s - loss: 5.1466 - val_loss: 0.2909
# Epoch 2/30
# 367/367 - 4s - loss: 0.2921 - val_loss: 0.2890
# Epoch 3/30
# 367/367 - 3s - loss: 0.2926 - val_loss: 0.2931
# Epoch 4/30
# 367/367 - 3s - loss: 0.2924 - val_loss: 0.2910
# Epoch 5/30
# 367/367 - 3s - loss: 0.2925 - val_loss: 0.2922
# Epoch 6/30
# 367/367 - 3s - loss: 0.2924 - val_loss: 0.2959
# Epoch 7/30
# 367/367 - 3s - loss: 0.2937 - val_loss: 0.2916
# Epoch 8/30
# 367/367 - 3s - loss: 0.2920 - val_loss: 0.2933
# Epoch 9/30
# 367/367 - 4s - loss: 0.2932 - val_loss: 0.2927
# Epoch 10/30
# 367/367 - 4s - loss: 0.2932 - val_loss: 0.2931
# Epoch 11/30
# 367/367 - 4s - loss: 0.2916 - val_loss: 0.2946
# Epoch 12/30
# 367/367 - 3s - loss: 0.2919 - val_loss: 0.2947
# Epoch 13/30
# 367/367 - 2s - loss: 0.2929 - val_loss: 0.2947
# Epoch 14/30
# 367/367 - 3s - loss: 0.2933 - val_loss: 0.2895
# Epoch 15/30
# 367/367 - 4s - loss: 0.2926 - val_loss: 0.2894
# Epoch 16/30
# 367/367 - 4s - loss: 0.2933 - val_loss: 0.2915
# Epoch 17/30
# 367/367 - 3s - loss: 0.2923 - val_loss: 0.2941
# Epoch 18/30
# 367/367 - 4s - loss: 0.2932 - val_loss: 0.2918
# Epoch 19/30
# 367/367 - 4s - loss: 0.2936 - val_loss: 0.2989
# Epoch 20/30
# 367/367 - 5s - loss: 0.2922 - val_loss: 0.2888
# Epoch 21/30
# 367/367 - 5s - loss: 0.2927 - val_loss: 0.2950
# Epoch 22/30
# 367/367 - 5s - loss: 0.2929 - val_loss: 0.2916
# Epoch 23/30
# 367/367 - 6s - loss: 0.2929 - val_loss: 0.2944
# Epoch 24/30
# 367/367 - 6s - loss: 0.2929 - val_loss: 0.2986
# Epoch 25/30
# 367/367 - 6s - loss: 0.2933 - val_loss: 0.2939
# Epoch 26/30
# 367/367 - 6s - loss: 0.2932 - val_loss: 0.2901
# Epoch 27/30
# 367/367 - 6s - loss: 0.2930 - val_loss: 0.2943
# Epoch 28/30
# 367/367 - 6s - loss: 0.2931 - val_loss: 0.2932
# Epoch 29/30
# 367/367 - 5s - loss: 0.2924 - val_loss: 0.2956
# Epoch 30/30
# 367/367 - 4s - loss: 0.2925 - val_loss: 0.2944

# %%
##for 0.01
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               67900
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 6s - loss: 0.2324 - val_loss: 0.1773
# Epoch 2/30
# 367/367 - 6s - loss: 0.1653 - val_loss: 0.1628
# Epoch 3/30
# 367/367 - 6s - loss: 0.1464 - val_loss: 0.1512
# Epoch 4/30
# 367/367 - 6s - loss: 0.1327 - val_loss: 0.1536
# Epoch 5/30
# 367/367 - 5s - loss: 0.1287 - val_loss: 0.1263
# Epoch 6/30
# 367/367 - 5s - loss: 0.1201 - val_loss: 0.1274
# Epoch 7/30
# 367/367 - 6s - loss: 0.1178 - val_loss: 0.1159
# Epoch 8/30
# 367/367 - 6s - loss: 0.1150 - val_loss: 0.1226
# Epoch 9/30
# 367/367 - 6s - loss: 0.1132 - val_loss: 0.1330
# Epoch 10/30
# 367/367 - 6s - loss: 0.1112 - val_loss: 0.1195
# Epoch 11/30
# 367/367 - 6s - loss: 0.1118 - val_loss: 0.1121
# Epoch 12/30
# 367/367 - 6s - loss: 0.1080 - val_loss: 0.1463
# Epoch 13/30
# 367/367 - 5s - loss: 0.1068 - val_loss: 0.1250
# Epoch 14/30
# 367/367 - 4s - loss: 0.1070 - val_loss: 0.1116
# Epoch 15/30
# 367/367 - 4s - loss: 0.1060 - val_loss: 0.1159
# Epoch 16/30
# 367/367 - 5s - loss: 0.1048 - val_loss: 0.1040
# Epoch 17/30
# 367/367 - 5s - loss: 0.1009 - val_loss: 0.1254
# Epoch 18/30
# 367/367 - 5s - loss: 0.1031 - val_loss: 0.1136
# Epoch 19/30
# 367/367 - 5s - loss: 0.1012 - val_loss: 0.0977
# Epoch 20/30
# 367/367 - 5s - loss: 0.0995 - val_loss: 0.1209
# Epoch 21/30
# 367/367 - 4s - loss: 0.1009 - val_loss: 0.1043
# Epoch 22/30
# 367/367 - 5s - loss: 0.0973 - val_loss: 0.1210
# Epoch 23/30
# 367/367 - 5s - loss: 0.0985 - val_loss: 0.1070
# Epoch 24/30
# 367/367 - 5s - loss: 0.0990 - val_loss: 0.1159
# Epoch 25/30
# 367/367 - 5s - loss: 0.0978 - val_loss: 0.1121
# Epoch 26/30
# 367/367 - 5s - loss: 0.0994 - val_loss: 0.1042
# Epoch 27/30
# 367/367 - 5s - loss: 0.0987 - val_loss: 0.1236
# Epoch 28/30
# 367/367 - 5s - loss: 0.0978 - val_loss: 0.1178
# Epoch 29/30
# 367/367 - 5s - loss: 0.0973 - val_loss: 0.1114
# Epoch 30/30
# 367/367 - 4s - loss: 0.0970 - val_loss: 0.1086

# %%
##for 0.001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 700)               67900
# _________________________________________________________________
# dense_10 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 7s - loss: 0.1873 - val_loss: 0.1678
# Epoch 2/30
# 367/367 - 5s - loss: 0.1444 - val_loss: 0.1335
# Epoch 3/30
# 367/367 - 5s - loss: 0.1283 - val_loss: 0.1310
# Epoch 4/30
# 367/367 - 5s - loss: 0.1164 - val_loss: 0.1197
# Epoch 5/30
# 367/367 - 6s - loss: 0.1091 - val_loss: 0.1118
# Epoch 6/30
# 367/367 - 5s - loss: 0.1013 - val_loss: 0.1026
# Epoch 7/30
# 367/367 - 5s - loss: 0.0956 - val_loss: 0.1005
# Epoch 8/30
# 367/367 - 5s - loss: 0.0916 - val_loss: 0.0930
# Epoch 9/30
# 367/367 - 6s - loss: 0.0903 - val_loss: 0.0922
# Epoch 10/30
# 367/367 - 5s - loss: 0.0865 - val_loss: 0.0926
# Epoch 11/30
# 367/367 - 5s - loss: 0.0840 - val_loss: 0.0829
# Epoch 12/30
# 367/367 - 6s - loss: 0.0821 - val_loss: 0.0900
# Epoch 13/30
# 367/367 - 5s - loss: 0.0802 - val_loss: 0.0912
# Epoch 14/30
# 367/367 - 4s - loss: 0.0790 - val_loss: 0.0850
# Epoch 15/30
# 367/367 - 5s - loss: 0.0775 - val_loss: 0.1013
# Epoch 16/30
# 367/367 - 5s - loss: 0.0765 - val_loss: 0.0895
# Epoch 17/30
# 367/367 - 5s - loss: 0.0763 - val_loss: 0.0776
# Epoch 18/30
# 367/367 - 6s - loss: 0.0744 - val_loss: 0.0836
# Epoch 19/30
# 367/367 - 5s - loss: 0.0718 - val_loss: 0.0827
# Epoch 20/30
# 367/367 - 5s - loss: 0.0721 - val_loss: 0.0889
# Epoch 21/30
# 367/367 - 5s - loss: 0.0717 - val_loss: 0.0828
# Epoch 22/30
# 367/367 - 4s - loss: 0.0695 - val_loss: 0.0876
# Epoch 23/30
# 367/367 - 5s - loss: 0.0698 - val_loss: 0.0729
# Epoch 24/30
# 367/367 - 5s - loss: 0.0683 - val_loss: 0.0925
# Epoch 25/30
# 367/367 - 6s - loss: 0.0665 - val_loss: 0.0779
# Epoch 26/30
# 367/367 - 5s - loss: 0.0672 - val_loss: 0.0717
# Epoch 27/30
# 367/367 - 5s - loss: 0.0656 - val_loss: 0.0730
# Epoch 28/30
# 367/367 - 5s - loss: 0.0652 - val_loss: 0.0830
# Epoch 29/30
# 367/367 - 5s - loss: 0.0634 - val_loss: 0.0775
# Epoch 30/30
# 367/367 - 4s - loss: 0.0638 - val_loss: 0.0793

# %%
##for 0.0001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_13 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 7s - loss: 0.2113 - val_loss: 0.1784
# Epoch 2/30
# 367/367 - 5s - loss: 0.1651 - val_loss: 0.1630
# Epoch 3/30
# 367/367 - 6s - loss: 0.1505 - val_loss: 0.1478
# Epoch 4/30
# 367/367 - 6s - loss: 0.1402 - val_loss: 0.1418
# Epoch 5/30
# 367/367 - 6s - loss: 0.1320 - val_loss: 0.1372
# Epoch 6/30
# 367/367 - 5s - loss: 0.1264 - val_loss: 0.1384
# Epoch 7/30
# 367/367 - 5s - loss: 0.1213 - val_loss: 0.1295
# Epoch 8/30
# 367/367 - 5s - loss: 0.1169 - val_loss: 0.1217
# Epoch 9/30
# 367/367 - 5s - loss: 0.1138 - val_loss: 0.1219
# Epoch 10/30
# 367/367 - 5s - loss: 0.1103 - val_loss: 0.1220
# Epoch 11/30
# 367/367 - 5s - loss: 0.1077 - val_loss: 0.1136
# Epoch 12/30
# 367/367 - 5s - loss: 0.1047 - val_loss: 0.1267
# Epoch 13/30
# 367/367 - 4s - loss: 0.1022 - val_loss: 0.1173
# Epoch 14/30
# 367/367 - 4s - loss: 0.1003 - val_loss: 0.1254
# Epoch 15/30
# 367/367 - 4s - loss: 0.0977 - val_loss: 0.1176
# Epoch 16/30
# 367/367 - 5s - loss: 0.0957 - val_loss: 0.1161
# Epoch 17/30
# 367/367 - 5s - loss: 0.0936 - val_loss: 0.1199
# Epoch 18/30
# 367/367 - 5s - loss: 0.0922 - val_loss: 0.1149
# Epoch 19/30
# 367/367 - 5s - loss: 0.0911 - val_loss: 0.1157
# Epoch 20/30
# 367/367 - 6s - loss: 0.0891 - val_loss: 0.1215
# Epoch 21/30
# 367/367 - 5s - loss: 0.0871 - val_loss: 0.1160
# Epoch 22/30
# 367/367 - 5s - loss: 0.0863 - val_loss: 0.1209
# Epoch 23/30
# 367/367 - 5s - loss: 0.0846 - val_loss: 0.1204
# Epoch 24/30
# 367/367 - 5s - loss: 0.0837 - val_loss: 0.1164
# Epoch 25/30
# 367/367 - 5s - loss: 0.0826 - val_loss: 0.1087
# Epoch 26/30
# 367/367 - 5s - loss: 0.0808 - val_loss: 0.1197
# Epoch 27/30
# 367/367 - 5s - loss: 0.0811 - val_loss: 0.1121
# Epoch 28/30
# 367/367 - 5s - loss: 0.0796 - val_loss: 0.1216
# Epoch 29/30
# 367/367 - 5s - loss: 0.0782 - val_loss: 0.1204
# Epoch 30/30
# 367/367 - 4s - loss: 0.0779 - val_loss: 0.1091

# %%
##for lr scheduler 5epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 6s - loss: 0.1902 - val_loss: 0.1581
# Epoch 2/30
# 367/367 - 6s - loss: 0.1449 - val_loss: 0.1608
# Epoch 3/30
# 367/367 - 5s - loss: 0.1300 - val_loss: 0.1261
# Epoch 4/30
# 367/367 - 6s - loss: 0.1189 - val_loss: 0.1107
# Epoch 5/30
# 367/367 - 5s - loss: 0.1100 - val_loss: 0.1172
# Epoch 6/30
# 367/367 - 5s - loss: 0.1004 - val_loss: 0.1192
# Epoch 7/30
# 367/367 - 5s - loss: 0.0945 - val_loss: 0.0949
# Epoch 8/30
# 367/367 - 5s - loss: 0.0895 - val_loss: 0.0976
# Epoch 9/30
# 367/367 - 5s - loss: 0.0859 - val_loss: 0.0928
# Epoch 10/30
# 367/367 - 5s - loss: 0.0803 - val_loss: 0.0903
# Epoch 11/30
# 367/367 - 5s - loss: 0.0774 - val_loss: 0.0850
# Epoch 12/30
# 367/367 - 5s - loss: 0.0743 - val_loss: 0.0831
# Epoch 13/30
# 367/367 - 6s - loss: 0.0714 - val_loss: 0.0830
# Epoch 14/30
# 367/367 - 5s - loss: 0.0702 - val_loss: 0.0797
# Epoch 15/30
# 367/367 - 4s - loss: 0.0673 - val_loss: 0.0766
# Epoch 16/30
# 367/367 - 5s - loss: 0.0655 - val_loss: 0.0753
# Epoch 17/30
# 367/367 - 6s - loss: 0.0638 - val_loss: 0.0774
# Epoch 18/30
# 367/367 - 6s - loss: 0.0624 - val_loss: 0.0751
# Epoch 19/30
# 367/367 - 6s - loss: 0.0613 - val_loss: 0.0764
# Epoch 20/30
# 367/367 - 6s - loss: 0.0598 - val_loss: 0.0759
# Epoch 21/30
# 367/367 - 6s - loss: 0.0587 - val_loss: 0.0754
# Epoch 22/30
# 367/367 - 6s - loss: 0.0578 - val_loss: 0.0710
# Epoch 23/30
# 367/367 - 6s - loss: 0.0563 - val_loss: 0.0685
# Epoch 24/30
# 367/367 - 6s - loss: 0.0556 - val_loss: 0.0700
# Epoch 25/30
# 367/367 - 6s - loss: 0.0550 - val_loss: 0.0729
# Epoch 26/30
# 367/367 - 6s - loss: 0.0541 - val_loss: 0.0730
# Epoch 27/30
# 367/367 - 6s - loss: 0.0536 - val_loss: 0.0689
# Epoch 28/30
# 367/367 - 6s - loss: 0.0528 - val_loss: 0.0715
# Epoch 29/30
# 367/367 - 5s - loss: 0.0523 - val_loss: 0.0715
# Epoch 30/30
# 367/367 - 5s - loss: 0.0515 - val_loss: 0.0708

# %%
##for for lr scheduler 10epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_19 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 7s - loss: 0.1879 - val_loss: 0.1611
# Epoch 2/30
# 367/367 - 5s - loss: 0.1441 - val_loss: 0.1515
# Epoch 3/30
# 367/367 - 5s - loss: 0.1288 - val_loss: 0.1205
# Epoch 4/30
# 367/367 - 5s - loss: 0.1178 - val_loss: 0.1114
# Epoch 5/30
# 367/367 - 5s - loss: 0.1093 - val_loss: 0.1033
# Epoch 6/30
# 367/367 - 6s - loss: 0.1026 - val_loss: 0.1055
# Epoch 7/30
# 367/367 - 7s - loss: 0.0958 - val_loss: 0.1207
# Epoch 8/30
# 367/367 - 5s - loss: 0.0915 - val_loss: 0.1066
# Epoch 9/30
# 367/367 - 5s - loss: 0.0903 - val_loss: 0.0928
# Epoch 10/30
# 367/367 - 5s - loss: 0.0865 - val_loss: 0.0911
# Epoch 11/30
# 367/367 - 5s - loss: 0.0828 - val_loss: 0.0859
# Epoch 12/30
# 367/367 - 5s - loss: 0.0789 - val_loss: 0.0811
# Epoch 13/30
# 367/367 - 5s - loss: 0.0746 - val_loss: 0.0736
# Epoch 14/30
# 367/367 - 4s - loss: 0.0723 - val_loss: 0.0787
# Epoch 15/30
# 367/367 - 4s - loss: 0.0705 - val_loss: 0.0896
# Epoch 16/30
# 367/367 - 4s - loss: 0.0678 - val_loss: 0.0690
# Epoch 17/30
# 367/367 - 5s - loss: 0.0656 - val_loss: 0.0780
# Epoch 18/30
# 367/367 - 6s - loss: 0.0632 - val_loss: 0.0698
# Epoch 19/30
# 367/367 - 6s - loss: 0.0623 - val_loss: 0.0772
# Epoch 20/30
# 367/367 - 5s - loss: 0.0605 - val_loss: 0.0786
# Epoch 21/30
# 367/367 - 4s - loss: 0.0599 - val_loss: 0.0738
# Epoch 22/30
# 367/367 - 4s - loss: 0.0570 - val_loss: 0.0740
# Epoch 23/30
# 367/367 - 4s - loss: 0.0559 - val_loss: 0.0741
# Epoch 24/30
# 367/367 - 4s - loss: 0.0548 - val_loss: 0.0705
# Epoch 25/30
# 367/367 - 4s - loss: 0.0538 - val_loss: 0.0758
# Epoch 26/30
# 367/367 - 4s - loss: 0.0525 - val_loss: 0.0759
# Epoch 27/30
# 367/367 - 4s - loss: 0.0514 - val_loss: 0.0672
# Epoch 28/30
# 367/367 - 4s - loss: 0.0508 - val_loss: 0.0742
# Epoch 29/30
# 367/367 - 4s - loss: 0.0496 - val_loss: 0.0746
# Epoch 30/30
# 367/367 - 3s - loss: 0.0489 - val_loss: 0.0758

# %%
##for 7p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 15:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_7 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_22 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 3s - loss: 0.1919 - val_loss: 0.1583
# Epoch 2/30
# 367/367 - 3s - loss: 0.1471 - val_loss: 0.1369
# Epoch 3/30
# 367/367 - 4s - loss: 0.1298 - val_loss: 0.1198
# Epoch 4/30
# 367/367 - 4s - loss: 0.1185 - val_loss: 0.1241
# Epoch 5/30
# 367/367 - 4s - loss: 0.1099 - val_loss: 0.1166
# Epoch 6/30
# 367/367 - 3s - loss: 0.1031 - val_loss: 0.1125
# Epoch 7/30
# 367/367 - 3s - loss: 0.0987 - val_loss: 0.1139
# Epoch 8/30
# 367/367 - 3s - loss: 0.0936 - val_loss: 0.1039
# Epoch 9/30
# 367/367 - 3s - loss: 0.0916 - val_loss: 0.0985
# Epoch 10/30
# 367/367 - 3s - loss: 0.0880 - val_loss: 0.1040
# Epoch 11/30
# 367/367 - 3s - loss: 0.0849 - val_loss: 0.1152
# Epoch 12/30
# 367/367 - 3s - loss: 0.0834 - val_loss: 0.1154
# Epoch 13/30
# 367/367 - 3s - loss: 0.0815 - val_loss: 0.0884
# Epoch 14/30
# 367/367 - 3s - loss: 0.0785 - val_loss: 0.1054
# Epoch 15/30
# 367/367 - 3s - loss: 0.0774 - val_loss: 0.1057
# Epoch 16/30
# 367/367 - 3s - loss: 0.0746 - val_loss: 0.1001
# Epoch 17/30
# 367/367 - 3s - loss: 0.0721 - val_loss: 0.1097
# Epoch 18/30
# 367/367 - 4s - loss: 0.0703 - val_loss: 0.1045
# Epoch 19/30
# 367/367 - 3s - loss: 0.0679 - val_loss: 0.1043
# Epoch 20/30
# 367/367 - 3s - loss: 0.0656 - val_loss: 0.0986
# Epoch 21/30
# 367/367 - 3s - loss: 0.0627 - val_loss: 0.1019
# Epoch 22/30
# 367/367 - 3s - loss: 0.0621 - val_loss: 0.0993
# Epoch 23/30
# 367/367 - 3s - loss: 0.0602 - val_loss: 0.0949
# Epoch 24/30
# 367/367 - 3s - loss: 0.0581 - val_loss: 0.0978
# Epoch 25/30
# 367/367 - 3s - loss: 0.0565 - val_loss: 0.0999
# Epoch 26/30
# 367/367 - 3s - loss: 0.0557 - val_loss: 0.0974
# Epoch 27/30
# 367/367 - 3s - loss: 0.0534 - val_loss: 0.1008
# Epoch 28/30
# 367/367 - 3s - loss: 0.0526 - val_loss: 0.0947
# Epoch 29/30
# 367/367 - 3s - loss: 0.0517 - val_loss: 0.1032
# Epoch 30/30
# 367/367 - 3s - loss: 0.0507 - val_loss: 0.0991

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_32_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_32_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(96,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_8 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.90965233  0.27064548 -0.04445391 -0.90649118  0.26990264 -0.0409652
#   -0.90488287  0.27233149 -0.03712486 -0.9048223   0.27776076 -0.03444051
#   -0.90542503  0.2848387  -0.03403024 -0.90549049  0.29175066 -0.03598224
#   -0.90423704  0.29716067 -0.03950412 -0.90155666  0.30059259 -0.04355965
#   -0.91822093  0.27154273 -0.04958113 -0.91365757  0.26936134 -0.04566913
#   -0.91119762  0.2717112  -0.04071127 -0.91109969  0.27865617 -0.03728775
#   -0.91183152  0.28784008 -0.03734279 -0.91135768  0.29613792 -0.04071516
#   -0.90872156  0.30171258 -0.04574706 -0.90421765  0.30439565 -0.05078057
#   -0.93039662  0.27395498 -0.05607436 -0.92362656  0.26909214 -0.05217368
#   -0.9195755   0.27080072 -0.04558855 -0.91939636  0.28011407 -0.04102144
#   -0.92017592  0.29250477 -0.04219268 -0.91827132  0.30221073 -0.04800913
#   -0.91293941  0.30708172 -0.05496911 -0.90555755  0.30804543 -0.06068846
#   -0.9488398   0.27977635 -0.06382377 -0.93883182  0.27000495 -0.06162218
#   -0.93148948  0.26939003 -0.0527648  -0.93109606  0.28276686 -0.04627309
#   -0.93138502  0.30019267 -0.05025172 -0.92564896  0.31033192 -0.06014141
#   -0.9152279   0.31247    -0.06881425 -0.90376872  0.3103305  -0.07396979]
#  [-0.90722744  0.26981342 -0.04201799 -0.90515294  0.27133336 -0.03813039
#   -0.90472272  0.276029   -0.03498327 -0.90526462  0.28283408 -0.03389091
#   -0.90558343  0.28995839 -0.03524525 -0.90473057  0.29586497 -0.03844037
#   -0.902421    0.29984395 -0.04244341 -0.89890951  0.301929   -0.04637044
#   -0.91475502  0.26956952 -0.046939   -0.91161457  0.2705619  -0.04203843
#   -0.91095321  0.27638832 -0.03793141 -0.91167498  0.28528167 -0.03695024
#   -0.9116902   0.29408407 -0.03954092 -0.90966148  0.30048461 -0.04430433
#   -0.90559762  0.30391257 -0.0494635  -0.9002477   0.30492281 -0.05387885
#   -0.92534565  0.26993304 -0.05364559 -0.92027768  0.26951244 -0.04743205
#   -0.91916702  0.27697293 -0.04178375 -0.92011508  0.28916698 -0.04127813
#   -0.91916324  0.30000982 -0.04614926 -0.91468375  0.30620068 -0.05311371
#   -0.90769468  0.30807176 -0.05930213 -0.89981692  0.30725171 -0.06362846
#   -0.94163734  0.27220657 -0.06302544 -0.93283109  0.26812508 -0.0555025
#   -0.9307068   0.27803678 -0.04713083 -0.93178053  0.29583978 -0.04820027
#   -0.92785398  0.30846783 -0.05732346 -0.91833186  0.31246824 -0.06676218
#   -0.90687161  0.3111531  -0.07289313 -0.89604584  0.30775955 -0.07578164]]
# [[ -35.    -75.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -75.      1.      0.      0.   -110.    -60.  ]]
# (11718, 96) (11718, 7) training data size
# (3907, 96) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 96)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 700)               67900
# _________________________________________________________________
# dense_25 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_26 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 563,507
# Trainable params: 563,507
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 3s - loss: 0.1871 - val_loss: 0.1565
# Epoch 2/30
# 367/367 - 2s - loss: 0.1437 - val_loss: 0.1352
# Epoch 3/30
# 367/367 - 2s - loss: 0.1255 - val_loss: 0.1265
# Epoch 4/30
# 367/367 - 2s - loss: 0.1168 - val_loss: 0.1174
# Epoch 5/30
# 367/367 - 2s - loss: 0.1081 - val_loss: 0.1090
# Epoch 6/30
# 367/367 - 2s - loss: 0.1025 - val_loss: 0.1087
# Epoch 7/30
# 367/367 - 2s - loss: 0.0954 - val_loss: 0.1046
# Epoch 8/30
# 367/367 - 2s - loss: 0.0911 - val_loss: 0.0940
# Epoch 9/30
# 367/367 - 2s - loss: 0.0887 - val_loss: 0.0967
# Epoch 10/30
# 367/367 - 2s - loss: 0.0863 - val_loss: 0.0931
# Epoch 11/30
# 367/367 - 2s - loss: 0.0832 - val_loss: 0.0898
# Epoch 12/30
# 367/367 - 2s - loss: 0.0823 - val_loss: 0.0912
# Epoch 13/30
# 367/367 - 2s - loss: 0.0805 - val_loss: 0.0945
# Epoch 14/30
# 367/367 - 2s - loss: 0.0783 - val_loss: 0.0883
# Epoch 15/30
# 367/367 - 2s - loss: 0.0783 - val_loss: 0.0886
# Epoch 16/30
# 367/367 - 2s - loss: 0.0763 - val_loss: 0.1047
# Epoch 17/30
# 367/367 - 2s - loss: 0.0765 - val_loss: 0.0975
# Epoch 18/30
# 367/367 - 2s - loss: 0.0738 - val_loss: 0.0876
# Epoch 19/30
# 367/367 - 2s - loss: 0.0731 - val_loss: 0.0905
# Epoch 20/30
# 367/367 - 2s - loss: 0.0717 - val_loss: 0.0930
# Epoch 21/30
# 367/367 - 2s - loss: 0.0692 - val_loss: 0.0941
# Epoch 22/30
# 367/367 - 2s - loss: 0.0664 - val_loss: 0.0927
# Epoch 23/30
# 367/367 - 2s - loss: 0.0638 - val_loss: 0.0876
# Epoch 24/30
# 367/367 - 2s - loss: 0.0617 - val_loss: 0.0847
# Epoch 25/30
# 367/367 - 2s - loss: 0.0594 - val_loss: 0.0970
# Epoch 26/30
# 367/367 - 2s - loss: 0.0579 - val_loss: 0.0835
# Epoch 27/30
# 367/367 - 2s - loss: 0.0563 - val_loss: 0.0691
# Epoch 28/30
# 367/367 - 2s - loss: 0.0545 - val_loss: 0.1059
# Epoch 29/30
# 367/367 - 2s - loss: 0.0525 - val_loss: 0.0920
# Epoch 30/30
# 367/367 - 2s - loss: 0.0512 - val_loss: 0.0940

# %%
#plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#lgd=plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.06,0.25)
plt.xticks(np.arange(0.0, 31, 2))
plt.yticks(np.arange(0.06, 0.25, 0.02))
plt.savefig('Validation_Loss_for_lr_8by4.png', dpi=1200)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7b933499f0c4> in <module>
#       1 #plt.plot(history_1.history['val_loss'])
# ----> 2 plt.plot(history_2.history['val_loss'])
#       3 plt.plot(history_3.history['val_loss'])
#       4 plt.plot(history_4.history['val_loss'])
#       5 plt.plot(history_5.history['val_loss'])
#
# NameError: name 'plt' is not defined

# %%
#plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.04,0.25)
plt.xticks(np.arange(0.0, 31, 2))
plt.yticks(np.arange(0.04, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_8by4.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.1','lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.05,)
plt.xticks(np.arange(0.0, 31, 2))
plt.yticks(np.arange(0.05, 0.31, 0.05))
plt.savefig('Validation_Loss_for_lr_1_8by4.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.1','lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.0,)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_1_8by4.png', dpi=1200)
plt.show()
