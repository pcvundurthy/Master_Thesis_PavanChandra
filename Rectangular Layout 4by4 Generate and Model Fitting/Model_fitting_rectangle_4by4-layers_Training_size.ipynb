# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_4.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_4.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96599853  0.27606791 -0.07565659 -0.95086392  0.26695474 -0.06533805
#   -0.94930712  0.28749528 -0.05464469 -0.94653851  0.31281185 -0.06572685
#   -1.02090166  0.29927989 -0.09043877 -0.99077126  0.26520123 -0.09134644
#   -0.98375094  0.30325434 -0.07242409 -0.95978485  0.33228947 -0.10427239
#   -1.11885836  0.35967639 -0.059538   -1.15987075  0.32063895 -0.15402077
#   -1.05699218  0.37419412 -0.17750612 -0.91324645  0.32098244 -0.18743819
#   -0.54780831  0.19032361 -0.059538   -0.50679591  0.22936105 -0.15402077
#   -0.60967449  0.17580588 -0.17750612 -0.75342021  0.22901756 -0.18743819]]
# [[ -35.          -35.            1.            0.            0.
#   -110.          -60.        ]
#  [ -25.33333333  -35.            1.            0.            0.
#   -110.          -60.        ]]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
# Out:
# (3072, 48) (3072, 7) training data size
# (1024, 48) (1024, 7) Validation data size

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm


input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])
#metrics=['accuracy']
##Implementing Early stopping

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()
# Out:
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense (Dense)                (None, 700)               34300
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________

# %%
#from keras.utils import plot_model
#keras.utils.plot_model(model)
#plot_model(model, to_file='Model_Architecture_9p.png', dpi=1200, show_shapes=True, show_layer_names=True)

# %%
history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=2, validation_data=(xval_scale,yval_scale))
#history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=1, callbacks=my_callbacks, validation_data=(xval_scale,yval_scale))
# Out:
# Epoch 1/20
# 96/96 - 1s - loss: 0.2390 - mean_absolute_error: 0.2390 - val_loss: 0.2042 - val_mean_absolute_error: 0.2042
# Epoch 2/20
# 96/96 - 1s - loss: 0.1892 - mean_absolute_error: 0.1892 - val_loss: 0.1818 - val_mean_absolute_error: 0.1818
# Epoch 3/20
# 96/96 - 1s - loss: 0.1711 - mean_absolute_error: 0.1711 - val_loss: 0.1678 - val_mean_absolute_error: 0.1678
# Epoch 4/20
# 96/96 - 1s - loss: 0.1565 - mean_absolute_error: 0.1565 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 5/20
# 96/96 - 1s - loss: 0.1509 - mean_absolute_error: 0.1509 - val_loss: 0.1539 - val_mean_absolute_error: 0.1539
# Epoch 6/20
# 96/96 - 1s - loss: 0.1425 - mean_absolute_error: 0.1425 - val_loss: 0.1514 - val_mean_absolute_error: 0.1514
# Epoch 7/20
# 96/96 - 1s - loss: 0.1437 - mean_absolute_error: 0.1437 - val_loss: 0.1478 - val_mean_absolute_error: 0.1478
# Epoch 8/20
# 96/96 - 1s - loss: 0.1323 - mean_absolute_error: 0.1323 - val_loss: 0.1427 - val_mean_absolute_error: 0.1427
# Epoch 9/20
# 96/96 - 1s - loss: 0.1296 - mean_absolute_error: 0.1296 - val_loss: 0.1346 - val_mean_absolute_error: 0.1346
# Epoch 10/20
# 96/96 - 1s - loss: 0.1244 - mean_absolute_error: 0.1244 - val_loss: 0.1493 - val_mean_absolute_error: 0.1493
# Epoch 11/20
# 96/96 - 1s - loss: 0.1211 - mean_absolute_error: 0.1211 - val_loss: 0.1422 - val_mean_absolute_error: 0.1422
# Epoch 12/20
# 96/96 - 1s - loss: 0.1184 - mean_absolute_error: 0.1184 - val_loss: 0.1324 - val_mean_absolute_error: 0.1324
# Epoch 13/20
# 96/96 - 1s - loss: 0.1145 - mean_absolute_error: 0.1145 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219
# Epoch 14/20
# 96/96 - 1s - loss: 0.1119 - mean_absolute_error: 0.1119 - val_loss: 0.1164 - val_mean_absolute_error: 0.1164
# Epoch 15/20
# 96/96 - 1s - loss: 0.1089 - mean_absolute_error: 0.1089 - val_loss: 0.1262 - val_mean_absolute_error: 0.1262
# Epoch 16/20
# 96/96 - 1s - loss: 0.1076 - mean_absolute_error: 0.1076 - val_loss: 0.1123 - val_mean_absolute_error: 0.1123
# Epoch 17/20
# 96/96 - 1s - loss: 0.1077 - mean_absolute_error: 0.1077 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219
# Epoch 18/20
# 96/96 - 1s - loss: 0.1026 - mean_absolute_error: 0.1026 - val_loss: 0.1171 - val_mean_absolute_error: 0.1171
# Epoch 19/20
# 96/96 - 1s - loss: 0.1026 - mean_absolute_error: 0.1026 - val_loss: 0.1110 - val_mean_absolute_error: 0.1110
# Epoch 20/20
# 96/96 - 1s - loss: 0.1010 - mean_absolute_error: 0.1010 - val_loss: 0.1190 - val_mean_absolute_error: 0.1190

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training ', 'Cross-Validation'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Model_Loss_4p_mae.png', dpi=1200)
plt.show()

# %%
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])
#metrics=['accuracy']
##Implementing Early stopping

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=2, validation_data=(xval_scale,yval_scale))
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training ', 'Cross-Validation'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Model_Loss_5p_mae.png', dpi=1200)
plt.show()
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 367/367 - 3s - loss: 0.1884 - mean_absolute_error: 0.1884 - val_loss: 0.1667 - val_mean_absolute_error: 0.1667
# Epoch 2/20
# 367/367 - 3s - loss: 0.1431 - mean_absolute_error: 0.1431 - val_loss: 0.1366 - val_mean_absolute_error: 0.1366
# Epoch 3/20
# 367/367 - 3s - loss: 0.1273 - mean_absolute_error: 0.1273 - val_loss: 0.1254 - val_mean_absolute_error: 0.1254
# Epoch 4/20
# 367/367 - 4s - loss: 0.1162 - mean_absolute_error: 0.1162 - val_loss: 0.1253 - val_mean_absolute_error: 0.1253
# Epoch 5/20
# 367/367 - 4s - loss: 0.1081 - mean_absolute_error: 0.1081 - val_loss: 0.1204 - val_mean_absolute_error: 0.1204
# Epoch 6/20
# 367/367 - 4s - loss: 0.1005 - mean_absolute_error: 0.1005 - val_loss: 0.1028 - val_mean_absolute_error: 0.1028
# Epoch 7/20
# 367/367 - 3s - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.1059 - val_mean_absolute_error: 0.1059
# Epoch 8/20
# 367/367 - 3s - loss: 0.0912 - mean_absolute_error: 0.0912 - val_loss: 0.1067 - val_mean_absolute_error: 0.1067
# Epoch 9/20
# 367/367 - 3s - loss: 0.0877 - mean_absolute_error: 0.0877 - val_loss: 0.1022 - val_mean_absolute_error: 0.1022
# Epoch 10/20
# 367/367 - 3s - loss: 0.0859 - mean_absolute_error: 0.0859 - val_loss: 0.1058 - val_mean_absolute_error: 0.1058
# Epoch 11/20
# 367/367 - 4s - loss: 0.0828 - mean_absolute_error: 0.0828 - val_loss: 0.1000 - val_mean_absolute_error: 0.1000
# Epoch 12/20
# 367/367 - 3s - loss: 0.0795 - mean_absolute_error: 0.0795 - val_loss: 0.0932 - val_mean_absolute_error: 0.0932
# Epoch 13/20
# 367/367 - 3s - loss: 0.0774 - mean_absolute_error: 0.0774 - val_loss: 0.0948 - val_mean_absolute_error: 0.0948
# Epoch 14/20
# 367/367 - 3s - loss: 0.0755 - mean_absolute_error: 0.0755 - val_loss: 0.0870 - val_mean_absolute_error: 0.0870
# Epoch 15/20
# 367/367 - 3s - loss: 0.0741 - mean_absolute_error: 0.0741 - val_loss: 0.0927 - val_mean_absolute_error: 0.0927
# Epoch 16/20
# 367/367 - 4s - loss: 0.0733 - mean_absolute_error: 0.0733 - val_loss: 0.0822 - val_mean_absolute_error: 0.0822
# Epoch 17/20
# 367/367 - 4s - loss: 0.0730 - mean_absolute_error: 0.0730 - val_loss: 0.0811 - val_mean_absolute_error: 0.0811
# Epoch 18/20
# 367/367 - 4s - loss: 0.0711 - mean_absolute_error: 0.0711 - val_loss: 0.0883 - val_mean_absolute_error: 0.0883
# Epoch 19/20
# 367/367 - 4s - loss: 0.0675 - mean_absolute_error: 0.0675 - val_loss: 0.0912 - val_mean_absolute_error: 0.0912
# Epoch 20/20
# 367/367 - 3s - loss: 0.0681 - mean_absolute_error: 0.0681 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832

# %%
##for 6p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_6.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_6.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])
#metrics=['accuracy']
##Implementing Early stopping

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=2, validation_data=(xval_scale,yval_scale))
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training ', 'Cross-Validation'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Model_Loss_6p_mae.png', dpi=1200)
plt.show()
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.97193227  0.28311894 -0.07503682 -0.95575292  0.26763612 -0.0711619
#   -0.94843902  0.27649472 -0.05647182 -0.94931561  0.30501705 -0.05957846
#   -1.02443984  0.30965996 -0.08099909 -1.00460336  0.27637867 -0.09767224
#   -0.98201709  0.27869913 -0.07227972 -0.97407958  0.32913877 -0.09217471
#   -1.09623367  0.3560277  -0.04439676 -1.1578076   0.35485661 -0.10560989
#   -1.09225249  0.29842017 -0.12224508 -0.94862082  0.3393647  -0.19959043
#   -0.570433    0.1939723  -0.04439676 -0.50885907  0.19514339 -0.10560989
#   -0.57441418  0.25157983 -0.12224508 -0.71804585  0.2106353  -0.19959043]]
# [[ -35.   -35.     1.     0.     0.  -110.   -60. ]
#  [ -29.2  -35.     1.     0.     0.  -110.   -60. ]]
# (34992, 48) (34992, 7) training data size
# (11664, 48) (11664, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1094/1094 - 14s - loss: 0.1681 - mean_absolute_error: 0.1681 - val_loss: 0.1425 - val_mean_absolute_error: 0.1425
# Epoch 2/20
# 1094/1094 - 10s - loss: 0.1236 - mean_absolute_error: 0.1236 - val_loss: 0.1280 - val_mean_absolute_error: 0.1280
# Epoch 3/20
# 1094/1094 - 9s - loss: 0.1081 - mean_absolute_error: 0.1081 - val_loss: 0.1179 - val_mean_absolute_error: 0.1179
# Epoch 4/20
# 1094/1094 - 10s - loss: 0.0981 - mean_absolute_error: 0.0981 - val_loss: 0.1136 - val_mean_absolute_error: 0.1136
# Epoch 5/20
# 1094/1094 - 9s - loss: 0.0903 - mean_absolute_error: 0.0903 - val_loss: 0.1186 - val_mean_absolute_error: 0.1186
# Epoch 6/20
# 1094/1094 - 10s - loss: 0.0846 - mean_absolute_error: 0.0846 - val_loss: 0.1265 - val_mean_absolute_error: 0.1265
# Epoch 7/20
# 1094/1094 - 10s - loss: 0.0810 - mean_absolute_error: 0.0810 - val_loss: 0.1186 - val_mean_absolute_error: 0.1186
# Epoch 8/20
# 1094/1094 - 10s - loss: 0.0762 - mean_absolute_error: 0.0762 - val_loss: 0.1368 - val_mean_absolute_error: 0.1368
# Epoch 9/20
# 1094/1094 - 13s - loss: 0.0746 - mean_absolute_error: 0.0746 - val_loss: 0.1157 - val_mean_absolute_error: 0.1157
# Epoch 10/20
# 1094/1094 - 16s - loss: 0.0721 - mean_absolute_error: 0.0721 - val_loss: 0.1105 - val_mean_absolute_error: 0.1105
# Epoch 11/20
# 1094/1094 - 15s - loss: 0.0703 - mean_absolute_error: 0.0703 - val_loss: 0.1198 - val_mean_absolute_error: 0.1198
# Epoch 12/20
# 1094/1094 - 15s - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.1251 - val_mean_absolute_error: 0.1251
# Epoch 13/20
# 1094/1094 - 12s - loss: 0.0672 - mean_absolute_error: 0.0672 - val_loss: 0.1085 - val_mean_absolute_error: 0.1085
# Epoch 14/20
# 1094/1094 - 14s - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.1131 - val_mean_absolute_error: 0.1131
# Epoch 15/20
# 1094/1094 - 15s - loss: 0.0647 - mean_absolute_error: 0.0647 - val_loss: 0.1186 - val_mean_absolute_error: 0.1186
# Epoch 16/20
# 1094/1094 - 18s - loss: 0.0625 - mean_absolute_error: 0.0625 - val_loss: 0.1092 - val_mean_absolute_error: 0.1092
# Epoch 17/20
# 1094/1094 - 18s - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.1164 - val_mean_absolute_error: 0.1164
# Epoch 18/20
# 1094/1094 - 18s - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.1150 - val_mean_absolute_error: 0.1150
# Epoch 19/20
# 1094/1094 - 12s - loss: 0.0587 - mean_absolute_error: 0.0587 - val_loss: 0.1271 - val_mean_absolute_error: 0.1271
# Epoch 20/20
# 1094/1094 - 15s - loss: 0.0578 - mean_absolute_error: 0.0578 - val_loss: 0.1228 - val_mean_absolute_error: 0.1228

# %%
##for 7p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_7.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_7.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])
#metrics=['accuracy']
##Implementing Early stopping

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=2, validation_data=(xval_scale,yval_scale))
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training ', 'Cross-Validation'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Model_Loss_7p_mae.png', dpi=1200)
plt.show()
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.97321774  0.28487344 -0.07453987 -0.95726885  0.26850045 -0.07232388
#   -0.94840786  0.27418931 -0.057514   -0.94963199  0.30258225 -0.05828972
#   -1.02465111  0.3116654  -0.07852802 -1.00796787  0.28013023 -0.09771487
#   -0.98189961  0.27363221 -0.07442115 -0.97692503  0.32693841 -0.08865975
#   -1.09115974  0.35497121 -0.04154939 -1.15242376  0.35775686 -0.09569425
#   -1.09076841  0.26997043 -0.13046033 -0.96096559  0.34532799 -0.2014758
#   -0.57550693  0.19502879 -0.04154939 -0.51424291  0.19224314 -0.09569425
#   -0.57589826  0.28002957 -0.13046033 -0.70570107  0.20467201 -0.2014758 ]]
# [[ -35.          -35.            1.            0.            0.
#   -110.          -60.        ]
#  [ -30.16666667  -35.            1.            0.            0.
#   -110.          -60.        ]]
# (88236, 48) (88236, 7) training data size
# (29413, 48) (29413, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_10 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 2758/2758 - 43s - loss: 0.1415 - mean_absolute_error: 0.1415 - val_loss: 0.1189 - val_mean_absolute_error: 0.1189
# Epoch 2/20
# 2758/2758 - 43s - loss: 0.0981 - mean_absolute_error: 0.0981 - val_loss: 0.1041 - val_mean_absolute_error: 0.1041
# Epoch 3/20
# 2758/2758 - 45s - loss: 0.0832 - mean_absolute_error: 0.0832 - val_loss: 0.0973 - val_mean_absolute_error: 0.0973
# Epoch 4/20
# 2758/2758 - 41s - loss: 0.0758 - mean_absolute_error: 0.0758 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961
# Epoch 5/20
# 2758/2758 - 43s - loss: 0.0709 - mean_absolute_error: 0.0709 - val_loss: 0.0936 - val_mean_absolute_error: 0.0936
# Epoch 6/20
# 2758/2758 - 45s - loss: 0.0675 - mean_absolute_error: 0.0675 - val_loss: 0.0926 - val_mean_absolute_error: 0.0926
# Epoch 7/20
# 2758/2758 - 44s - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.0808 - val_mean_absolute_error: 0.0808
# Epoch 8/20
# 2758/2758 - 53s - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.1088 - val_mean_absolute_error: 0.1088
# Epoch 9/20
# 2758/2758 - 45s - loss: 0.0605 - mean_absolute_error: 0.0605 - val_loss: 0.0998 - val_mean_absolute_error: 0.0998
# Epoch 10/20
# 2758/2758 - 52s - loss: 0.0585 - mean_absolute_error: 0.0585 - val_loss: 0.0953 - val_mean_absolute_error: 0.0953
# Epoch 11/20
# 2758/2758 - 41s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0968 - val_mean_absolute_error: 0.0968
# Epoch 12/20
# 2758/2758 - 48s - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0949 - val_mean_absolute_error: 0.0949
# Epoch 13/20
# 2758/2758 - 48s - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.1055 - val_mean_absolute_error: 0.1055
# Epoch 14/20
# 2758/2758 - 48s - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.1007 - val_mean_absolute_error: 0.1007
# Epoch 15/20
# 2758/2758 - 50s - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0926 - val_mean_absolute_error: 0.0926
# Epoch 16/20
# 2758/2758 - 47s - loss: 0.0519 - mean_absolute_error: 0.0519 - val_loss: 0.0878 - val_mean_absolute_error: 0.0878
# Epoch 17/20
# 2758/2758 - 51s - loss: 0.0511 - mean_absolute_error: 0.0511 - val_loss: 0.0869 - val_mean_absolute_error: 0.0869
# Epoch 18/20
# 2758/2758 - 45s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.0885 - val_mean_absolute_error: 0.0885
# Epoch 19/20
# 2758/2758 - 41s - loss: 0.0495 - mean_absolute_error: 0.0495 - val_loss: 0.0930 - val_mean_absolute_error: 0.0930
# Epoch 20/20
# 2758/2758 - 37s - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.0855 - val_mean_absolute_error: 0.0855

# %%
##for 8p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_8.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_8.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])
#metrics=['accuracy']
##Implementing Early stopping

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=2, validation_data=(xval_scale,yval_scale))
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training ', 'Cross-Validation'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Model_Loss_8p_mae.png', dpi=1200)
plt.show()
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.9740792   0.28610709 -0.07411546 -0.95839672  0.2692544  -0.07305714
#   -0.94846498  0.27270179 -0.05837477 -0.94977004  0.3007404  -0.05746266
#   -1.02466716  0.31296683 -0.07676985 -1.01022897  0.28286214 -0.09740703
#   -0.98210186  0.27058637 -0.07636307 -0.97869309  0.32494291 -0.08611368
#   -1.08767419  0.35420764 -0.03968909 -1.14816328  0.35907906 -0.08932012
#   -1.09413263  0.25857529 -0.14222283 -0.97089051  0.34990919 -0.20220091
#   -0.57899247  0.19579236 -0.03968909 -0.51850339  0.19092094 -0.08932012
#   -0.57253404  0.29142471 -0.14222283 -0.69577615  0.20009081 -0.20220091]]
# [[ -35.          -35.            1.            0.            0.
#   -110.          -60.        ]
#  [ -30.85714286  -35.            1.            0.            0.
#   -110.          -60.        ]]
# (196608, 48) (196608, 7) training data size
# (65536, 48) (65536, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_13 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 6144/6144 - 86s - loss: 0.1237 - mean_absolute_error: 0.1237 - val_loss: 0.1697 - val_mean_absolute_error: 0.1697
# Epoch 2/20
# 6144/6144 - 81s - loss: 0.0848 - mean_absolute_error: 0.0848 - val_loss: 0.1661 - val_mean_absolute_error: 0.1661
# Epoch 3/20
# 6144/6144 - 58s - loss: 0.0731 - mean_absolute_error: 0.0731 - val_loss: 0.1927 - val_mean_absolute_error: 0.1927
# Epoch 4/20
# 6144/6144 - 54s - loss: 0.0667 - mean_absolute_error: 0.0667 - val_loss: 0.1725 - val_mean_absolute_error: 0.1725
# Epoch 5/20
# 6144/6144 - 54s - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.1705 - val_mean_absolute_error: 0.1705
# Epoch 6/20
# 6144/6144 - 54s - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.1532 - val_mean_absolute_error: 0.1532
# Epoch 7/20
# 6144/6144 - 54s - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.1536 - val_mean_absolute_error: 0.1536
# Epoch 8/20
# 6144/6144 - 54s - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.1671 - val_mean_absolute_error: 0.1671
# Epoch 9/20
# 6144/6144 - 53s - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.1573 - val_mean_absolute_error: 0.1573
# Epoch 10/20
# 6144/6144 - 52s - loss: 0.0516 - mean_absolute_error: 0.0516 - val_loss: 0.1496 - val_mean_absolute_error: 0.1496
# Epoch 11/20
# 6144/6144 - 55s - loss: 0.0504 - mean_absolute_error: 0.0504 - val_loss: 0.1460 - val_mean_absolute_error: 0.1460
# Epoch 12/20
# 6144/6144 - 51s - loss: 0.0492 - mean_absolute_error: 0.0492 - val_loss: 0.1510 - val_mean_absolute_error: 0.1510
# Epoch 13/20
# 6144/6144 - 56s - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.1566 - val_mean_absolute_error: 0.1566
# Epoch 14/20
# 6144/6144 - 52s - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.1594 - val_mean_absolute_error: 0.1594
# Epoch 15/20
# 6144/6144 - 56s - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.1474 - val_mean_absolute_error: 0.1474
# Epoch 16/20
# 6144/6144 - 50s - loss: 0.0454 - mean_absolute_error: 0.0454 - val_loss: 0.1523 - val_mean_absolute_error: 0.1523
# Epoch 17/20
# 6144/6144 - 55s - loss: 0.0448 - mean_absolute_error: 0.0448 - val_loss: 0.1513 - val_mean_absolute_error: 0.1513
# Epoch 18/20
# 6144/6144 - 49s - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.1490 - val_mean_absolute_error: 0.1490
# Epoch 19/20
# 6144/6144 - 55s - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.1632 - val_mean_absolute_error: 0.1632
# Epoch 20/20
# 6144/6144 - 51s - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.1538 - val_mean_absolute_error: 0.1538

# %%
##for 9p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_9.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_9.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam", metrics=[tf.keras.metrics.MeanAbsoluteError()])
#metrics=['accuracy']
##Implementing Early stopping

my_callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=20, verbose=2, validation_data=(xval_scale,yval_scale))
plt.plot(history_6.history['loss'])
plt.plot(history_6.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Training ', 'Cross-Validation'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Model_Loss_9p_mae.png', dpi=1200)
plt.show()
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.97469332  0.28701884 -0.07376234 -0.95926109  0.26988649 -0.07355102
#   -0.94855689  0.27168183 -0.05907563 -0.94982826  0.29930869 -0.05690043
#   -1.02461177  0.31387498 -0.07546004 -1.01183089  0.28491046 -0.09700795
#   -0.98244139  0.26866376 -0.07799321 -0.97985826  0.32320343 -0.08421299
#   -1.08513373  0.35363339 -0.03837951 -1.14483208  0.35975165 -0.08490503
#   -1.09989279  0.25630532 -0.15166631 -0.97898757  0.3534858  -0.20228408
#   -0.58153294  0.19636661 -0.03837951 -0.52183458  0.19024835 -0.08490503
#   -0.56677387  0.29369468 -0.15166631 -0.68767909  0.1965142  -0.20228408]]
# [[ -35.     -35.       1.       0.       0.    -110.     -60.   ]
#  [ -31.375  -35.       1.       0.       0.    -110.     -60.   ]]
# (398580, 48) (398580, 7) training data size
# (132861, 48) (132861, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 12456/12456 - 107s - loss: 0.1046 - mean_absolute_error: 0.1046 - val_loss: 0.0897 - val_mean_absolute_error: 0.0897
# Epoch 2/20
# 12456/12456 - 109s - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.0804 - val_mean_absolute_error: 0.0804
# Epoch 3/20
# 12456/12456 - 107s - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.0853 - val_mean_absolute_error: 0.0853
# Epoch 4/20
# 12456/12456 - 76s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0752 - val_mean_absolute_error: 0.0752
# Epoch 5/20
# 12456/12456 - 89s - loss: 0.0544 - mean_absolute_error: 0.0544 - val_loss: 0.0718 - val_mean_absolute_error: 0.0718
# Epoch 6/20
# 12456/12456 - 114s - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715
# Epoch 7/20
# 12456/12456 - 115s - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0813 - val_mean_absolute_error: 0.0813
# Epoch 8/20
# 12456/12456 - 115s - loss: 0.0488 - mean_absolute_error: 0.0488 - val_loss: 0.0740 - val_mean_absolute_error: 0.0740
# Epoch 9/20
# 12456/12456 - 114s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0826 - val_mean_absolute_error: 0.0826
# Epoch 10/20
# 12456/12456 - 117s - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721
# Epoch 11/20
# 12456/12456 - 97s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0798 - val_mean_absolute_error: 0.0798
# Epoch 12/20
# 12456/12456 - 106s - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0709 - val_mean_absolute_error: 0.0709
# Epoch 13/20
# 12456/12456 - 108s - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717
# Epoch 14/20
# 12456/12456 - 106s - loss: 0.0431 - mean_absolute_error: 0.0431 - val_loss: 0.0797 - val_mean_absolute_error: 0.0797
# Epoch 15/20
# 12456/12456 - 108s - loss: 0.0423 - mean_absolute_error: 0.0423 - val_loss: 0.0887 - val_mean_absolute_error: 0.0887
# Epoch 16/20
# 12456/12456 - 107s - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594
# Epoch 17/20
# 12456/12456 - 108s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0823 - val_mean_absolute_error: 0.0823
# Epoch 18/20
# 12456/12456 - 106s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0800 - val_mean_absolute_error: 0.0800
# Epoch 19/20
# 12456/12456 - 108s - loss: 0.0401 - mean_absolute_error: 0.0401 - val_loss: 0.0754 - val_mean_absolute_error: 0.0754
# Epoch 20/20
# 12456/12456 - 107s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0767 - val_mean_absolute_error: 0.0767

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['4p ', '5p', '6p','7p','8p','9p'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Complete_Training_Loss_mae.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['4p ', '5p', '6p','7p','8p','9p'], loc='upper right')
#plt.xlim(0.0,)
#plt.ylim(0.0,0.5)
plt.xticks(np.arange(0.0, 21, 2))
plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Complete_Validation_Loss_mae.png', dpi=1200)
plt.show()
