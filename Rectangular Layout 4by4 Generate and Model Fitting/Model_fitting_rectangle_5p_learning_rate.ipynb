# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
import pandas as pd

# %%
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_4.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_4.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from numpy import loadtxt
from keras.models import load_model
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm


input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#opt = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(loss='mae', optimizer="adam")
model.summary()
history_9 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96599853  0.27606791 -0.07565659 -0.95086392  0.26695474 -0.06533805
#   -0.94930712  0.28749528 -0.05464469 -0.94653851  0.31281185 -0.06572685
#   -1.02090166  0.29927989 -0.09043877 -0.99077126  0.26520123 -0.09134644
#   -0.98375094  0.30325434 -0.07242409 -0.95978485  0.33228947 -0.10427239
#   -1.11885836  0.35967639 -0.059538   -1.15987075  0.32063895 -0.15402077
#   -1.05699218  0.37419412 -0.17750612 -0.91324645  0.32098244 -0.18743819
#   -0.54780831  0.19032361 -0.059538   -0.50679591  0.22936105 -0.15402077
#   -0.60967449  0.17580588 -0.17750612 -0.75342021  0.22901756 -0.18743819]]
# [[ -35.          -35.            1.            0.            0.
#   -110.          -60.        ]
#  [ -25.33333333  -35.            1.            0.            0.
#   -110.          -60.        ]]
# (3072, 48) (3072, 7) training data size
# (1024, 48) (1024, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense (Dense)                (None, 700)               34300
# _________________________________________________________________
# dense_1 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 96/96 - 1s - loss: 0.2475 - val_loss: 0.2031
# Epoch 2/30
# 96/96 - 1s - loss: 0.1951 - val_loss: 0.1829
# Epoch 3/30
# 96/96 - 1s - loss: 0.1726 - val_loss: 0.1681
# Epoch 4/30
# 96/96 - 1s - loss: 0.1607 - val_loss: 0.1603
# Epoch 5/30
# 96/96 - 1s - loss: 0.1520 - val_loss: 0.1511
# Epoch 6/30
# 96/96 - 1s - loss: 0.1444 - val_loss: 0.1501
# Epoch 7/30
# 96/96 - 1s - loss: 0.1423 - val_loss: 0.1485
# Epoch 8/30
# 96/96 - 1s - loss: 0.1389 - val_loss: 0.1434
# Epoch 9/30
# 96/96 - 1s - loss: 0.1309 - val_loss: 0.1391
# Epoch 10/30
# 96/96 - 1s - loss: 0.1278 - val_loss: 0.1429
# Epoch 11/30
# 96/96 - 1s - loss: 0.1240 - val_loss: 0.1254
# Epoch 12/30
# 96/96 - 1s - loss: 0.1217 - val_loss: 0.1363
# Epoch 13/30
# 96/96 - 1s - loss: 0.1192 - val_loss: 0.1167
# Epoch 14/30
# 96/96 - 1s - loss: 0.1153 - val_loss: 0.1283
# Epoch 15/30
# 96/96 - 1s - loss: 0.1133 - val_loss: 0.1200
# Epoch 16/30
# 96/96 - 1s - loss: 0.1098 - val_loss: 0.1341
# Epoch 17/30
# 96/96 - 1s - loss: 0.1085 - val_loss: 0.1204
# Epoch 18/30
# 96/96 - 1s - loss: 0.1090 - val_loss: 0.1191
# Epoch 19/30
# 96/96 - 1s - loss: 0.1020 - val_loss: 0.1130
# Epoch 20/30
# 96/96 - 1s - loss: 0.1011 - val_loss: 0.1069
# Epoch 21/30
# 96/96 - 1s - loss: 0.1018 - val_loss: 0.1164
# Epoch 22/30
# 96/96 - 1s - loss: 0.1013 - val_loss: 0.1162
# Epoch 23/30
# 96/96 - 1s - loss: 0.0980 - val_loss: 0.1056
# Epoch 24/30
# 96/96 - 1s - loss: 0.0950 - val_loss: 0.1089
# Epoch 25/30
# 96/96 - 1s - loss: 0.0945 - val_loss: 0.1101
# Epoch 26/30
# 96/96 - 1s - loss: 0.0965 - val_loss: 0.1079
# Epoch 27/30
# 96/96 - 1s - loss: 0.0962 - val_loss: 0.1242
# Epoch 28/30
# 96/96 - 1s - loss: 0.0962 - val_loss: 0.1038
# Epoch 29/30
# 96/96 - 1s - loss: 0.0912 - val_loss: 0.1042
# Epoch 30/30
# 96/96 - 1s - loss: 0.0919 - val_loss: 0.1062

# %%
##for 0.1 lr
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate 0.1
#
opt = keras.optimizers.Adam(learning_rate=0.1)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_1 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_4 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 3s - loss: 3.1368 - val_loss: 0.2945
# Epoch 2/30
# 367/367 - 3s - loss: 0.2930 - val_loss: 0.2959
# Epoch 3/30
# 367/367 - 3s - loss: 0.2926 - val_loss: 0.2927
# Epoch 4/30
# 367/367 - 3s - loss: 0.2927 - val_loss: 0.2951
# Epoch 5/30
# 367/367 - 4s - loss: 0.2931 - val_loss: 0.2920
# Epoch 6/30
# 367/367 - 3s - loss: 0.2928 - val_loss: 0.2907
# Epoch 7/30
# 367/367 - 3s - loss: 0.2928 - val_loss: 0.2916
# Epoch 8/30
# 367/367 - 3s - loss: 0.2922 - val_loss: 0.2973
# Epoch 9/30
# 367/367 - 3s - loss: 0.2936 - val_loss: 0.2924
# Epoch 10/30
# 367/367 - 3s - loss: 0.2926 - val_loss: 0.2944
# Epoch 11/30
# 367/367 - 3s - loss: 0.2929 - val_loss: 0.2920
# Epoch 12/30
# 367/367 - 3s - loss: 0.2922 - val_loss: 0.2895
# Epoch 13/30
# 367/367 - 3s - loss: 0.2920 - val_loss: 0.2948
# Epoch 14/30
# 367/367 - 3s - loss: 0.2932 - val_loss: 0.2939
# Epoch 15/30
# 367/367 - 3s - loss: 0.2925 - val_loss: 0.2959
# Epoch 16/30
# 367/367 - 3s - loss: 0.2930 - val_loss: 0.2949
# Epoch 17/30
# 367/367 - 3s - loss: 0.2929 - val_loss: 0.2911
# Epoch 18/30
# 367/367 - 3s - loss: 0.2925 - val_loss: 0.2937
# Epoch 19/30
# 367/367 - 3s - loss: 0.2929 - val_loss: 0.2921
# Epoch 20/30
# 367/367 - 5s - loss: 0.2926 - val_loss: 0.2962
# Epoch 21/30
# 367/367 - 5s - loss: 0.2932 - val_loss: 0.3010
# Epoch 22/30
# 367/367 - 5s - loss: 0.2926 - val_loss: 0.2954
# Epoch 23/30
# 367/367 - 6s - loss: 0.2933 - val_loss: 0.2965
# Epoch 24/30
# 367/367 - 5s - loss: 0.2920 - val_loss: 0.2912
# Epoch 25/30
# 367/367 - 5s - loss: 0.2940 - val_loss: 0.2918
# Epoch 26/30
# 367/367 - 5s - loss: 0.2935 - val_loss: 0.3019
# Epoch 27/30
# 367/367 - 5s - loss: 0.2933 - val_loss: 0.2929
# Epoch 28/30
# 367/367 - 5s - loss: 0.2924 - val_loss: 0.3005
# Epoch 29/30
# 367/367 - 5s - loss: 0.2935 - val_loss: 0.2983
# Epoch 30/30
# 367/367 - 5s - loss: 0.2928 - val_loss: 0.3000

# %%
##for 0.01
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_2 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_7 (Dense)              (None, 700)               490700
# _________________________________________________________________
# dense_8 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 6s - loss: 0.2330 - val_loss: 0.1856
# Epoch 2/30
# 367/367 - 5s - loss: 0.1710 - val_loss: 0.1614
# Epoch 3/30
# 367/367 - 5s - loss: 0.1516 - val_loss: 0.1594
# Epoch 4/30
# 367/367 - 5s - loss: 0.1368 - val_loss: 0.1364
# Epoch 5/30
# 367/367 - 6s - loss: 0.1311 - val_loss: 0.1421
# Epoch 6/30
# 367/367 - 5s - loss: 0.1254 - val_loss: 0.1272
# Epoch 7/30
# 367/367 - 6s - loss: 0.1198 - val_loss: 0.1358
# Epoch 8/30
# 367/367 - 6s - loss: 0.1156 - val_loss: 0.1181
# Epoch 9/30
# 367/367 - 6s - loss: 0.1130 - val_loss: 0.1429
# Epoch 10/30
# 367/367 - 6s - loss: 0.1118 - val_loss: 0.1101
# Epoch 11/30
# 367/367 - 6s - loss: 0.1057 - val_loss: 0.1232
# Epoch 12/30
# 367/367 - 6s - loss: 0.1020 - val_loss: 0.1110
# Epoch 13/30
# 367/367 - 7s - loss: 0.1051 - val_loss: 0.1137
# Epoch 14/30
# 367/367 - 6s - loss: 0.1012 - val_loss: 0.1017
# Epoch 15/30
# 367/367 - 6s - loss: 0.1004 - val_loss: 0.1308
# Epoch 16/30
# 367/367 - 4s - loss: 0.1001 - val_loss: 0.1226
# Epoch 17/30
# 367/367 - 4s - loss: 0.0955 - val_loss: 0.0997
# Epoch 18/30
# 367/367 - 4s - loss: 0.0968 - val_loss: 0.1855
# Epoch 19/30
# 367/367 - 5s - loss: 0.0982 - val_loss: 0.0987
# Epoch 20/30
# 367/367 - 5s - loss: 0.0953 - val_loss: 0.1269
# Epoch 21/30
# 367/367 - 5s - loss: 0.0940 - val_loss: 0.1092
# Epoch 22/30
# 367/367 - 5s - loss: 0.0945 - val_loss: 0.1111
# Epoch 23/30
# 367/367 - 5s - loss: 0.0913 - val_loss: 0.1291
# Epoch 24/30
# 367/367 - 5s - loss: 0.0922 - val_loss: 0.1057
# Epoch 25/30
# 367/367 - 5s - loss: 0.0933 - val_loss: 0.1272
# Epoch 26/30
# 367/367 - 5s - loss: 0.0924 - val_loss: 0.1063
# Epoch 27/30
# 367/367 - 5s - loss: 0.0903 - val_loss: 0.1191
# Epoch 28/30
# 367/367 - 5s - loss: 0.0911 - val_loss: 0.1136
# Epoch 29/30
# 367/367 - 5s - loss: 0.0890 - val_loss: 0.1339
# Epoch 30/30
# 367/367 - 5s - loss: 0.0911 - val_loss: 0.0914

# %%
##for 0.001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mae', optimizer=opt)

model.summary()

history_3 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 700)               34300
# _________________________________________________________________
# dense_10 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_11 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 6s - loss: 0.1896 - val_loss: 0.1586
# Epoch 2/30
# 367/367 - 5s - loss: 0.1456 - val_loss: 0.1426
# Epoch 3/30
# 367/367 - 5s - loss: 0.1288 - val_loss: 0.1490
# Epoch 4/30
# 367/367 - 5s - loss: 0.1164 - val_loss: 0.1264
# Epoch 5/30
# 367/367 - 5s - loss: 0.1084 - val_loss: 0.1021
# Epoch 6/30
# 367/367 - 6s - loss: 0.1031 - val_loss: 0.1233
# Epoch 7/30
# 367/367 - 5s - loss: 0.0965 - val_loss: 0.1200
# Epoch 8/30
# 367/367 - 5s - loss: 0.0931 - val_loss: 0.1211
# Epoch 9/30
# 367/367 - 5s - loss: 0.0898 - val_loss: 0.1109
# Epoch 10/30
# 367/367 - 5s - loss: 0.0879 - val_loss: 0.1348
# Epoch 11/30
# 367/367 - 6s - loss: 0.0844 - val_loss: 0.1125
# Epoch 12/30
# 367/367 - 5s - loss: 0.0798 - val_loss: 0.1004
# Epoch 13/30
# 367/367 - 6s - loss: 0.0790 - val_loss: 0.1118
# Epoch 14/30
# 367/367 - 6s - loss: 0.0777 - val_loss: 0.0973
# Epoch 15/30
# 367/367 - 6s - loss: 0.0756 - val_loss: 0.1036
# Epoch 16/30
# 367/367 - 7s - loss: 0.0724 - val_loss: 0.0970
# Epoch 17/30
# 367/367 - 6s - loss: 0.0727 - val_loss: 0.1147
# Epoch 18/30
# 367/367 - 6s - loss: 0.0699 - val_loss: 0.1180
# Epoch 19/30
# 367/367 - 6s - loss: 0.0695 - val_loss: 0.0908
# Epoch 20/30
# 367/367 - 5s - loss: 0.0688 - val_loss: 0.0975
# Epoch 21/30
# 367/367 - 5s - loss: 0.0675 - val_loss: 0.1163
# Epoch 22/30
# 367/367 - 6s - loss: 0.0669 - val_loss: 0.1038
# Epoch 23/30
# 367/367 - 6s - loss: 0.0642 - val_loss: 0.1134
# Epoch 24/30
# 367/367 - 6s - loss: 0.0639 - val_loss: 0.1041
# Epoch 25/30
# 367/367 - 6s - loss: 0.0637 - val_loss: 0.0929
# Epoch 26/30
# 367/367 - 6s - loss: 0.0625 - val_loss: 0.0902
# Epoch 27/30
# 367/367 - 6s - loss: 0.0620 - val_loss: 0.1064
# Epoch 28/30
# 367/367 - 6s - loss: 0.0626 - val_loss: 0.1108
# Epoch 29/30
# 367/367 - 6s - loss: 0.0614 - val_loss: 0.1082
# Epoch 30/30
# 367/367 - 6s - loss: 0.0584 - val_loss: 0.0879

# %%
##for 0.0001
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer=opt)
model.summary()

history_4 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale))
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_13 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_14 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 10s - loss: 0.2232 - val_loss: 0.1949
# Epoch 2/30
# 367/367 - 6s - loss: 0.1801 - val_loss: 0.1725
# Epoch 3/30
# 367/367 - 6s - loss: 0.1620 - val_loss: 0.1587
# Epoch 4/30
# 367/367 - 6s - loss: 0.1505 - val_loss: 0.1489
# Epoch 5/30
# 367/367 - 6s - loss: 0.1423 - val_loss: 0.1414
# Epoch 6/30
# 367/367 - 5s - loss: 0.1359 - val_loss: 0.1383
# Epoch 7/30
# 367/367 - 5s - loss: 0.1300 - val_loss: 0.1305
# Epoch 8/30
# 367/367 - 4s - loss: 0.1258 - val_loss: 0.1282
# Epoch 9/30
# 367/367 - 5s - loss: 0.1215 - val_loss: 0.1244
# Epoch 10/30
# 367/367 - 6s - loss: 0.1180 - val_loss: 0.1230
# Epoch 11/30
# 367/367 - 6s - loss: 0.1150 - val_loss: 0.1176
# Epoch 12/30
# 367/367 - 7s - loss: 0.1124 - val_loss: 0.1169
# Epoch 13/30
# 367/367 - 7s - loss: 0.1097 - val_loss: 0.1146
# Epoch 14/30
# 367/367 - 7s - loss: 0.1070 - val_loss: 0.1163
# Epoch 15/30
# 367/367 - 5s - loss: 0.1052 - val_loss: 0.1116
# Epoch 16/30
# 367/367 - 6s - loss: 0.1029 - val_loss: 0.1142
# Epoch 17/30
# 367/367 - 6s - loss: 0.1009 - val_loss: 0.1111
# Epoch 18/30
# 367/367 - 5s - loss: 0.0991 - val_loss: 0.1092
# Epoch 19/30
# 367/367 - 6s - loss: 0.0971 - val_loss: 0.1077
# Epoch 20/30
# 367/367 - 6s - loss: 0.0954 - val_loss: 0.1069
# Epoch 21/30
# 367/367 - 7s - loss: 0.0941 - val_loss: 0.1062
# Epoch 22/30
# 367/367 - 6s - loss: 0.0924 - val_loss: 0.1061
# Epoch 23/30
# 367/367 - 6s - loss: 0.0914 - val_loss: 0.1029
# Epoch 24/30
# 367/367 - 6s - loss: 0.0898 - val_loss: 0.1011
# Epoch 25/30
# 367/367 - 8s - loss: 0.0883 - val_loss: 0.1004
# Epoch 26/30
# 367/367 - 7s - loss: 0.0873 - val_loss: 0.0997
# Epoch 27/30
# 367/367 - 7s - loss: 0.0866 - val_loss: 0.1024
# Epoch 28/30
# 367/367 - 7s - loss: 0.0848 - val_loss: 0.1021
# Epoch 29/30
# 367/367 - 7s - loss: 0.0837 - val_loss: 0.0978
# Epoch 30/30
# 367/367 - 7s - loss: 0.0827 - val_loss: 0.1005

# %%
##for lr scheduler 5epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_5 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_16 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_17 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 14s - loss: 0.1908 - val_loss: 0.1740
# Epoch 2/30
# 367/367 - 6s - loss: 0.1448 - val_loss: 0.1370
# Epoch 3/30
# 367/367 - 6s - loss: 0.1286 - val_loss: 0.1353
# Epoch 4/30
# 367/367 - 7s - loss: 0.1182 - val_loss: 0.1247
# Epoch 5/30
# 367/367 - 8s - loss: 0.1089 - val_loss: 0.1080
# Epoch 6/30
# 367/367 - 7s - loss: 0.0985 - val_loss: 0.1045
# Epoch 7/30
# 367/367 - 8s - loss: 0.0935 - val_loss: 0.0943
# Epoch 8/30
# 367/367 - 8s - loss: 0.0875 - val_loss: 0.0968
# Epoch 9/30
# 367/367 - 6s - loss: 0.0827 - val_loss: 0.0914
# Epoch 10/30
# 367/367 - 6s - loss: 0.0792 - val_loss: 0.0823
# Epoch 11/30
# 367/367 - 7s - loss: 0.0743 - val_loss: 0.0840
# Epoch 12/30
# 367/367 - 7s - loss: 0.0721 - val_loss: 0.0812
# Epoch 13/30
# 367/367 - 7s - loss: 0.0693 - val_loss: 0.0806
# Epoch 14/30
# 367/367 - 6s - loss: 0.0671 - val_loss: 0.0805
# Epoch 15/30
# 367/367 - 5s - loss: 0.0655 - val_loss: 0.0821
# Epoch 16/30
# 367/367 - 4s - loss: 0.0620 - val_loss: 0.0755
# Epoch 17/30
# 367/367 - 4s - loss: 0.0603 - val_loss: 0.0744
# Epoch 18/30
# 367/367 - 4s - loss: 0.0590 - val_loss: 0.0743
# Epoch 19/30
# 367/367 - 7s - loss: 0.0574 - val_loss: 0.0750
# Epoch 20/30
# 367/367 - 6s - loss: 0.0568 - val_loss: 0.0732
# Epoch 21/30
# 367/367 - 7s - loss: 0.0548 - val_loss: 0.0723
# Epoch 22/30
# 367/367 - 7s - loss: 0.0539 - val_loss: 0.0730
# Epoch 23/30
# 367/367 - 7s - loss: 0.0534 - val_loss: 0.0745
# Epoch 24/30
# 367/367 - 7s - loss: 0.0526 - val_loss: 0.0723
# Epoch 25/30
# 367/367 - 6s - loss: 0.0512 - val_loss: 0.0707
# Epoch 26/30
# 367/367 - 8s - loss: 0.0506 - val_loss: 0.0723
# Epoch 27/30
# 367/367 - 7s - loss: 0.0499 - val_loss: 0.0705
# Epoch 28/30
# 367/367 - 7s - loss: 0.0493 - val_loss: 0.0695
# Epoch 29/30
# 367/367 - 7s - loss: 0.0488 - val_loss: 0.0705
# Epoch 30/30
# 367/367 - 7s - loss: 0.0481 - val_loss: 0.0683

# %%
##for for lr scheduler 10epochs
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_6 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_19 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_20 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 11s - loss: 0.1930 - val_loss: 0.1676
# Epoch 2/30
# 367/367 - 8s - loss: 0.1442 - val_loss: 0.1439
# Epoch 3/30
# 367/367 - 7s - loss: 0.1291 - val_loss: 0.1239
# Epoch 4/30
# 367/367 - 7s - loss: 0.1181 - val_loss: 0.1237
# Epoch 5/30
# 367/367 - 6s - loss: 0.1083 - val_loss: 0.1066
# Epoch 6/30
# 367/367 - 7s - loss: 0.1039 - val_loss: 0.1242
# Epoch 7/30
# 367/367 - 7s - loss: 0.0972 - val_loss: 0.1210
# Epoch 8/30
# 367/367 - 7s - loss: 0.0902 - val_loss: 0.1102
# Epoch 9/30
# 367/367 - 7s - loss: 0.0878 - val_loss: 0.0917
# Epoch 10/30
# 367/367 - 7s - loss: 0.0837 - val_loss: 0.0970
# Epoch 11/30
# 367/367 - 7s - loss: 0.0797 - val_loss: 0.0909
# Epoch 12/30
# 367/367 - 6s - loss: 0.0750 - val_loss: 0.0980
# Epoch 13/30
# 367/367 - 6s - loss: 0.0722 - val_loss: 0.0882
# Epoch 14/30
# 367/367 - 6s - loss: 0.0696 - val_loss: 0.0917
# Epoch 15/30
# 367/367 - 6s - loss: 0.0664 - val_loss: 0.0925
# Epoch 16/30
# 367/367 - 6s - loss: 0.0646 - val_loss: 0.0869
# Epoch 17/30
# 367/367 - 8s - loss: 0.0617 - val_loss: 0.0851
# Epoch 18/30
# 367/367 - 7s - loss: 0.0595 - val_loss: 0.0802
# Epoch 19/30
# 367/367 - 7s - loss: 0.0578 - val_loss: 0.0756
# Epoch 20/30
# 367/367 - 6s - loss: 0.0554 - val_loss: 0.0871
# Epoch 21/30
# 367/367 - 7s - loss: 0.0548 - val_loss: 0.0785
# Epoch 22/30
# 367/367 - 7s - loss: 0.0535 - val_loss: 0.0838
# Epoch 23/30
# 367/367 - 8s - loss: 0.0513 - val_loss: 0.0859
# Epoch 24/30
# 367/367 - 7s - loss: 0.0507 - val_loss: 0.0761
# Epoch 25/30
# 367/367 - 7s - loss: 0.0490 - val_loss: 0.0791
# Epoch 26/30
# 367/367 - 7s - loss: 0.0486 - val_loss: 0.0838
# Epoch 27/30
# 367/367 - 6s - loss: 0.0473 - val_loss: 0.0826
# Epoch 28/30
# 367/367 - 7s - loss: 0.0462 - val_loss: 0.0784
# Epoch 29/30
# 367/367 - 8s - loss: 0.0453 - val_loss: 0.0816
# Epoch 30/30
# 367/367 - 7s - loss: 0.0449 - val_loss: 0.0845

# %%
##for 7p
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 15:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

#my_callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)]
#    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
#    tf.keras.callbacks.CSVLogger('Points_5_training.log')]
# Display the model
model.summary()

history_7 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_22 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_23 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 7s - loss: 0.1915 - val_loss: 0.1584
# Epoch 2/30
# 367/367 - 5s - loss: 0.1472 - val_loss: 0.1447
# Epoch 3/30
# 367/367 - 6s - loss: 0.1310 - val_loss: 0.1276
# Epoch 4/30
# 367/367 - 6s - loss: 0.1185 - val_loss: 0.1173
# Epoch 5/30
# 367/367 - 6s - loss: 0.1105 - val_loss: 0.1119
# Epoch 6/30
# 367/367 - 5s - loss: 0.1046 - val_loss: 0.1068
# Epoch 7/30
# 367/367 - 5s - loss: 0.0974 - val_loss: 0.1146
# Epoch 8/30
# 367/367 - 5s - loss: 0.0932 - val_loss: 0.1028
# Epoch 9/30
# 367/367 - 5s - loss: 0.0885 - val_loss: 0.0848
# Epoch 10/30
# 367/367 - 5s - loss: 0.0850 - val_loss: 0.0899
# Epoch 11/30
# 367/367 - 5s - loss: 0.0837 - val_loss: 0.0981
# Epoch 12/30
# 367/367 - 6s - loss: 0.0806 - val_loss: 0.0877
# Epoch 13/30
# 367/367 - 5s - loss: 0.0791 - val_loss: 0.1044
# Epoch 14/30
# 367/367 - 4s - loss: 0.0765 - val_loss: 0.1004
# Epoch 15/30
# 367/367 - 3s - loss: 0.0748 - val_loss: 0.0940
# Epoch 16/30
# 367/367 - 4s - loss: 0.0719 - val_loss: 0.0927
# Epoch 17/30
# 367/367 - 4s - loss: 0.0674 - val_loss: 0.0877
# Epoch 18/30
# 367/367 - 4s - loss: 0.0650 - val_loss: 0.0855
# Epoch 19/30
# 367/367 - 4s - loss: 0.0630 - val_loss: 0.0878
# Epoch 20/30
# 367/367 - 4s - loss: 0.0600 - val_loss: 0.0843
# Epoch 21/30
# 367/367 - 4s - loss: 0.0582 - val_loss: 0.0849
# Epoch 22/30
# 367/367 - 4s - loss: 0.0567 - val_loss: 0.0725
# Epoch 23/30
# 367/367 - 4s - loss: 0.0543 - val_loss: 0.0824
# Epoch 24/30
# 367/367 - 4s - loss: 0.0528 - val_loss: 0.0867
# Epoch 25/30
# 367/367 - 4s - loss: 0.0511 - val_loss: 0.0792
# Epoch 26/30
# 367/367 - 5s - loss: 0.0499 - val_loss: 0.0832
# Epoch 27/30
# 367/367 - 4s - loss: 0.0493 - val_loss: 0.0818
# Epoch 28/30
# 367/367 - 4s - loss: 0.0473 - val_loss: 0.0806
# Epoch 29/30
# 367/367 - 4s - loss: 0.0466 - val_loss: 0.0741
# Epoch 30/30
# 367/367 - 4s - loss: 0.0452 - val_loss: 0.0773

# %%
##for lr scheduler 20
#Reading the Training data (virtually generated) from a file 
#Input data
x_data = pd.read_csv('x_rec_16_data_5.csv')
x_data=x_data.values[:,1:]
print("read_x_data")
#Output data
y_data = pd.read_csv('y_rec_16_data_5.csv')
y_data=y_data.values[:,1:]
print("read_y_data")
print(x_data[:2,:])
print(y_data[:2,:])

X_train, X_val, y_train, y_val = train_test_split(x_data, y_data)
print(np.shape(X_train), np.shape(y_train), "training data size")
print(np.shape(X_val), np.shape(y_val),"Validation data size")
#print(X_train[0:9,:])

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_x.fit(X_train)
xtrain_scale=scaler_x.transform(X_train)

scaler_x.fit(X_val)
xval_scale=scaler_x.transform(X_val)

scaler_y.fit(y_train)
ytrain_scale=scaler_y.transform(y_train)

scaler_y.fit(y_val)
yval_scale=scaler_y.transform(y_val)
input_layer = Input(shape=(48,))
hidden_layer_1 = Dense(units = 700, activation = 'relu')(input_layer)
hidden_layer_2 = Dense(units = 700, activation = 'relu')(hidden_layer_1)
output_layer = Dense(units = 7, activation = 'linear')(hidden_layer_2)
model = Model(inputs = input_layer, outputs = output_layer, name = 'Rectangular_4by4_sensor_concept_NN')

#for specific values of learning rate
#
#opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer="adam")
#metrics=['accuracy']
##Implementing Early stopping
def scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

model.summary()

history_8 = model.fit(xtrain_scale, ytrain_scale, epochs=30, verbose=2, validation_data=(xval_scale,yval_scale), callbacks=[callback])
# Out:
# read_x_data
# read_y_data
# [[-0.97820564  0.29297193 -0.07061703 -0.96544182  0.2754832  -0.07559271
#   -0.95055615  0.26713403 -0.06478687 -0.94939434  0.28851273 -0.05467842
#   -1.02291172  0.31880814 -0.06668594 -1.02036267  0.29820167 -0.09116619
#   -0.98972578  0.26476729 -0.09036746 -0.9837491   0.30531915 -0.07307987
#   -1.06898421  0.34968716 -0.03087716 -1.12097493  0.35989869 -0.06120685
#   -1.15727766  0.31518646 -0.15790448 -1.05000599  0.3741363  -0.18206539
#   -0.59768246  0.20031284 -0.03087716 -0.54569173  0.19010131 -0.06120685
#   -0.50938901  0.23481354 -0.15790448 -0.61666068  0.1758637  -0.18206539]
#  [-0.96984174  0.28045413 -0.07554428 -0.95366561  0.26681943 -0.06915842
#   -0.94867445  0.2803592  -0.05532045 -0.94855848  0.30831947 -0.06174094
#   -1.02365787  0.3062235  -0.08467621 -0.9992982   0.27119693 -0.09646884
#   -0.9827315   0.28755233 -0.07063151 -0.96914893  0.3312652  -0.09716293
#   -1.10428192  0.35754912 -0.04928571 -1.163557    0.34725352 -0.12266363
#   -1.09223439  0.34451607 -0.13466374 -0.93305379  0.33148657 -0.19556371
#   -0.56238474  0.19245088 -0.04928571 -0.50310967  0.20274648 -0.12266363
#   -0.57443228  0.20548393 -0.13466374 -0.73361288  0.21851343 -0.19556371]]
# [[ -35.    -35.      1.      0.      0.   -110.    -60.  ]
#  [ -27.75  -35.      1.      0.      0.   -110.    -60.  ]]
# (11718, 48) (11718, 7) training data size
# (3907, 48) (3907, 7) Validation data size
# Model: "Rectangular_4by4_sensor_concept_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 48)]              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 700)               34300
# _________________________________________________________________
# dense_25 (Dense)             (None, 700)               490700
# _________________________________________________________________
# dense_26 (Dense)             (None, 7)                 4907
# =================================================================
# Total params: 529,907
# Trainable params: 529,907
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 367/367 - 7s - loss: 0.1931 - val_loss: 0.1672
# Epoch 2/30
# 367/367 - 5s - loss: 0.1474 - val_loss: 0.1523
# Epoch 3/30
# 367/367 - 5s - loss: 0.1298 - val_loss: 0.1312
# Epoch 4/30
# 367/367 - 5s - loss: 0.1164 - val_loss: 0.1312
# Epoch 5/30
# 367/367 - 6s - loss: 0.1088 - val_loss: 0.1469
# Epoch 6/30
# 367/367 - 5s - loss: 0.1022 - val_loss: 0.1333
# Epoch 7/30
# 367/367 - 5s - loss: 0.0963 - val_loss: 0.1353
# Epoch 8/30
# 367/367 - 5s - loss: 0.0929 - val_loss: 0.1238
# Epoch 9/30
# 367/367 - 5s - loss: 0.0886 - val_loss: 0.1169
# Epoch 10/30
# 367/367 - 5s - loss: 0.0852 - val_loss: 0.1285
# Epoch 11/30
# 367/367 - 5s - loss: 0.0815 - val_loss: 0.1467
# Epoch 12/30
# 367/367 - 5s - loss: 0.0799 - val_loss: 0.1439
# Epoch 13/30
# 367/367 - 4s - loss: 0.0781 - val_loss: 0.1406
# Epoch 14/30
# 367/367 - 4s - loss: 0.0754 - val_loss: 0.1468
# Epoch 15/30
# 367/367 - 3s - loss: 0.0738 - val_loss: 0.1409
# Epoch 16/30
# 367/367 - 4s - loss: 0.0728 - val_loss: 0.1355
# Epoch 17/30
# 367/367 - 5s - loss: 0.0711 - val_loss: 0.1380
# Epoch 18/30
# 367/367 - 5s - loss: 0.0700 - val_loss: 0.1393
# Epoch 19/30
# 367/367 - 5s - loss: 0.0678 - val_loss: 0.1590
# Epoch 20/30
# 367/367 - 5s - loss: 0.0680 - val_loss: 0.1674
# Epoch 21/30
# 367/367 - 5s - loss: 0.0655 - val_loss: 0.1231
# Epoch 22/30
# 367/367 - 5s - loss: 0.0627 - val_loss: 0.1432
# Epoch 23/30
# 367/367 - 7s - loss: 0.0590 - val_loss: 0.1533
# Epoch 24/30
# 367/367 - 5s - loss: 0.0579 - val_loss: 0.1352
# Epoch 25/30
# 367/367 - 5s - loss: 0.0556 - val_loss: 0.1464
# Epoch 26/30
# 367/367 - 5s - loss: 0.0533 - val_loss: 0.1568
# Epoch 27/30
# 367/367 - 5s - loss: 0.0521 - val_loss: 0.1427
# Epoch 28/30
# 367/367 - 5s - loss: 0.0494 - val_loss: 0.1602
# Epoch 29/30
# 367/367 - 5s - loss: 0.0488 - val_loss: 0.1600
# Epoch 30/30
# 367/367 - 5s - loss: 0.0482 - val_loss: 0.1602

# %%
#plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#lgd=plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.04,0.25)
plt.xticks(np.arange(0.0, 31, 2))
plt.yticks(np.arange(0.04, 0.25, 0.02))
plt.savefig('Validation_Loss_for_lr_2_5p.png', dpi=1200)
plt.show()

# %%
#plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.04,0.25)
plt.xticks(np.arange(0.0, 31, 2))
plt.yticks(np.arange(0.04, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_2_5p.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['val_loss'])
plt.plot(history_2.history['val_loss'])
plt.plot(history_3.history['val_loss'])
plt.plot(history_4.history['val_loss'])
plt.plot(history_5.history['val_loss'])
plt.plot(history_6.history['val_loss'])
plt.plot(history_7.history['val_loss'])
plt.plot(history_8.history['val_loss'])
plt.plot(history_9.history['val_loss'])
plt.title('Cross-Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
#plt.legend(['lr=0.1','lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20', 'adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.0,)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.0, 0.23, 0.02))
plt.savefig('Validation_Loss_for_lr_5p.png', dpi=1200)
plt.show()

# %%
plt.plot(history_1.history['loss'])
plt.plot(history_2.history['loss'])
plt.plot(history_3.history['loss'])
plt.plot(history_4.history['loss'])
plt.plot(history_5.history['loss'])
plt.plot(history_6.history['loss'])
plt.plot(history_7.history['loss'])
plt.plot(history_8.history['loss'])
plt.plot(history_9.history['loss'])
plt.title('Training loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['lr=0.1','lr=0.01','lr=0.001','lr=0.0001','lr scheduler_5','lr scheduler_10','lr scheduler_15','lr scheduler_20','adam'], loc='upper right')
#plt.xlim(0.0,)
plt.ylim(0.0,)
plt.xticks(np.arange(0.0, 31, 2))
#plt.yticks(np.arange(0.0, 0.25, 0.02))
plt.savefig('Training_Loss_for_lr_5p.png', dpi=1200)
plt.show()
